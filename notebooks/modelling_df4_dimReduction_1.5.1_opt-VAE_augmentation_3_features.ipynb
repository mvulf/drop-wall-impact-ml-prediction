# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import optuna

from pathlib import Path
import sys

from typing import Type
from sklearn.base import BaseEstimator
sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
from split_tools import get_train_test

sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from modelling4_utils import (
    BetaVAEncoder,
    MLPipeline,
    OptunaOptimizer,
    deep_update,
    deep_update_dim_transformer_params,
    RANDOM_STATE,
)

seed = RANDOM_STATE

from catboost import CatBoostClassifier
from statsmodels.api import Logit

from sklearn.decomposition import PCA

from sklearn.metrics import (
    make_scorer,
    f1_score,
    mean_squared_error
)

import optuna
from functools import partial

from copy import deepcopy

# %% [markdown]
# ## Settings

# %%
model_postfix = 'vae'

scoring_metrics={
    'mse': mean_squared_error,
}
step_scoring_average = "mean"
n_trials = 100 # was 600

features_to_drop=(
    'sign_sedimentation_Re',
    'sign_sedimentation_Stk',
    'sign_particle_droplet_diameter_ratio',
)

save_model_and_metrics = False
metrics_file = "metrics_modelling4_7-dim_reduction.xlsx"

# %% [markdown]
# ## Optimization function

# %%
def optimize_vae_optuna(
    dim_transformer:Type[BaseEstimator]=BetaVAEncoder,
    dim_transformer_params:dict=None,
    target:str='splashing', # Need for SMOTE before dim reduction
    dummy_estimator:Type[BaseEstimator]=CatBoostClassifier,  # placeholder
    objective:callable=None,
    direction:str="minimize",
    n_trials:int=n_trials,
    features_to_drop:tuple=features_to_drop,
    step_scoring_average:str=step_scoring_average,
    scoring_metrics:dict=scoring_metrics,
    verbose:bool=True,
    opt_cv_folds:int=5,
    seed:int=seed,
):
    dim_transformer_params = dim_transformer_params or {}
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=dummy_estimator,
        dim_transformer=dim_transformer,
        dim_transformer_params=dim_transformer_params,
        features_to_drop=features_to_drop,
        cv_folds=opt_cv_folds,
        verbose=verbose,
        step_scoring_average=step_scoring_average,
        scoring_metrics=scoring_metrics,
    )
    
    opt = OptunaOptimizer(
        objective=partial(
            objective,
            ml_pipe=ml_pipe,
        ),
        study_name='VAE_study',
        direction=direction,
        seed=seed,
    )
    
    opt.optimize(
        n_trials=n_trials,
        catch=(ValueError,),
    )
    
    best_params = opt.study.best_params
    
    print('raw best_params')
    display(best_params)
    
    return best_params


def VAE_objective(
    trial:optuna.trial.Trial,
    ml_pipe:MLPipeline,
):
    # VAE params
    # hidden_dim = 2**trial.suggest_int('log2_hidden_dim', 2, 8)
    hidden_dim = 2**trial.suggest_int('log2_hidden_dim', 2, 7)
    # normalization = trial.suggest_categorical('normalization', ['batch', 'layer', False])
    normalization = trial.suggest_categorical('normalization', ['batch', 'layer'])
    # activation = trial.suggest_categorical('activation', ['ReLU', 'LeakyReLU', False])
    activation = trial.suggest_categorical('activation', ['ReLU', 'LeakyReLU'])
    
    if activation == 'LeakyReLU':
        # negative_slope = trial.suggest_float('negative_slope', 0.01, .3, log=True)
        negative_slope = trial.suggest_float('negative_slope', 0.01, .1)
    else:
        negative_slope = None
    
    # BetaVAEncoder params
    # learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    beta_warmup_steps = trial.suggest_int('beta_warmup_steps', 100, 2000)
    # beta_start = trial.suggest_float('beta_start', 0.0, 0.5)
    # beta_end = trial.suggest_float('beta_end', 1.0, 10.0)
    beta_start = trial.suggest_float('beta_start', 0.0, 0.05)
    beta_end = trial.suggest_float('beta_end', 0.05, 0.3)
    
    suggested_transformer_params = {
        'VAE_params': {
            'hidden_dim': hidden_dim,
            'normalization': normalization,
            'activation': activation,
            'negative_slope': negative_slope,
        },
        'learning_rate': learning_rate,
        'beta_warmup_steps': beta_warmup_steps,
        'beta_start': beta_start,
        'beta_end': beta_end,
    }
    
    dim_transformer_params = deep_update_dim_transformer_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_transformer_params,
    )
    
    try:
        score = ml_pipe.step_transformer(
            dim_transformer_params=dim_transformer_params,
        )
    except ValueError as e:
        trial.set_user_attr('fail_reason', str(e))
        raise
    
    score_val = score[0]
    # score_train = score[1]
    return score_val

# %%
dim_transformer_params = {
    'VAE_params': {
            'latent_dim': 3,
        },
    'verbose': False,
    'early_stopping': True,
    'early_stopping_patience': 10,
    'max_epochs': 500,
}

raw_vae_params = optimize_vae_optuna(
    dim_transformer_params=dim_transformer_params,
    objective=VAE_objective,
)
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Re',
#  'sedimentation_Stk',
#  'particle_liquid_density_ratio',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'Re',
#  'We',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'init_volume_fraction',
#                                   'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Re', 'sedimentation_Stk',
#                                   'particle_liquid_density_ratio',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'Re', 'We', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# [I 2025-05-06 22:18:23,628] A new study created in memory with name: VAE_study
# [I 2025-05-06 22:18:24,886] Trial 0 finished with value: 0.7812430597615815 and parameters: {'log2_hidden_dim': 4, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.00020511104188433984, 'beta_warmup_steps': 210, 'beta_start': 0.04330880728874676, 'beta_end': 0.20027875293580222}. Best is trial 0 with value: 0.7812430597615815.
# [I 2025-05-06 22:18:28,328] Trial 1 finished with value: 0.3425997785354883 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.0002310201887845295, 'beta_warmup_steps': 448, 'beta_start': 0.015212112147976888, 'beta_end': 0.18118910790805948}. Best is trial 1 with value: 0.3425997785354883.
# [I 2025-05-06 22:18:32,256] Trial 2 finished with value: 0.2773200760056137 and parameters: {'log2_hidden_dim': 4, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.04297256589643226, 'learning_rate': 0.000816845589476017, 'beta_warmup_steps': 1592, 'beta_start': 0.009983689107917987, 'beta_end': 0.17855860960340292}. Best is trial 2 with value: 0.2773200760056137.
# [I 2025-05-06 22:18:34,336] Trial 3 finished with value: 0.11990362711691216 and parameters: {'log2_hidden_dim': 5, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.007902619549708232, 'beta_warmup_steps': 1935, 'beta_start': 0.04041986740582306, 'beta_end': 0.1261534422933427}. Best is trial 3 with value: 0.11990362711691216.
# [I 2025-05-06 22:18:36,539] Trial 4 finished with value: 0.34358003115143526 and parameters: {'log2_hidden_dim': 2, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0.013094966900369657, 'learning_rate': 0.006586289317583112, 'beta_warmup_steps': 591, 'beta_start': 0.0331261142176991, 'beta_end': 0.12792776902235276}. Best is trial 3 with value: 0.11990362711691216.
# [I 2025-05-06 22:18:38,225] Trial 5 finished with value: 0.15366485970390184 and parameters: {'log2_hidden_dim': 5, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.007568292060167618, 'beta_warmup_steps': 1801, 'beta_start': 0.02989499894055426, 'beta_end': 0.2804685587557792}. Best is trial 3 with value: 0.11990362711691216.
# [I 2025-05-06 22:18:40,961] Trial 6 finished with value: 0.3541222736927838 and parameters: {'log2_hidden_dim': 2, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0
. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:31,686] Trial 71 finished with value: 0.08953512643705402 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.004129805046555924, 'beta_warmup_steps': 1790, 'beta_start': 0.015652599106117396, 'beta_end': 0.09137069362573913}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:34,031] Trial 72 finished with value: 0.09580151790047564 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.004403463783570699, 'beta_warmup_steps': 1772, 'beta_start': 0.015612670774903038, 'beta_end': 0.09081794682516667}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:37,006] Trial 73 finished with value: 0.09529318270069277 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.003882953821550118, 'beta_warmup_steps': 1667, 'beta_start': 0.02443233698242729, 'beta_end': 0.07663016802589434}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:41,439] Trial 74 finished with value: 0.18927994042472812 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.0004628343114483634, 'beta_warmup_steps': 1839, 'beta_start': 0.002190101159651292, 'beta_end': 0.06683895484851007}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:43,308] Trial 75 finished with value: 0.09800849738907988 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.004836676011131087, 'beta_warmup_steps': 1474, 'beta_start': 0.014740471002096937, 'beta_end': 0.20013301618295132}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:45,762] Trial 76 finished with value: 0.09666552608565226 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.0030223320719722797, 'beta_warmup_steps': 1944, 'beta_start': 0.005131628316808835, 'beta_end': 0.08604825015772216}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:50,363] Trial 77 finished with value: 0.22353259627605446 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.0003619659985249688, 'beta_warmup_steps': 1647, 'beta_start': 0.007145772147057627, 'beta_end': 0.10066090183672748}. Best is trial 42 with value: 0.08629089982327082.
# [I 2025-05-06 22:21:53,153] Trial 78 finished with value: 0.08354076183937234 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.005858897318652011, 'beta_warmup_steps': 1765, 'beta_start': 0.010429652425245252, 'beta_end': 0.05690400482544297}. Best is trial 78 with value: 0.08354076183937234.
# [I 2025-05-06 22:21:56,227] Trial 79 finished with value: 0.18213139240140724 and parameters: {'log2_hidden_dim': 3, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.005680506639241825, 'beta_warmup_steps': 1763, 'beta_start': 0.010393736637377998, 'beta_end': 0.056167621947336835}. Best is trial 78 with value: 0.08354076183937234.
# [I 2025-05-06 22:21:59,026] Trial 80 finished with value: 0.09603911490011052 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.00365243015863451, 'beta_warmup_steps': 1547, 'beta_start': 0.020498472403231157, 'beta_end': 0.061409868930764805}. Best is trial 78 with value: 0.08354076183937234.
# [I 2025-05-06 22:22:01,492] Trial 81 finished with value: 0.08042182039415259 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.006922247850538581, 'beta_warmup_steps': 1868, 'beta_start': 0.001533630277278449, 'beta_end': 0.08022850614053856}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:04,244] Trial 82 finished with value: 0.08694142782016726 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008903999326121794, 'beta_warmup_steps': 1731, 'beta_start': 0.0129319041131112, 'beta_end': 0.05005369710936624}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:06,736] Trial 83 finished with value: 0.08836278662312938 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.006602152877358343, 'beta_warmup_steps': 1730, 'beta_start': 0.013311313791828218, 'beta_end': 0.08364318382145558}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:09,086] Trial 84 finished with value: 0.08437731700477256 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008791819551703078, 'beta_warmup_steps': 1703, 'beta_start': 0.013010066223173501, 'beta_end': 0.08327290662011688}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:11,389] Trial 85 finished with value: 0.08868840172306008 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008415780769876643, 'beta_warmup_steps': 1625, 'beta_start': 0.012769655716631788, 'beta_end': 0.08323279582476452}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:13,711] Trial 86 finished with value: 0.12251101202859323 and parameters: {'log2_hidden_dim': 7, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.00669695082535037, 'beta_warmup_steps': 1710, 'beta_start': 0.0017468478386549868, 'beta_end': 0.08310293412471453}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:15,895] Trial 87 finished with value: 0.08245914616201082 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008311742159887127, 'beta_warmup_steps': 1616, 'beta_start': 0.004671304835362574, 'beta_end': 0.08988422620678382}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:18,228] Trial 88 finished with value: 0.10259593866892328 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.06226215252886757, 'learning_rate': 0.008679520551326389, 'beta_warmup_steps': 1622, 'beta_start': 0.004847209940505809, 'beta_end': 0.09953821042163653}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:20,639] Trial 89 finished with value: 0.08572884591474325 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008000198364432744, 'beta_warmup_steps': 1577, 'beta_start': 0.0072786225665502705, 'beta_end': 0.08749795169257278}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:22,473] Trial 90 finished with value: 0.10076763409262846 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.007355393663139574, 'beta_warmup_steps': 1573, 'beta_start': 0.007607813334083545, 'beta_end': 0.1240690577364056}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:24,464] Trial 91 finished with value: 0.08352501474281307 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008677063323207229, 'beta_warmup_steps': 1499, 'beta_start': 0.0014059813620172328, 'beta_end': 0.08576746070220505}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:25,960] Trial 92 finished with value: 0.1034397079281681 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008863059248097877, 'beta_warmup_steps': 1486, 'beta_start': 0.001597638685397057, 'beta_end': 0.25924592816708586}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:27,714] Trial 93 finished with value: 0.08819594562091435 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.007783243075473726, 'beta_warmup_steps': 1694, 'beta_start': 0.004512602281389131, 'beta_end': 0.10695664763680873}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:29,999] Trial 94 finished with value: 0.08357995321762324 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.007554524905449594, 'beta_warmup_steps': 1697, 'beta_start': 0.004248976062822893, 'beta_end': 0.10581746157032698}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:31,937] Trial 95 finished with value: 0.0905142220604162 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.00986790274606877, 'beta_warmup_steps': 1519, 'beta_start': 0.005974413942126806, 'beta_end': 0.09035295485862194}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:33,836] Trial 96 finished with value: 0.0897601897078647 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.005698130463067266, 'beta_warmup_steps': 1409, 'beta_start': 0.002491217203291307, 'beta_end': 0.1385571833658728}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:35,879] Trial 97 finished with value: 0.09187484867018222 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.007287876172297195, 'beta_warmup_steps': 1570, 'beta_start': 0.0009848926068880917, 'beta_end': 0.11561852921215181}. Best is trial 81 with value: 0.08042182039415259.
# [I 2025-05-06 22:22:38,394] Trial 98 finished with value: 0.07558211106325992 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.008932374659668466, 'beta_warmup_steps': 1868, 'beta_start': 0.009345854997423107, 'beta_end': 0.07521844538935374}. Best is trial 98 with value: 0.07558211106325992.
# [I 2025-05-06 22:22:40,745] Trial 99 finished with value: 0.12194258174121493 and parameters: {'log2_hidden_dim': 7, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.006389669262142865, 'beta_warmup_steps': 1854, 'beta_start': 0.009616633393697387, 'beta_end': 0.1060448714328467}. Best is trial 98 with value: 0.07558211106325992.
# raw best_params
# {'log2_hidden_dim': 7,
#  'normalization': 'layer',
#  'activation': 'ReLU',
#  'learning_rate': 0.008932374659668466,
#  'beta_warmup_steps': 1868,
#  'beta_start': 0.009345854997423107,
#  'beta_end': 0.07521844538935374}

# %%
def get_vae_params(
    raw_vae_params:dict,
):
    hidden_dim = 2**raw_vae_params['log2_hidden_dim']
    suggested_transformer_params = {
        'VAE_params': {
            'hidden_dim': hidden_dim,
            'normalization': raw_vae_params['normalization'],
            'activation': raw_vae_params['activation'],
        },
        'learning_rate':    raw_vae_params['learning_rate'],
        'beta_warmup_steps': raw_vae_params['beta_warmup_steps'],
        'beta_start':       raw_vae_params['beta_start'],
        'beta_end':         raw_vae_params['beta_end'],
    }
    
    if 'negative_slope' in raw_vae_params:
        suggested_transformer_params['VAE_params']['negative_slope'] = (
            raw_vae_params['negative_slope']
        )
    
    return suggested_transformer_params
    
suggested_transformer_params = get_vae_params(
    raw_vae_params=raw_vae_params
)

dim_transformer_params = deepcopy(dim_transformer_params)

deep_update(
    original=dim_transformer_params,
    updates=suggested_transformer_params,
)
dim_transformer_params['verbose'] = True
display(dim_transformer_params)
# Out:
# {'VAE_params': {'latent_dim': 3,
#   'hidden_dim': 128,
#   'normalization': 'layer',
#   'activation': 'ReLU'},
#  'verbose': True,
#  'early_stopping': True,
#  'early_stopping_patience': 10,
#  'max_epochs': 500,
#  'learning_rate': 0.008932374659668466,
#  'beta_warmup_steps': 1868,
#  'beta_start': 0.009345854997423107,
#  'beta_end': 0.07521844538935374}

# %%
dim_transformer_params['verbose'] = True
# To simplify data extraction, initialize ml_pipe
target = 'splashing'

ml_pipe = MLPipeline(
    target=target,
    estimator=CatBoostClassifier,
    estimator_params={'verbose': False,},
    # dim_transformer=PCA,
    # dim_transformer_params={'n_components': 6},
    dim_transformer=BetaVAEncoder,
    dim_transformer_params=dim_transformer_params,
    features_to_drop=features_to_drop,
    model_postfix=model_postfix,
    verbose=True,
)

# X_train = ml_pipe.train.drop(columns=[target])
# X_test = ml_pipe.test.drop(columns=[target])
# display(X_train.info())
# display(X_test.info())

ml_pipe.run(
    save_model_and_metrics=False,
    cv_verbose=False,
)
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Re',
#  'sedimentation_Stk',
#  'particle_liquid_density_ratio',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'Re',
#  'We',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'init_volume_fraction',
#                                   'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Re', 'sedimentation_Stk',
#                                   'particle_liquid_density_ratio',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'Re', 'We', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# [CV] END .................................................... total time=   1.4s
# [CV] END .................................................... total time=   1.3s
# [CV] END .................................................... total time=   1.2s
# [CV] END .................................................... total time=   1.3s
# [CV] END .................................................... total time=   1.2s
# [CV] END .................................................... total time=   1.2s
# [CV] END .................................................... total time=   1.2s
# VAE_params: {'latent_dim': 3, 'hidden_dim': 128, 'normalization': 'layer', 'activation': 'ReLU', 'input_dim': 12, 'verbose': True}
# Encoder: Sequential(
#   (0): Linear(in_features=12, out_features=128, bias=True)
#   (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (2): ReLU(inplace=True)
# )
# Latent space:
# 	Mu: Linear(in_features=128, out_features=3, bias=True)
# 	log_sigma2: Linear(in_features=128, out_features=3, bias=True)
# Decoder: Sequential(
#   (0): Linear(in_features=3, out_features=128, bias=True)
#   (1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (2): ReLU(inplace=True)
#   (3): Linear(in_features=128, out_features=12, bias=True)
# )
# Epochs:   0%|          | 0/500 [00:00<?, ?it/s]
# Early stopping at epoch 44.
# no summary in estimator class "CatBoostClassifier"
#                                                                        0
# target                                                         splashing
# model                             CatBoostClassifier_splashing_smote_vae
# holdout_test_f1_macro                                           0.839525
# holdout_test_accuracy_balanced                                  0.836806
# holdout_test_roc_auc                                            0.921296
# holdout_test_f1                                                 0.886598
# holdout_test_accuracy                                           0.853333
# cv_test_f1_macro_median                                         0.858018
# cv_test_accuracy_balanced_median                                0.873016
# cv_test_roc_auc_median                                          0.939628
# cv_test_f1_median                                               0.895522
# cv_test_accuracy_median                                         0.867925
# cv_test_precision_class_0_median                                0.764706
# cv_test_recall_class_0_median                                   0.894737
# cv_test_f1_class_0_median                                       0.820513

# %% [markdown]
# Total Loss increases because beta increases!
