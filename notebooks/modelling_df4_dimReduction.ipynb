# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import optuna

from pathlib import Path
import sys

sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from modelling4_utils import (
    BetaVAEncoder,
)

# %%
vae_encoder = BetaVAEncoder(
    VAE_params={
        'latent_dim': 3,
        'hidden_dim': 32,
    },
    verbose=True,
    learning_rate=1e-3,
    max_epochs=200,
)

X = np.random.randn(300, 12)

Z = vae_encoder.fit_transform(X)
# Out:
# VAE_params: {'latent_dim': 3, 'hidden_dim': 32, 'input_dim': 12, 'verbose': True}
# Encoder: Sequential(
#   (0): Linear(in_features=12, out_features=32, bias=True)
#   (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.1, inplace=True)
# )
# Latent space:
# 	Mu: Linear(in_features=32, out_features=3, bias=True)
# 	log_sigma2: Linear(in_features=32, out_features=3, bias=True)
# Decoder: Sequential(
#   (0): Linear(in_features=3, out_features=32, bias=True)
#   (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.1, inplace=True)
#   (3): Linear(in_features=32, out_features=12, bias=True)
# )
# Epoch 0/200, Loss: 1.1315, Reconstr Loss: 1.1058, KL Divergence: 0.1332, Beta: 0.36
# 	Val Loss: 0.9345, Val Reconstr Loss: 0.9111, Val KL Divergence: 0.0649
# Epoch 1/200, Loss: 1.1274, Reconstr Loss: 1.0663, KL Divergence: 0.1121, Beta: 0.72
# 	Val Loss: 0.9933, Val Reconstr Loss: 0.9471, Val KL Divergence: 0.0643
# Epoch 2/200, Loss: 1.1168, Reconstr Loss: 1.0405, KL Divergence: 0.0838, Beta: 1.08
# 	Val Loss: 0.9728, Val Reconstr Loss: 0.9168, Val KL Divergence: 0.0518
# Epoch 3/200, Loss: 1.1022, Reconstr Loss: 1.0274, KL Divergence: 0.0590, Beta: 1.44
# 	Val Loss: 0.9664, Val Reconstr Loss: 0.9136, Val KL Divergence: 0.0366
# Epoch 4/200, Loss: 1.0865, Reconstr Loss: 1.0186, KL Divergence: 0.0416, Beta: 1.80
# 	Val Loss: 0.9647, Val Reconstr Loss: 0.9182, Val KL Divergence: 0.0258
# Epoch 5/200, Loss: 1.0822, Reconstr Loss: 1.0214, KL Divergence: 0.0306, Beta: 2.16
# 	Val Loss: 0.9838, Val Reconstr Loss: 0.9432, Val KL Divergence: 0.0188
# Epoch 6/200, Loss: 1.0975, Reconstr Loss: 1.0440, KL Divergence: 0.0228, Beta: 2.52
# 	Val Loss: 0.9356, Val Reconstr Loss: 0.8996, Val KL Divergence: 0.0143
# Epoch 7/200, Loss: 1.0642, Reconstr Loss: 1.0137, KL Divergence: 0.0186, Beta: 2.88
# 	Val Loss: 0.9558, Val Reconstr Loss: 0.9164, Val KL Divergence: 0.0137
# Epoch 8/200, Loss: 1.0729, Reconstr Loss: 1.0183, KL Divergence: 0.0178, Beta: 3.24
# 	Val Loss: 0.9314, Val Reconstr Loss: 0.8873, Val KL Divergence: 0.0136
# Epoch 9/200, Loss: 1.0754, Reconstr Loss: 1.0121, KL Divergence: 0.0183, Beta: 3.60
# 	Val Loss: 0.9802, Val Reconstr Loss: 0.9325, Val KL Divergence: 0.0132
# Epoch 10/200, Loss: 1.0770, Reconstr Loss: 1.0132, KL Divergence: 0.0168, Beta: 3.96
# 	Val Loss: 0.9580, Val Reconstr Loss: 0.9081, Val KL Divergence: 0.0126
# Epoch 11/200, Loss: 1.0682, Reconstr Loss: 1.0001, KL Divergence: 0.0170, Beta: 4.00
# 	Val Loss: 0.9538, Val Reconstr Loss: 0.9042, Val KL Divergence: 0.0124
# Epoch 12/200, Loss: 1.0860, Reconstr Loss: 1.0210, KL Divergence: 0.0162, Beta: 4.00
# 	Val Loss: 0.9432, Val Reconstr Loss: 0.8956, Val KL Divergence: 0.0119
# Epoch 13/200, Loss: 1.0894, Reconstr Loss: 1.0283, KL Divergence: 0.0153, Beta: 4.00
# 	Val Loss: 0.9289, Val Reconstr Loss: 0.8841, Val KL Divergence: 0.0112
# Epoch 14/200, Loss: 1.0800, Reconstr Loss: 1.0202, KL Divergence: 0.0149, Beta: 4.00
# 	Val Loss: 0.9427, Val Reconstr Loss: 0.8982, Val KL Divergence: 0.0111
# Epoch 15/200, Loss: 1.0844, Reconstr Loss: 1.0283, KL Divergence: 0.0140, Beta: 4.00
# 	Val Loss: 0.9697, Val Reconstr Loss: 0.9269, Val KL Divergence: 0.0107
# Epoch 16/200, Loss: 1.0598, Reconstr Loss: 1.0042, KL Divergence: 0.0139, Beta: 4.00
# 	Val Loss: 0.9385, Val Reconstr Loss: 0.8960, Val KL Divergence: 0.0106
# Epoch 17/200, Loss: 1.0716, Reconstr Loss: 1.0189, KL Divergence: 0.0132, Beta: 4.00
# 	Val Loss: 0.9712, Val Reconstr Loss: 0.9296, Val KL Divergence: 0.0104
# Epoch 18/200, Loss: 1.0630, Reconstr Loss: 1.0110, KL Divergence: 0.0130, Beta: 4.00
# 	Val Loss: 0.9766, Val Reconstr Loss: 0.9372, Val KL Divergence: 0.0098
# Epoch 19/200, Loss: 1.0769, Reconstr Loss: 1.0260, KL Divergence: 0.0127, Beta: 4.00
# 	Val Loss: 0.9433, Val Reconstr Loss: 0.9047, Val KL Divergence: 0.0097
# Epoch 20/200, Loss: 1.0687, Reconstr Loss: 1.0178, KL Divergence: 0.0127, Beta: 4.00
# 	Val Loss: 0.9373, Val Reconstr Loss: 0.8987, Val KL Divergence: 0.0097
# Epoch 21/200, Loss: 1.0594, Reconstr Loss: 1.0103, KL Divergence: 0.0123, Beta: 4.00
# 	Val Loss: 0.9332, Val Reconstr Loss: 0.8942, Val KL Divergence: 0.0098
# Epoch 22/200, Loss: 1.0711, Reconstr Loss: 1.0219, KL Divergence: 0.0123, Beta: 4.00
# 	Val Loss: 0.9279, Val Reconstr Loss: 0.8890, Val KL Divergence: 0.0097
# Epoch 23/200, Loss: 1.0574, Reconstr Loss: 1.0071, KL Divergence: 0.0126, Beta: 4.00
# 	Val Loss: 0.9237, Val Reconstr Loss: 0.8854, Val KL Divergence: 0.0096
# Epoch 24/200, Loss: 1.0866, Reconstr Loss: 1.0372, KL Divergence: 0.0123, Beta: 4.00
# 	Val Loss: 0.9823, Val Reconstr Loss: 0.9444, Val KL Divergence: 0.0095
# Epoch 25/200, Loss: 1.0773, Reconstr Loss: 1.0285, KL Divergence: 0.0122, Beta: 4.00
# 	Val Loss: 0.9347, Val Reconstr Loss: 0.8962, Val KL Divergence: 0.0096
# Epoch 26/200, Loss: 1.0591, Reconstr Loss: 1.0120, KL Divergence: 0.0118, Beta: 4.00
# 	Val Loss: 0.9542, Val Reconstr Loss: 0.9158, Val KL Divergence: 0.0096
# Epoch 27/200, Loss: 1.0663, Reconstr Loss: 1.0191, KL Divergence: 0.0118, Beta: 4.00
# 	Val Loss: 0.9555, Val Reconstr Loss: 0.9170, Val KL Divergence: 0.0096
# Epoch 28/200, Loss: 1.0581, Reconstr Loss: 1.0098, KL Divergence: 0.0121, Beta: 4.00
# 	Val Loss: 0.9648, Val Reconstr Loss: 0.9245, Val KL Divergence: 0.0101
# Epoch 29/200, Loss: 1.0709, Reconstr Loss: 1.0231, KL Divergence: 0.0119, Beta: 4.00
# 	Val Loss: 0.9510, Val Reconstr Loss: 0.9115, Val KL Divergence: 0.0099
# Epoch 30/200, Loss: 1.0564, Reconstr Loss: 1.0087, KL Divergence: 0.0119, Beta: 4.00
# 	Val Loss: 0.9433, Val Reconstr Loss: 0.9046, Val KL Divergence: 0.0097
# Epoch 31/200, Loss: 1.0731, Reconstr Loss: 1.0237, KL Divergence: 0.0123, Beta: 4.00
# 	Val Loss: 0.9174, Val Reconstr Loss: 0.8783, Val KL Divergence: 0.0098
# Epoch 32/200, Loss: 1.0707, Reconstr Loss: 1.0237, KL Divergence: 0.0118, Beta: 4.00
# 	Val Loss: 0.9348, Val Reconstr Loss: 0.8976, Val KL Divergence: 0.0093
# Epoch 33/200, Loss: 1.0601, Reconstr Loss: 1.0130, KL Divergence: 0.0118, Beta: 4.00
# 	Val Loss: 0.9603, Val Reconstr Loss: 0.9220, Val KL Divergence: 0.0096
# Epoch 34/200, Loss: 1.0724, Reconstr Loss: 1.0257, KL Divergence: 0.0117, Beta: 4.00
# 	Val Loss: 0.9355, Val Reconstr Loss: 0.8978, Val KL Divergence: 0.0094
# Epoch 35/200, Loss: 1.0681, Reconstr Loss: 1.0200, KL Divergence: 0.0120, Beta: 4.00
# 	Val Loss: 0.9554, Val Reconstr Loss: 0.9186, Val KL Divergence: 0.0092
# Epoch 36/200, Loss: 1.0606, Reconstr Loss: 1.0130, KL Divergence: 0.0119, Beta: 4.00
# 	Val Loss: 0.9416, Val Reconstr Loss: 0.9043, Val KL Divergence: 0.0093
# Epoch 37/200, Loss: 1.0695, Reconstr Loss: 1.0228, KL Divergence: 0.0117, Beta: 4.00
# 	Val Loss: 0.9399, Val Reconstr Loss: 0.9029, Val KL Divergence: 0.0093
# Epoch 38/200, Loss: 1.0710, Reconstr Loss: 1.0249, KL Divergence: 0.0115, Beta: 4.00
# 	Val Loss: 0.9401, Val Reconstr Loss: 0.9032, Val KL Divergence: 0.0092
# Epoch 39/200, Loss: 1.0642, Reconstr Loss: 1.0180, KL Divergence: 0.0116, Beta: 4.00
# 	Val Loss: 0.9214, Val Reconstr Loss: 0.8846, Val KL Divergence: 0.0092
# Epoch 40/200, Loss: 1.0804, Reconstr Loss: 1.0336, KL Divergence: 0.0117, Beta: 4.00
# 	Val Loss: 0.9856, Val Reconstr Loss: 0.9480, Val KL Divergence: 0.0094
# Epoch 41/200, Loss: 1.0778, Reconstr Loss: 1.0309, KL Divergence: 0.0117, Beta: 4.00
# 	Val Loss: 0.9490, Val Reconstr Loss: 0.9124, Val KL Divergence: 0.0091
# Early stopping at epoch 41.
