# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import logging

# Set logging level for PyTorch Tabular
logging.getLogger("pytorch_tabular").setLevel(logging.ERROR)

# Set logging level for PyTorch Lightning
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

# Set logging level for Lightning Fabric
logging.getLogger("lightning_fabric").setLevel(logging.ERROR)

# Disable device availability messages
logging.getLogger("lightning.pytorch.utilities.rank_zero").setLevel(logging.FATAL)

import pandas as pd
import numpy as np

from pytorch_tabular.models import CategoryEmbeddingModelConfig, TabNetModelConfig

import optuna

from functools import partial

from pathlib import Path
import sys

from typing import Type
from sklearn.base import BaseEstimator

from sklearn.metrics import (
    make_scorer,
    f1_score,
)

sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from split_tools import get_train_test
from modelling4_utils import (
    # _prepare_df,
    MLPipeline,
    StatsModelsEstimator,
    PytorchTabularEstimator,
    deep_update_estimator_params,
    OptunaOptimizer,
    GridSearchOptimizer,
    RANDOM_STATE,
)

# from pytorch_lightning.loggers import MLFlowLogger
from pytorch_lightning.loggers import TensorBoardLogger

seed = RANDOM_STATE

# Fix error with save weights

# import torch
# # from omegaconf import DictConfig
# # from omegaconf.base import ContainerMetadata
# # import typing
# # torch.serialization.add_safe_globals([DictConfig, ContainerMetadata, typing.Any])
# import pytorch_tabular.utils.python_utils as pt_utils
# pt_utils.pl_load = lambda f, map_location: torch.load(f, map_location=map_location, weights_only=False)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# True
# 1

# %% [markdown]
# # Settings

# %%
model_postfix = 'opt-model'

scoring_metrics = {"f1_macro": make_scorer(f1_score, average="macro"),}
step_scoring_average = "mean"
n_trials = 500 # make 500

save_model_and_metrics = True
metrics_file = "metrics_modelling4_6_1-neural_networks_no_fragmentation.xlsx"

# %% [markdown]
# ## Optimization function

# %%
def optimize_estimator_optuna(
    target:str,
    estimator:Type[BaseEstimator],
    estimator_params:dict,
    objective:callable,
    n_trials:int,
    add_smote:bool,
    is_smotenc:bool,
    smote_params:dict,
    step_scoring_average:str=step_scoring_average,
    params_to_process:list=None,
    model_postfix:str=model_postfix,
    scoring_metrics:dict=scoring_metrics,
    save_model_and_metrics:bool=save_model_and_metrics,
    metrics_file:str=metrics_file,
    opt_cv_folds:int=5,
    seed:int=seed,
):
    
    estimator_params = estimator_params.copy()
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=estimator,
        estimator_params=estimator_params,
        model_postfix=model_postfix,
        add_smote=add_smote,
        is_smotenc=is_smotenc,
        smote_params=smote_params,
        scoring_metrics=scoring_metrics,
        step_scoring_average=step_scoring_average,
        cv_folds=opt_cv_folds,
    )
    
    opt = OptunaOptimizer(
        objective=partial(objective, ml_pipe=ml_pipe),
        study_name="model_study",
        direction="maximize",
        seed=seed,
    )
    
    opt.optimize(n_trials=n_trials)
    
    best_params = opt.study.best_params
    
    print('raw best_params')
    display(best_params)
    
    if params_to_process:
        for param in params_to_process:
            if param == 'log2_size':
                keys = [k for k in best_params.keys() if param in k]
                sorted_keys = sorted(keys, key=lambda k: int(k.split("_")[1]))
                layer_sizes = [
                    2**best_params.pop(key)
                    for key in sorted_keys
                ]
                best_params['layers'] = '-'.join(map(str, layer_sizes))
            elif param == 'num_layers':
                key = next((k for k in best_params.keys() if param in k), None)
                if key:
                    best_params.pop(key)
            else: # Other cases
                # Find one key in best_params which contains param
                key = next((k for k in best_params.keys() if param in k), None)
                if key:
                    best_params[param] = best_params.pop(key)

    print('best_params')
    display(best_params)
    
    suggested_estimator_params = {
        "model_config_params": best_params
    }
    best_estimator_params = deep_update_estimator_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_estimator_params,
    )
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=estimator,
        estimator_params={**estimator_params, **best_estimator_params},
        model_postfix=model_postfix,
        add_smote=add_smote,
        is_smotenc=is_smotenc,
        smote_params=smote_params,
        step_scoring_average=step_scoring_average, # No need to pass, it would not be used
        metrics_file=metrics_file,
    )
    
    ml_pipe.run(
        save_model_and_metrics=save_model_and_metrics,
    )

# %% [markdown]
# ## TabNet

# %%
def TabNet_objective(
    trial:optuna.trial.Trial, 
    ml_pipe:MLPipeline,
):
    # decoder dimension
    n_d = trial.suggest_int('n_d', 4, 32, step=4)
    # attention dimension
    n_a = trial.suggest_int('n_a', 4, 32, step=4)
    # number of steps of the attention mechanism
    n_steps = trial.suggest_int('n_steps', 1, 5)
    # sparsity parameter - controls the importance of the sparsity loss
    gamma = trial.suggest_float('gamma', 1.0, 1.8)
    # number of shared GLU layers (shared across steps & features)
    n_shared = trial.suggest_int('n_shared', 1, 3)
    # number of independent GLU layers (shared across decision steps)
    n_independent = trial.suggest_int('n_independent', 1, 4)
    # learning rate
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True)
    
    suggested_estimator_params = {
        "model_config_params": {
            'n_d': n_d,
            'n_a': n_a,
            'n_steps': n_steps,
            'gamma': gamma,
            'n_shared': n_shared,
            'n_independent': n_independent,
            'learning_rate': learning_rate,
        }
    }
    
    estimator_params = deep_update_estimator_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_estimator_params,
    )
    
    score = ml_pipe.step(
        estimator=ml_pipe._pipeline_params['estimator'],
        estimator_params=estimator_params,
    )
    
    return score

# %%
estimator = PytorchTabularEstimator
target = "no_fragmentation"

add_smote = True
is_smotenc = True
smote_params = {
    'categorical_features': (
        'wettability',
        'inclination',
    ),
}

estimator_params = {
    "model_class": TabNetModelConfig,
    "model_config_params": {
        'virtual_batch_size': 32,
    },
    # "data_config_params": {},
    "trainer_config_params": {
        'max_epochs': 250,
        'batch_size': 300, # let's condiser whole dataset
        'early_stopping': 'valid_loss',
        'early_stopping_patience': 15,
        'accelerator': 'gpu',
        'devices': 1,
        'progress_bar': 'none',
    },
    "optimizer_config_params": {
        'optimizer': 'Adam',
        'lr_scheduler': 'ReduceLROnPlateau',
        'lr_scheduler_params': {
            'patience': 5,
            'factor': 0.5,
        },
    },
}

optimize_estimator_optuna(
    target=target,
    estimator=estimator,
    estimator_params=estimator_params,
    objective=TabNet_objective,
    n_trials=n_trials,
    add_smote=add_smote,
    is_smotenc=is_smotenc,
    smote_params=smote_params,
)
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ..\data\df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# [I 2025-04-28 22:23:53,137] A new study created in memory with name: model_study
# [I 2025-04-28 22:24:11,987] Trial 0 finished with value: 0.5392016475079326 and parameters: {'n_d': 12, 'n_a': 32, 'n_steps': 4, 'gamma': 1.4789267873576293, 'n_shared': 1, 'n_independent': 1, 'learning_rate':
. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:45:48,397] Trial 32 finished with value: 0.8129486303448912 and parameters: {'n_d': 28, 'n_a': 20, 'n_steps': 4, 'gamma': 1.0012008765488902, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.09597667497754939}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:46:04,676] Trial 33 finished with value: 0.3541239619608173 and parameters: {'n_d': 20, 'n_a': 8, 'n_steps': 4, 'gamma': 1.1554135243905443, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 3.4445716207434064e-05}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:46:29,469] Trial 34 finished with value: 0.8448757568064258 and parameters: {'n_d': 24, 'n_a': 12, 'n_steps': 3, 'gamma': 1.3794994141353254, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.04662975332907781}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:46:54,773] Trial 35 finished with value: 0.7796809176841817 and parameters: {'n_d': 24, 'n_a': 16, 'n_steps': 3, 'gamma': 1.3772093371492222, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.007386210901079622}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:47:39,263] Trial 36 finished with value: 0.8142743325592757 and parameters: {'n_d': 28, 'n_a': 12, 'n_steps': 2, 'gamma': 1.4140911057381151, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0021926760379398}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:48:00,939] Trial 37 finished with value: 0.789285850215748 and parameters: {'n_d': 24, 'n_a': 12, 'n_steps': 1, 'gamma': 1.5510036414618096, 'n_shared': 1, 'n_independent': 3, 'learning_rate': 0.01369140787707847}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:48:27,755] Trial 38 finished with value: 0.7484969324928104 and parameters: {'n_d': 8, 'n_a': 16, 'n_steps': 2, 'gamma': 1.3707311690386017, 'n_shared': 1, 'n_independent': 4, 'learning_rate': 0.05102862335084718}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:48:46,044] Trial 39 finished with value: 0.803667186737733 and parameters: {'n_d': 28, 'n_a': 12, 'n_steps': 3, 'gamma': 1.2997427920032898, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.027305235724379182}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:49:24,445] Trial 40 finished with value: 0.8234257623989312 and parameters: {'n_d': 24, 'n_a': 20, 'n_steps': 3, 'gamma': 1.0598158959340733, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.006847814520026457}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:49:43,729] Trial 41 finished with value: 0.7448663166051264 and parameters: {'n_d': 20, 'n_a': 8, 'n_steps': 4, 'gamma': 1.2349598922363738, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.055441427439264244}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:50:20,491] Trial 42 finished with value: 0.8229491268964952 and parameters: {'n_d': 20, 'n_a': 8, 'n_steps': 4, 'gamma': 1.1413638441230194, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.0337123903756989}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:50:48,719] Trial 43 finished with value: 0.8182968378981119 and parameters: {'n_d': 20, 'n_a': 12, 'n_steps': 3, 'gamma': 1.4801774924919615, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.05408787681631103}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:51:30,523] Trial 44 finished with value: 0.780000924731741 and parameters: {'n_d': 16, 'n_a': 4, 'n_steps': 5, 'gamma': 1.285535623720808, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.020754954778975595}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:52:03,717] Trial 45 finished with value: 0.7996249123915192 and parameters: {'n_d': 24, 'n_a': 8, 'n_steps': 4, 'gamma': 1.3354821139024409, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.09188664384042082}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:52:29,476] Trial 46 finished with value: 0.7847350451924564 and parameters: {'n_d': 16, 'n_a': 12, 'n_steps': 3, 'gamma': 1.233746984406491, 'n_shared': 2, 'n_independent': 3, 'learning_rate': 0.03662389946734743}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:53:00,174] Trial 47 finished with value: 0.7882168991998713 and parameters: {'n_d': 8, 'n_a': 4, 'n_steps': 2, 'gamma': 1.1877719000895328, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.015339688238536733}. Best is trial 4 with value: 0.8462403887528481.
# [I 2025-04-28 22:54:00,595] Trial 48 finished with value: 0.7715903465671604 and parameters: {'n_d': 28, 'n_a': 8, 'n_steps': 5, 'gamma': 1.3442061801787661, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 0
. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:46:20,094] Trial 485 finished with value: 0.8527347072580337 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7454011088464279, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0059905861626660135}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:47:29,691] Trial 486 finished with value: 0.8008276044837033 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7654953579649366, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.000577310905066459}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:48:15,850] Trial 487 finished with value: 0.8712725907227187 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7879257546883234, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.002275216782688808}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:49:20,341] Trial 488 finished with value: 0.8397695178956927 and parameters: {'n_d': 8, 'n_a': 24, 'n_steps': 1, 'gamma': 1.702373001884138, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0014256962642715638}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:50:00,745] Trial 489 finished with value: 0.8703220050177454 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7998603845741115, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0027878399466395496}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:51:04,204] Trial 490 finished with value: 0.7599032268288475 and parameters: {'n_d': 4, 'n_a': 32, 'n_steps': 3, 'gamma': 1.7709821443867646, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0018860902554494652}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:51:39,484] Trial 491 finished with value: 0.8583476235532725 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7323638038855158, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.003878388102646692}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:52:42,125] Trial 492 finished with value: 0.8619558205363832 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7542843620698916, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0011983439310043916}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:53:38,542] Trial 493 finished with value: 0.8504214413037943 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.2726217324781768, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0015089243047026778}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:54:26,341] Trial 494 finished with value: 0.8673926625549344 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.777986036314574, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.002238937058412171}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:55:03,172] Trial 495 finished with value: 0.8688697097661932 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7160382144121848, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.003164017392470129}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:55:37,667] Trial 496 finished with value: 0.8032536173368531 and parameters: {'n_d': 12, 'n_a': 28, 'n_steps': 1, 'gamma': 1.784406882492211, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.002585006831182325}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:56:24,843] Trial 497 finished with value: 0.8307693029174039 and parameters: {'n_d': 20, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7502326832924486, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0016785598911915568}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:56:53,328] Trial 498 finished with value: 0.8432229196589549 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.7674465673478377, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.004287358341358139}. Best is trial 313 with value: 0.8858708938120703.
# [I 2025-04-29 04:57:40,455] Trial 499 finished with value: 0.8697629994813976 and parameters: {'n_d': 8, 'n_a': 28, 'n_steps': 1, 'gamma': 1.741501792596284, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0019307188573743314}. Best is trial 313 with value: 0.8858708938120703.
# raw best_params
# {'n_d': 8,
#  'n_a': 28,
#  'n_steps': 1,
#  'gamma': 1.7805532870058474,
#  'n_shared': 1,
#  'n_independent': 1,
#  'learning_rate': 0.0034854351987926684}
# best_params
# {'n_d': 8,
#  'n_a': 28,
#  'n_steps': 1,
#  'gamma': 1.7805532870058474,
#  'n_shared': 1,
#  'n_independent': 1,
#  'learning_rate': 0.0034854351987926684}
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ..\data\df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "PytorchTabularEstimator"
#                                                                                0
# target                                                          no_fragmentation
# model                             TabNetModel_no_fragmentation_smotenc_opt-model
# holdout_test_f1_macro                                                   0.859023
# holdout_test_accuracy_balanced                                          0.847727
# holdout_test_roc_auc                                                    0.938182
# holdout_test_f1                                                         0.789474
# holdout_test_accuracy                                                   0.893333
# cv_test_f1_macro_median                                                  0.90293
# cv_test_accuracy_balanced_median                                        0.892857
# cv_test_roc_auc_median                                                  0.970696
# cv_test_f1_median                                                       0.857143
# cv_test_accuracy_median                                                 0.924528
# cv_test_precision_class_0_median                                        0.942857
# cv_test_recall_class_0_median                                           0.923077
# cv_test_f1_class_0_median                                               0.945946
# Model saved in ..\results\models_modelling4\TabNetModel_no_fragmentation_smotenc_opt-model
