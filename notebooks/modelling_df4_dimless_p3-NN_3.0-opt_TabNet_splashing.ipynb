# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import logging

# Set logging level for PyTorch Tabular
logging.getLogger("pytorch_tabular").setLevel(logging.ERROR)

# Set logging level for PyTorch Lightning
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

# Set logging level for Lightning Fabric
logging.getLogger("lightning_fabric").setLevel(logging.ERROR)

# Disable device availability messages
logging.getLogger("lightning.pytorch.utilities.rank_zero").setLevel(logging.FATAL)

import pandas as pd
import numpy as np

from pytorch_tabular.models import CategoryEmbeddingModelConfig, TabNetModelConfig

import optuna

from functools import partial

from pathlib import Path
import sys

from typing import Type
from sklearn.base import BaseEstimator

from sklearn.metrics import (
    make_scorer,
    f1_score,
)

sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from split_tools import get_train_test
from modelling4_utils import (
    # _prepare_df,
    MLPipeline,
    StatsModelsEstimator,
    PytorchTabularEstimator,
    deep_update_estimator_params,
    OptunaOptimizer,
    GridSearchOptimizer,
    RANDOM_STATE,
)

# from pytorch_lightning.loggers import MLFlowLogger
from pytorch_lightning.loggers import TensorBoardLogger

seed = RANDOM_STATE

# Fix error with save weights

# import torch
# # from omegaconf import DictConfig
# # from omegaconf.base import ContainerMetadata
# # import typing
# # torch.serialization.add_safe_globals([DictConfig, ContainerMetadata, typing.Any])
# import pytorch_tabular.utils.python_utils as pt_utils
# pt_utils.pl_load = lambda f, map_location: torch.load(f, map_location=map_location, weights_only=False)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# True
# 1

# %% [markdown]
# # Settings

# %%
model_postfix = 'opt-model'

scoring_metrics = {"f1_macro": make_scorer(f1_score, average="macro"),}
step_scoring_average = "mean"
n_trials = 500 # make 500

save_model_and_metrics = True
metrics_file = "metrics_modelling4_6-neural_networks.xlsx"

# %% [markdown]
# ## Optimization function

# %%
def optimize_estimator_optuna(
    target:str,
    estimator:Type[BaseEstimator],
    estimator_params:dict,
    objective:callable,
    n_trials:int,
    add_smote:bool,
    is_smotenc:bool,
    smote_params:dict,
    step_scoring_average:str=step_scoring_average,
    params_to_process:list=None,
    model_postfix:str=model_postfix,
    scoring_metrics:dict=scoring_metrics,
    save_model_and_metrics:bool=save_model_and_metrics,
    metrics_file:str=metrics_file,
    opt_cv_folds:int=5,
    seed:int=seed,
):
    
    estimator_params = estimator_params.copy()
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=estimator,
        estimator_params=estimator_params,
        model_postfix=model_postfix,
        add_smote=add_smote,
        is_smotenc=is_smotenc,
        smote_params=smote_params,
        scoring_metrics=scoring_metrics,
        step_scoring_average=step_scoring_average,
        cv_folds=opt_cv_folds,
    )
    
    opt = OptunaOptimizer(
        objective=partial(objective, ml_pipe=ml_pipe),
        study_name="model_study",
        direction="maximize",
        seed=seed,
    )
    
    opt.optimize(n_trials=n_trials)
    
    best_params = opt.study.best_params
    
    print('raw best_params')
    display(best_params)
    
    if params_to_process:
        for param in params_to_process:
            if param == 'log2_size':
                keys = [k for k in best_params.keys() if param in k]
                sorted_keys = sorted(keys, key=lambda k: int(k.split("_")[1]))
                layer_sizes = [
                    2**best_params.pop(key)
                    for key in sorted_keys
                ]
                best_params['layers'] = '-'.join(map(str, layer_sizes))
            elif param == 'num_layers':
                key = next((k for k in best_params.keys() if param in k), None)
                if key:
                    best_params.pop(key)
            else: # Other cases
                # Find one key in best_params which contains param
                key = next((k for k in best_params.keys() if param in k), None)
                if key:
                    best_params[param] = best_params.pop(key)

    print('best_params')
    display(best_params)
    
    suggested_estimator_params = {
        "model_config_params": best_params
    }
    best_estimator_params = deep_update_estimator_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_estimator_params,
    )
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=estimator,
        estimator_params={**estimator_params, **best_estimator_params},
        model_postfix=model_postfix,
        add_smote=add_smote,
        is_smotenc=is_smotenc,
        smote_params=smote_params,
        step_scoring_average=step_scoring_average, # No need to pass, it would not be used
        metrics_file=metrics_file,
    )
    
    ml_pipe.run(
        save_model_and_metrics=save_model_and_metrics,
    )

# %% [markdown]
# ## TabNet

# %%
def TabNet_objective(
    trial:optuna.trial.Trial, 
    ml_pipe:MLPipeline,
):
    # decoder dimension
    n_d = trial.suggest_int('n_d', 4, 32, step=4)
    # attention dimension
    n_a = trial.suggest_int('n_a', 4, 32, step=4)
    # number of steps of the attention mechanism
    n_steps = trial.suggest_int('n_steps', 1, 5)
    # sparsity parameter - controls the importance of the sparsity loss
    gamma = trial.suggest_float('gamma', 1.0, 1.8)
    # number of shared GLU layers (shared across steps & features)
    n_shared = trial.suggest_int('n_shared', 1, 3)
    # number of independent GLU layers (shared across decision steps)
    n_independent = trial.suggest_int('n_independent', 1, 4)
    # learning rate
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True)
    
    suggested_estimator_params = {
        "model_config_params": {
            'n_d': n_d,
            'n_a': n_a,
            'n_steps': n_steps,
            'gamma': gamma,
            'n_shared': n_shared,
            'n_independent': n_independent,
            'learning_rate': learning_rate,
        }
    }
    
    estimator_params = deep_update_estimator_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_estimator_params,
    )
    
    score = ml_pipe.step(
        estimator=ml_pipe._pipeline_params['estimator'],
        estimator_params=estimator_params,
    )
    
    return score

# %%
estimator = PytorchTabularEstimator
target = "splashing"

add_smote = True
is_smotenc = False
smote_params = {
    # 'categorical_features': (
    #     'wettability',
    #     'inclination',
    # ),
}

estimator_params = {
    "model_class": TabNetModelConfig,
    # Other params SET in optuna
    "model_config_params": {
        'virtual_batch_size': 32,
    },
    # "data_config_params": {},
    "trainer_config_params": {
        'max_epochs': 250,
        'batch_size': 300, # let's condiser whole dataset
        'early_stopping': 'valid_loss',
        'early_stopping_patience': 15,
        'accelerator': 'gpu',
        'devices': 1,
        'progress_bar': 'none',
    },
    "optimizer_config_params": {
        'optimizer': 'Adam',
        'lr_scheduler': 'ReduceLROnPlateau',
        'lr_scheduler_params': {
            'patience': 5,
            'factor': 0.5,
        },
    },
}

optimize_estimator_optuna(
    target=target,
    estimator=estimator,
    estimator_params=estimator_params,
    objective=TabNet_objective,
    n_trials=n_trials,
    add_smote=add_smote,
    is_smotenc=is_smotenc,
    smote_params=smote_params,
)
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# [I 2025-04-28 22:17:29,302] A new study created in memory with name: model_study
# [I 2025-04-28 22:17:49,874] Trial 0 finished with value: 0.5795639467066054 and parameters: {'n_d': 12, 'n_a': 32, 'n_steps': 4, 'gamma': 1.4789267873576293, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 1.7073967431528103e-05}. Best is trial 0 with value: 0.5795639467066054.
# [I 2025-04-28 22:18:52,930] Trial 1 finished with value: 0.4042893442534458 and parameters: {'n_d': 28, 'n_a': 20, 'n_steps': 4, 'gamma': 1.016467595436642, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 7.068974950624602e-05}. Best is trial 0 with value: 0.5795639467066054.
# [I 2025-04-28 22:20:07,414] Trial 2 finished with value: 0.7684237549237549 and parameters: {'n_d': 8, 'n_a': 8, 'n_steps': 2, 'gamma': 1.4198051453057903, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 0.0028016351587162596}. Best is trial 2 with value: 0.7684237549237549.
# [I 2025-04-28 22:21:15,236] Trial 3 finished with value: 0.7188485740098265 and parameters: {'n_d': 8, 'n_a': 12, 'n_steps': 2, 'gamma': 1.3648559873736288, 'n_shared': 3, 'n_independent': 1, 'learning_rate': 0.0011400863701127321}. Best is trial 2 with value: 0.7684237549237549.
# [I 2025-04-28 22:21:59,699] Trial 4 finished with value: 0.8273309372461026 and parameters: {'n_d': 20, 'n_a': 4, 'n_steps': 4, 'gamma': 1.1364192989498332, 'n_shared': 1, 'n_independent': 4, 'learning_rate': 0.07286653737491042}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:23:02,620] Trial 5 finished with value: 0.8226773312229346 and parameters: {'n_d': 28, 'n_a': 12, 'n_steps': 1, 'gamma': 1.5473864212097257, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.0009565499215943821}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:23:50,182] Trial 6 finished with value: 0.7967054694584003 and parameters: {'n_d': 4, 'n_a': 32, 'n_steps': 2, 'gamma': 1.5300178274831855, 'n_shared': 1, 'n_independent': 3, 'learning_rate': 0.0015375920235481753}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:24:49,102] Trial 7 finished with value: 0.7978447437775408 and parameters: {'n_d': 8, 'n_a': 32, 'n_steps': 4, 'gamma': 1.7515991532513513, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.04869640941520897}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:25:11,662] Trial 8 finished with value: 0.8026534603195454 and parameters: {'n_d': 4, 'n_a': 8, 'n_steps': 1, 'gamma': 1.2602642646106115, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 0.02065142557895925}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:25:41,068] Trial 9 finished with value: 0.7995507348961153 and parameters: {'n_d': 12, 'n_a': 12, 'n_steps': 3, 'gamma': 1.1127393799798102, 'n_shared': 3, 'n_independent': 1, 'learning_rate': 0.08862326508576249}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:26:23,124] Trial 10 finished with value: 0.726026990724572 and parameters: {'n_d': 20, 'n_a': 20, 'n_steps': 5, 'gamma': 1.1997002646729518, 'n_shared': 1, 'n_independent': 4, 'learning_rate': 0.008345792463621356}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:27:58,493] Trial 11 finished with value: 0.7420727696054917 and parameters: {'n_d': 32, 'n_a': 4, 'n_steps': 1, 'gamma': 1.6645389136182605, 'n_shared': 2, 'n_independent': 3, 'learning_rate': 0.00020274890145558356}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:28:17,725] Trial 12 finished with value: 0.4832050169832696 and parameters: {'n_d': 20, 'n_a': 4, 'n_steps': 5, 'gamma': 1.5960130821055818, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.0002561061414463539}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:28:50,208] Trial 13 finished with value: 0.7496236920167755 and parameters: {'n_d': 24, 'n_a': 16, 'n_steps': 3, 'gamma': 1.3117359535102595, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.007045490097809971}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:29:58,869] Trial 14 finished with value: 0.6804999196752832 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 4, 'gamma': 1.136043563645182, 'n_shared': 1, 'n_independent': 3, 'learning_rate': 0.0003582840003935093}. Best is trial 4 with value: 0.8273309372461026.
# [I 2025-04-28 22:30:27,060] Trial 15 finished with value: 0.8368562129954519 and parameters: {'n_d': 24, 'n_a': 8, 'n_steps': 1, 'gamma': 1.7854285863180408, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 0.00505449335983824}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:31:06,779] Trial 16 finished with value: 0.8069157722276381 and parameters: {'n_d': 16, 'n_a': 4, 'n_steps': 3, 'gamma': 1.7705302610073226, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.02262440092118986}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:31:56,074] Trial 17 finished with value: 0.8096005665358339 and parameters: {'n_d': 24, 'n_a': 8, 'n_steps': 2, 'gamma': 1.004610458677871, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.005237158758309081}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:32:40,597] Trial 18 finished with value: 0.7653277653034942 and parameters: {'n_d': 16, 'n_a': 16, 'n_steps': 5, 'gamma': 1.6877199001564414, 'n_shared': 2, 'n_independent': 3, 'learning_rate': 0.024265967666884297}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:33:12,394] Trial 19 finished with value: 0.8158560195683439 and parameters: {'n_d': 24, 'n_a': 8, 'n_steps': 4, 'gamma': 1.402405367744498, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.0713341485704057}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:33:48,457] Trial 20 finished with value: 0.7984977896178032 and parameters: {'n_d': 32, 'n_a': 24, 'n_steps': 3, 'gamma': 1.2291720617181945, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.012419793724978269}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:35:09,034] Trial 21 finished with value: 0.8097632292037114 and parameters: {'n_d': 28, 'n_a': 12, 'n_steps': 1, 'gamma': 1.5758809057178926, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.0005819859548536519}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:35:50,871] Trial 22 finished with value: 0.8244400865165316 and parameters: {'n_d': 20, 'n_a': 12, 'n_steps': 1, 'gamma': 1.665552069894914, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.002519705462549954}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:36:30,456] Trial 23 finished with value: 0.7276391845484844 and parameters: {'n_d': 20, 'n_a': 4, 'n_steps': 1, 'gamma': 1.7984152833963516, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 0.0026302428184389556}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:37:09,044] Trial 24 finished with value: 0.7873917527941149 and parameters: {'n_d': 16, 'n_a': 8, 'n_steps': 2, 'gamma': 1.6549737392628758, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.003938931491806729}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:37:30,346] Trial 25 finished with value: 0.7943555296208258 and parameters: {'n_d': 24, 'n_a': 16, 'n_steps': 1, 'gamma': 1.710862389196553, 'n_shared': 2, 'n_independent': 2, 'learning_rate': 0.03234647892689129}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:38:01,787] Trial 26 finished with value: 0.7469847841609414 and parameters: {'n_d': 20, 'n_a': 4, 'n_steps': 2, 'gamma': 1.6193884212332625, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.009735323727668414}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:38:26,876] Trial 27 finished with value: 0.5617638639141693 and parameters: {'n_d': 24, 'n_a': 12, 'n_steps': 3, 'gamma': 1.5012802415354047, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 9.419764524068458e-05}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:39:07,800] Trial 28 finished with value: 0.8272996824405492 and parameters: {'n_d': 16, 'n_a': 8, 'n_steps': 1, 'gamma': 1.7233329962038337, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.0028145304261850937}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:39:44,534] Trial 29 finished with value: 0.8065107732815227 and parameters: {'n_d': 12, 'n_a': 8, 'n_steps': 4, 'gamma': 1.0760951459419328, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.014108422345450171}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:40:03,399] Trial 30 finished with value: 0.47548101194021386 and parameters: {'n_d': 16, 'n_a': 4, 'n_steps': 5, 'gamma': 1.7216238462441618, 'n_shared': 1, 'n_independent': 3, 'learning_rate': 1.2246651174215794e-05}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:40:39,650] Trial 31 finished with value: 0.7481379913815864 and parameters: {'n_d': 20, 'n_a': 8, 'n_steps': 1, 'gamma': 1.4425373481542418, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.0021397661028469523}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:42:02,607] Trial 32 finished with value: 0.8009662557502469 and parameters: {'n_d': 16, 'n_a': 12, 'n_steps': 1, 'gamma': 1.7487638269901045, 'n_shared': 1, 'n_independent': 1, 'learning_rate': 0.0006820184568447252}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:42:17,427] Trial 33 finished with value: 0.39262730396751017 and parameters: {'n_d': 12, 'n_a': 8, 'n_steps': 2, 'gamma': 1.6304948691473917, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 3.4445716207434064e-05}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:42:50,584] Trial 34 finished with value: 0.7720124979481773 and parameters: {'n_d': 20, 'n_a': 4, 'n_steps': 1, 'gamma': 1.3413426670393092, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.003733492621274676}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:43:34,910] Trial 35 finished with value: 0.7808602404310214 and parameters: {'n_d': 28, 'n_a': 16, 'n_steps': 2, 'gamma': 1.4805238348991623, 'n_shared': 1, 'n_independent': 2, 'learning_rate': 0.0016112922916290567}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:43:58,212] Trial 36 finished with value: 0.7974624305792357 and parameters: {'n_d': 24, 'n_a': 12, 'n_steps': 1, 'gamma': 1.7961881677647558, 'n_shared': 2, 'n_independent': 1, 'learning_rate': 0.005189737179493625}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:44:41,901] Trial 37 finished with value: 0.669484035268432 and parameters: {'n_d': 16, 'n_a': 8, 'n_steps': 2, 'gamma': 1.7080220869702871, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.0009707190122352009}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:45:07,459] Trial 38 finished with value: 0.8360119220531119 and parameters: {'n_d': 20, 'n_a': 12, 'n_steps': 1, 'gamma': 1.5552102831075532, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.03928952701683502}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:45:37,120] Trial 39 finished with value: 0.8043858316720922 and parameters: {'n_d': 8, 'n_a': 4, 'n_steps': 2, 'gamma': 1.5660135628049265, 'n_shared': 1, 'n_independent': 4, 'learning_rate': 0.0456499907303949}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:46:24,430] Trial 40 finished with value: 0.7311226126639372 and parameters: {'n_d': 12, 'n_a': 20, 'n_steps': 4, 'gamma': 1.5189162137549221, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.05425820139563714}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:46:56,174] Trial 41 finished with value: 0.826130706521025 and parameters: {'n_d': 20, 'n_a': 12, 'n_steps': 1, 'gamma': 1.6760502085012265, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.015819048561387165}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:47:19,114] Trial 42 finished with value: 0.8137931921185405 and parameters: {'n_d': 20, 'n_a': 8, 'n_steps': 1, 'gamma': 1.7419383486682685, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.09876671104836297}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:47:41,233] Trial 43 finished with value: 0.8279770956274619 and parameters: {'n_d': 24, 'n_a': 12, 'n_steps': 1, 'gamma': 1.4541755394727027, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.03556178358888926}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:48:03,317] Trial 44 finished with value: 0.800718586181629 and parameters: {'n_d': 24, 'n_a': 12, 'n_steps': 1, 'gamma': 1.366526271120791, 'n_shared': 2, 'n_independent': 4, 'learning_rate': 0.058962763022686375}. Best is trial 15 with value: 0.8368562129954519.
# [I 2025-04-28 22:48:27,612] Trial 45 finished with value: 0.852732840796059 and parameters: {'n_d': 28, 'n_a': 16, 'n_steps': 1, 'gamma': 1.444226100924046, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.03648732254409158}. Best is trial 45 with value: 0.852732840796059.
# [I 2025-04-28 22:49:05,577] Trial 46 finished with value: 0.819528737879368 and parameters: {'n_d': 28, 'n_a': 16, 'n_steps': 2, 'gamma': 1.2937952047676597, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.03767221604810053}. Best is trial 45 with value: 0.852732840796059.
# [I 2025-04-28 22:49:28,999] Trial 47 finished with value: 0.8381546464961099 and parameters: {'n_d': 28, 'n_a': 16, 'n_steps': 1, 'gamma': 1.4471012723659957, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.03004889822191927}. Best is trial 45 with value: 0.852732840796059.
# [I 2025-04-28 22:49:53,979] Trial 48 finished with value: 0.8615375472827068 and parameters: {'n_d': 32, 'n_a': 20, 'n_steps': 1, 'gamma': 1.4445977567574284, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.02270954564973895}. Best is trial 48 with value: 0.8615375472827068.
# [I 2025-04-28 22:50:17,387] Trial 49 finished with value: 0.8375843104225613 and parameters: {'n_d': 32, 'n_a': 20, 'n_steps': 1, 'gamma': 1.4228313916248398, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.02467115963636129}. Best is trial 48 with value: 0.8615375472827068.
# [I 2025-04-28 22:50:47,769] Trial 50 finished with value: 0.8507679764829763 and parameters: {'n_d': 32, 'n_a': 24, 'n_steps': 2, 'gamma': 1.3836219813910517, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.02241368401022797}. Best is trial 48 with value: 0.8615375472827068.
# [I 2025-04-28 22:51:16,376] Trial 51 finished with value: 0.8201648858819933 and parameters: {'n_d': 32, 'n_a': 24, 'n_steps': 2, 'gamma': 1.3731730311286496, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.018298879529385272}. Best is trial 48 with value: 0.8615375472827068.
# [I 2025-04-28 22:51:40,748] Trial 52 finished with value: 0.8406457437216843 and parameters: {'n_d': 32, 'n_a': 28, 'n_steps': 1, 'gamma': 1.4318740394125051, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.023989752173157804}. Best is trial 48 with value: 0.8615375472827068.
# [I 2025-04-28 22:52:04,320] Trial 53 finished with value: 0.8201869383655918 and parameters: {'n_d': 32, 'n_a': 28, 'n_steps': 1, 'gamma': 1.4300430197063168, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0.025832207591026342}. Best is trial 48 with value: 0.8615375472827068.
# [I 2025-04-28 22:52:42,211] Trial 54 finished with value: 0.804986458162988 and parameters: {'n_d': 32, 'n_a': 28, 'n_steps': 2, 'gamma': 1.4012042133776375, 'n_shared': 3, 'n_independent': 4, 'learning_rate': 0
. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:21:09,474] Trial 488 finished with value: 0.869141581380763 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.4715750094150561, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.02027539950046258}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:21:33,528] Trial 489 finished with value: 0.8475165231637997 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.473345743502398, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.020852783761662504}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:21:55,850] Trial 490 finished with value: 0.8593468491755172 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.467864457833487, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.025000156766730383}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:22:21,590] Trial 491 finished with value: 0.8428019483339959 and parameters: {'n_d': 32, 'n_a': 24, 'n_steps': 1, 'gamma': 1.4944338608136187, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.018253388648512503}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:22:46,109] Trial 492 finished with value: 0.8482996695961944 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.4502628890944613, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.02133304980821612}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:23:08,730] Trial 493 finished with value: 0.850173926504756 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.4742577141137105, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.0166516363271684}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:23:38,207] Trial 494 finished with value: 0.8560161454486257 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.4462394790220092, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.02464495902593723}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:23:59,128] Trial 495 finished with value: 0.8426053064279504 and parameters: {'n_d': 28, 'n_a': 20, 'n_steps': 1, 'gamma': 1.4609757521244062, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.018463123392447177}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:24:23,347] Trial 496 finished with value: 0.8473051748964483 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.2150900249720435, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.013015290771282892}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:24:48,405] Trial 497 finished with value: 0.8564823795976292 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.4843063887051666, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.015604145735273219}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:25:12,794] Trial 498 finished with value: 0.8550212787444356 and parameters: {'n_d': 28, 'n_a': 24, 'n_steps': 1, 'gamma': 1.1552095785801224, 'n_shared': 3, 'n_independent': 3, 'learning_rate': 0.00524254391669722}. Best is trial 362 with value: 0.8799682357171935.
# [I 2025-04-29 02:25:31,244] Trial 499 finished with value: 0.8417528021015498 and parameters: {'n_d': 24, 'n_a': 24, 'n_steps': 1, 'gamma': 1.024830666674894, 'n_shared': 2, 'n_independent': 3, 'learning_rate': 0.022678438030252393}. Best is trial 362 with value: 0.8799682357171935.
# raw best_params
# {'n_d': 28,
#  'n_a': 24,
#  'n_steps': 1,
#  'gamma': 1.4032711993871252,
#  'n_shared': 3,
#  'n_independent': 3,
#  'learning_rate': 0.020753028970070964}
# best_params
# {'n_d': 28,
#  'n_a': 24,
#  'n_steps': 1,
#  'gamma': 1.4032711993871252,
#  'n_shared': 3,
#  'n_independent': 3,
#  'learning_rate': 0.020753028970070964}
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "PytorchTabularEstimator"
#                                                                       0
# target                                                        splashing
# model                             TabNetModel_splashing_smote_opt-model
# holdout_test_f1_macro                                          0.755981
# holdout_test_accuracy_balanced                                 0.758102
# holdout_test_roc_auc                                           0.752315
# holdout_test_f1                                                0.821053
# holdout_test_accuracy                                          0.773333
# cv_test_f1_macro_median                                         0.82392
# cv_test_accuracy_balanced_median                               0.844427
# cv_test_roc_auc_median                                         0.912539
# cv_test_f1_median                                              0.861111
# cv_test_accuracy_median                                        0.830189
# cv_test_precision_class_0_median                                    0.8
# cv_test_recall_class_0_median                                  0.894737
# cv_test_f1_class_0_median                                      0.790698
# Model saved in ..\results\models_modelling4\TabNetModel_splashing_smote_opt-model

# %% [markdown]
# Модель переименована в: `TabNetModel_splashing_smote_500iters_opt-model`
