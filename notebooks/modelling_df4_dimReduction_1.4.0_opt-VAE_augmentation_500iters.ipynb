# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import optuna

from pathlib import Path
import sys

from typing import Type
from sklearn.base import BaseEstimator
sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
from split_tools import get_train_test

sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from modelling4_utils import (
    BetaVAEncoder,
    MLPipeline,
    OptunaOptimizer,
    deep_update,
    deep_update_dim_transformer_params,
    RANDOM_STATE,
)

seed = RANDOM_STATE

from catboost import CatBoostClassifier
from statsmodels.api import Logit

from sklearn.decomposition import PCA

from sklearn.metrics import (
    make_scorer,
    f1_score,
    mean_squared_error
)

import optuna
from functools import partial

from copy import deepcopy

# %% [markdown]
# ## Settings

# %%
model_postfix = 'vae'

scoring_metrics={
    'mse': mean_squared_error,
}
step_scoring_average = "mean"
n_trials = 500 # was 600

features_to_drop=(
    'sign_sedimentation_Re',
    'sign_sedimentation_Stk',
    'sign_particle_droplet_diameter_ratio',
)

save_model_and_metrics = False
metrics_file = "metrics_modelling4_7-dim_reduction.xlsx"

# %% [markdown]
# ## Optimization function

# %%
def optimize_vae_optuna(
    dim_transformer:Type[BaseEstimator]=BetaVAEncoder,
    dim_transformer_params:dict=None,
    target:str='splashing', # Need for SMOTE before dim reduction
    dummy_estimator:Type[BaseEstimator]=CatBoostClassifier,  # placeholder
    objective:callable=None,
    direction:str="minimize",
    n_trials:int=n_trials,
    features_to_drop:tuple=features_to_drop,
    step_scoring_average:str=step_scoring_average,
    scoring_metrics:dict=scoring_metrics,
    verbose:bool=True,
    opt_cv_folds:int=5,
    seed:int=seed,
):
    dim_transformer_params = dim_transformer_params or {}
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=dummy_estimator,
        dim_transformer=dim_transformer,
        dim_transformer_params=dim_transformer_params,
        features_to_drop=features_to_drop,
        cv_folds=opt_cv_folds,
        verbose=verbose,
        step_scoring_average=step_scoring_average,
        scoring_metrics=scoring_metrics,
    )
    
    opt = OptunaOptimizer(
        objective=partial(
            objective,
            ml_pipe=ml_pipe,
        ),
        study_name='VAE_study',
        direction=direction,
        seed=seed,
    )
    
    opt.optimize(
        n_trials=n_trials,
        catch=(ValueError,),
    )
    
    best_params = opt.study.best_params
    
    print('raw best_params')
    display(best_params)
    
    return best_params


def VAE_objective(
    trial:optuna.trial.Trial,
    ml_pipe:MLPipeline,
):
    # VAE params
    hidden_dim = 2**trial.suggest_int('log2_hidden_dim', 2, 8)
    normalization = trial.suggest_categorical('normalization', ['batch', 'layer', False])
    activation = trial.suggest_categorical('activation', ['ReLU', 'LeakyReLU', False])
    
    if activation == 'LeakyReLU':
        # negative_slope = trial.suggest_float('negative_slope', 0.01, .3, log=True)
        negative_slope = trial.suggest_float('negative_slope', 0.01, .1)
    else:
        negative_slope = None
    
    # BetaVAEncoder params
    # learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    beta_warmup_steps = trial.suggest_int('beta_warmup_steps', 100, 2000)
    # beta_start = trial.suggest_float('beta_start', 0.0, 0.5)
    # beta_end = trial.suggest_float('beta_end', 1.0, 10.0)
    beta_start = trial.suggest_float('beta_start', 0.0, 0.05)
    beta_end = trial.suggest_float('beta_end', 0.05, 0.3)
    
    suggested_transformer_params = {
        'VAE_params': {
            'hidden_dim': hidden_dim,
            'normalization': normalization,
            'activation': activation,
            'negative_slope': negative_slope,
        },
        'learning_rate': learning_rate,
        'beta_warmup_steps': beta_warmup_steps,
        'beta_start': beta_start,
        'beta_end': beta_end,
    }
    
    dim_transformer_params = deep_update_dim_transformer_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_transformer_params,
    )
    
    try:
        score = ml_pipe.step_transformer(
            dim_transformer_params=dim_transformer_params,
        )
    except ValueError as e:
        trial.set_user_attr('fail_reason', str(e))
        raise
    
    score_val = score[0]
    # score_train = score[1]
    return score_val

# %%
dim_transformer_params = {
    'VAE_params': {
            'latent_dim': 5,
        },
    'verbose': False,
    'early_stopping': True,
    'early_stopping_patience': 10,
    'max_epochs': 500,
}

raw_vae_params = optimize_vae_optuna(
    dim_transformer_params=dim_transformer_params,
    objective=VAE_objective,
)
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Re',
#  'sedimentation_Stk',
#  'particle_liquid_density_ratio',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'Re',
#  'We',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'init_volume_fraction',
#                                   'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Re', 'sedimentation_Stk',
#                                   'particle_liquid_density_ratio',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'Re', 'We', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# [I 2025-05-06 17:00:47,047] A new study created in memory with name: VAE_study
# [I 2025-05-06 17:00:56,476] Trial 0 finished with value: 0.07425060641963668 and parameters: {'log2_hidden_dim': 4, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.005399484409787433, 'beta_warmup_steps': 1242, 'beta_start': 0.03540362888980227, 'beta_end': 0.055146123573950614}. Best is trial 0 with value: 0.07425060641963668.
# [I 2025-05-06 17:01:01,537] Trial 1 finished with value: 0.09077311218668391 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': False, 'learning_rate': 0.0007309539835912913, 'beta_warmup_steps': 653, 'beta_start': 0.030592644736118974, 'beta_end': 0.08487346516301046}. Best is trial 0 with value: 0.07425060641963668.
# [I 2025-05-06 17:01:08,907] Trial 2 finished with value: 0.6976302612428328 and parameters: {'log2_hidden_dim': 4, 'normalization': False, 'activation': False, 'learning_rate': 0.0001238513729886094, 'beta_warmup_steps': 1254, 'beta_start': 0.008526206184364577, 'beta_end': 0.06626289824631988}. Best is trial 0 with value: 0.07425060641963668.
# [I 2025-05-06 17:01:11,161] Trial 3 finished with value: 0.07762958627810143 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0.020983441136030095, 'learning_rate': 0.0009780337016659412, 'beta_warmup_steps': 165, 'beta_start': 0.0454660201039391, 'beta_end': 0.11469499540000423}. Best is trial 0 with value: 0.07425060641963668.
# [I 2025-05-06 17:01:18,596] Trial 4 finished with value: 0.04034468077755213 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.09455490474077703, 'learning_rate': 0.006161049539380964, 'beta_warmup_steps': 1236, 'beta_start': 0.04609371175115584, 'beta_end': 0.07212312551297988}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:01:22,491] Trial 5 finished with value: 0.28033356518747304 and parameters: {'log2_hidden_dim': 3, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.03528410587186427, 'learning_rate': 0.001217284708112243, 'beta_warmup_steps': 367, 'beta_start': 0.04010984903770198, 'beta_end': 0.06863766091994271}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:01:24,930] Trial 6 finished with value: 0.05136250397191779 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.0034877126245459306, 'beta_warmup_steps': 240, 'beta_start': 0.017923286427213633, 'beta_end': 0.07896726488128243}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:01:36,488] Trial 7 finished with value: 0.09020042446556521 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': False, 'learning_rate': 0.0018841476921545091, 'beta_warmup_steps': 1786, 'beta_start': 0.023610746258097465, 'beta_end': 0.07989856148457543}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:01:39,425] Trial 8 finished with value: 0.6146960952119759 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.012287721406968568, 'learning_rate': 0.00016435497475111326, 'beta_warmup_steps': 159, 'beta_start': 0.03182052056318902, 'beta_end': 0.12858899526908169}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:01:43,230] Trial 9 finished with value: 0.3648392795630588 and parameters: {'log2_hidden_dim': 5, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.0003797544798678418, 'beta_warmup_steps': 406, 'beta_start': 0.04648488261712866, 'beta_end': 0.25203009489110423}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:01:55,096] Trial 10 finished with value: 0.04775628378823101 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.09596259432788043, 'learning_rate': 0.009275357267083414, 'beta_warmup_steps': 1779, 'beta_start': 0.0007797399829228002, 'beta_end': 0.1932817330486868}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:02:07,975] Trial 11 finished with value: 0.049422190497692114 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.09689149421685608, 'learning_rate': 0.008867615665213428, 'beta_warmup_steps': 1958, 'beta_start': 0.0015475168841728323, 'beta_end': 0.2048834857833998}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:02:18,604] Trial 12 finished with value: 0.05207704384462595 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.09721851209745704, 'learning_rate': 0.00870967103980756, 'beta_warmup_steps': 1603, 'beta_start': 0.012962280672248956, 'beta_end': 0.18782083052465398}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:02:25,433] Trial 13 finished with value: 0.07193514207822474 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.07067674260290614, 'learning_rate': 0.0033615388672554236, 'beta_warmup_steps': 945, 'beta_start': 0.00017200259694808502, 'beta_end': 0.2394504953892778}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:02:34,220] Trial 14 finished with value: 0.32389591935525386 and parameters: {'log2_hidden_dim': 2, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.07273307124076278, 'learning_rate': 0.004098687718690894, 'beta_warmup_steps': 1547, 'beta_start': 0.023105737920056404, 'beta_end': 0.2990042473403034}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:02:40,919] Trial 15 finished with value: 0.06757973527514827 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.0768577601022108, 'learning_rate': 0.002101878115560341, 'beta_warmup_steps': 909, 'beta_start': 0.0498628924787113, 'beta_end': 0.15139875659839858}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:02:50,052] Trial 16 finished with value: 0.05391376255620365 and parameters: {'log2_hidden_dim': 5, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.08645530353899158, 'learning_rate': 0.00993915828691159, 'beta_warmup_steps': 1368, 'beta_start': 0.008186911952357195, 'beta_end': 0.16216134888349285}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:03:02,297] Trial 17 finished with value: 0.053375723858685734 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05095895925713143, 'learning_rate': 0.005895505388559412, 'beta_warmup_steps': 1935, 'beta_start': 0.038791244302481265, 'beta_end': 0.21744273089577573}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:03:11,917] Trial 18 finished with value: 0.09713332498298358 and parameters: {'log2_hidden_dim': 4, 'normalization': 'layer', 'activation': False, 'learning_rate': 0.002395238978236527, 'beta_warmup_steps': 1612, 'beta_start': 0.016016986762895844, 'beta_end': 0.11417673474235698}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:03:16,837] Trial 19 finished with value: 0.10254910110213396 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00046639158755538886, 'beta_warmup_steps': 691, 'beta_start': 0.02774163143684069, 'beta_end': 0.13999154673909087}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:03:25,712] Trial 20 finished with value: 0.059092112571331165 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05860322177053002, 'learning_rate': 0.00626032000919533, 'beta_warmup_steps': 1427, 'beta_start': 0.0076453874448711, 'beta_end': 0.28252517053847387}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:03:39,158] Trial 21 finished with value: 0.047180145511166435 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.0992458512491101, 'learning_rate': 0.008119309552097049, 'beta_warmup_steps': 1974, 'beta_start': 0.0017776259027280496, 'beta_end': 0.19118260063278256}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:03:51,668] Trial 22 finished with value: 0.048142557502058855 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.09943510078291933, 'learning_rate': 0.00582745591812187, 'beta_warmup_steps': 1765, 'beta_start': 0.004652585475560224, 'beta_end': 0.17823564605324846}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:04:03,362] Trial 23 finished with value: 0.05560748154865044 and parameters: {'log2_hidden_dim': 6, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.08545226853571977, 'learning_rate': 0.0040313284954502865, 'beta_warmup_steps': 1802, 'beta_start': 0.012068233863355551, 'beta_end': 0.19850945689023267}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:04:16,124] Trial 24 finished with value: 0.05885576415996716 and parameters: {'log2_hidden_dim': 5, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.0865911895335052, 'learning_rate': 0.007501536968315089, 'beta_warmup_steps': 1996, 'beta_start': 0.018263597682153507, 'beta_end': 0.22393043579641744}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:04:24,857] Trial 25 finished with value: 0.060145600004398 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.08799262069848762, 'learning_rate': 0.0026668120967124776, 'beta_warmup_steps': 1193, 'beta_start': 0.003855775142978711, 'beta_end': 0.16888234730547816}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:04:32,252] Trial 26 finished with value: 0.11962348841699237 and parameters: {'log2_hidden_dim': 5, 'normalization': 'layer', 'activation': 'LeakyReLU', 'negative_slope': 0.09967189450319408, 'learning_rate': 0.0015073921280935143, 'beta_warmup_steps': 1066, 'beta_start': 0.011543586138728218, 'beta_end': 0.2558634795282372}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:04:43,036] Trial 27 finished with value: 0.04372953676844281 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05789273736552335, 'learning_rate': 0.004495233703570987, 'beta_warmup_steps': 1708, 'beta_start': 0.004601012779936964, 'beta_end': 0.10682843814552043}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:04:51,873] Trial 28 finished with value: 0.08830960935205867 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': False, 'learning_rate': 0.0044361176287002054, 'beta_warmup_steps': 1472, 'beta_start': 0.020882476866069814, 'beta_end': 0.1057292647916761}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:01,663] Trial 29 finished with value: 0.04904130108687159 and parameters: {'log2_hidden_dim': 4, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.005191719449608301, 'beta_warmup_steps': 1685, 'beta_start': 0.03417340034725125, 'beta_end': 0.052420394036433914}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:09,151] Trial 30 finished with value: 0.09130127832661707 and parameters: {'log2_hidden_dim': 4, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0027684312252191697, 'beta_warmup_steps': 1251, 'beta_start': 0.0387384087609043, 'beta_end': 0.09877651143348753}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:20,017] Trial 31 finished with value: 0.04644664159273186 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05246330741437149, 'learning_rate': 0.006766174252603928, 'beta_warmup_steps': 1865, 'beta_start': 0.004435428018308143, 'beta_end': 0.135204218139795}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:30,992] Trial 32 finished with value: 0.04415980794212494 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05061042671672362, 'learning_rate': 0.006930217860764358, 'beta_warmup_steps': 1858, 'beta_start': 0.00495558057721494, 'beta_end': 0.12857801204741615}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:41,908] Trial 33 finished with value: 0.04460818068580644 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.04864952712081475, 'learning_rate': 0.0064281678800635405, 'beta_warmup_steps': 1848, 'beta_start': 0.004878518379441413, 'beta_end': 0.12757564686279166}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:51,762] Trial 34 finished with value: 0.05127781617109019 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.04320197006713302, 'learning_rate': 0.004764249410323605, 'beta_warmup_steps': 1718, 'beta_start': 0.007310582128677474, 'beta_end': 0.09670625936962665}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:05:59,700] Trial 35 finished with value: 0.14552772982511095 and parameters: {'log2_hidden_dim': 3, 'normalization': False, 'activation': False, 'learning_rate': 0.0028943744668863134, 'beta_warmup_steps': 1482, 'beta_start': 0.010720775359031903, 'beta_end': 0.12307219282108901}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:06:07,605] Trial 36 finished with value: 0.10194406842128642 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.03610157881809631, 'learning_rate': 0.0006997541230832535, 'beta_warmup_steps': 1306, 'beta_start': 0.015087522338554642, 'beta_end': 0.06785662037243123}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:06:16,794] Trial 37 finished with value: 0.1899332307217761 and parameters: {'log2_hidden_dim': 3, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.06260116772119304, 'learning_rate': 0.0015987868538907737, 'beta_warmup_steps': 1650, 'beta_start': 0.029083228291538754, 'beta_end': 0.08487129537465884}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:06:27,234] Trial 38 finished with value: 0.09175773946143205 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': False, 'learning_rate': 0.00344790261214954, 'beta_warmup_steps': 1852, 'beta_start': 0.043032525975340366, 'beta_end': 0.1512607027010393}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:06:35,148] Trial 39 finished with value: 0.7582833791113158 and parameters: {'log2_hidden_dim': 4, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0.0425979680942401, 'learning_rate': 0.00010123622038071489, 'beta_warmup_steps': 1160, 'beta_start': 0.005854583975331578, 'beta_end': 0.11153178372024868}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:06:39,826] Trial 40 finished with value: 0.0512467488058326 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0011084245592576838, 'beta_warmup_steps': 682, 'beta_start': 0.009920592926345777, 'beta_end': 0.08923806599396425}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:06:51,048] Trial 41 finished with value: 0.04544690426535885 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05095953789204877, 'learning_rate': 0.0068810326827204015, 'beta_warmup_steps': 1860, 'beta_start': 0.004046372503669795, 'beta_end': 0.1335966878030097}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:02,094] Trial 42 finished with value: 0.04344400364189644 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.043822342291991924, 'learning_rate': 0.006649118934459839, 'beta_warmup_steps': 1854, 'beta_start': 0.003099831944632452, 'beta_end': 0.12353364348486494}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:12,019] Trial 43 finished with value: 0.044732716977439954 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.04406262287930101, 'learning_rate': 0.005216801274973875, 'beta_warmup_steps': 1704, 'beta_start': 0.0024463064246272614, 'beta_end': 0.06900698167456268}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:22,796] Trial 44 finished with value: 0.07111468142093955 and parameters: {'log2_hidden_dim': 4, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.03403956318451386, 'learning_rate': 0.007338641797985788, 'beta_warmup_steps': 1874, 'beta_start': 0.006408011067297305, 'beta_end': 0.12169136828838693}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:33,336] Trial 45 finished with value: 0.05662650191962364 and parameters: {'log2_hidden_dim': 5, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0.025977944649846454, 'learning_rate': 0.0038538108532220677, 'beta_warmup_steps': 1542, 'beta_start': 0.0144010889653742, 'beta_end': 0.0988664305580374}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:38,733] Trial 46 finished with value: 0.06617490763114689 and parameters: {'log2_hidden_dim': 4, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.06383894551026763, 'learning_rate': 0.009632604970439914, 'beta_warmup_steps': 850, 'beta_start': 0.00848597552316882, 'beta_end': 0.1548344285539321}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:50,285] Trial 47 finished with value: 0.04616932115666745 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.04622082867006865, 'learning_rate': 0.004904136463132335, 'beta_warmup_steps': 1912, 'beta_start': 0.00024865421953528064, 'beta_end': 0.14386608959833597}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:07:55,071] Trial 48 finished with value: 0.45507396541216955 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.027542370227844927, 'learning_rate': 0.00020226075593559426, 'beta_warmup_steps': 513, 'beta_start': 0.026137248807689778, 'beta_end': 0.07529425980931306}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:08:06,228] Trial 49 finished with value: 0.04550950180283497 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0.05768378757756439, 'learning_rate': 0.006007881744128164, 'beta_warmup_steps': 1560, 'beta_start': 0.03510511832307753, 'beta_end': 0.12469908607924045}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:08:16,079] Trial 50 finished with value: 0.0888261789652944 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': False, 'learning_rate': 0.003398831579019937, 'beta_warmup_steps': 1773, 'beta_start': 0.049674110110746794, 'beta_end': 0.09637226562251305}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:08:26,003] Trial 51 finished with value: 0.050417898305236755 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.039547274821635885, 'learning_rate': 0.0048393291599801, 'beta_warmup_steps': 1661, 'beta_start': 0.0028717623966555152, 'beta_end': 0.05621279391676716}. Best is trial 4 with value: 0.04034468077755213.
# [I 2025-05-06 17:08:36,053] Trial 52 finished with value: 0.03985558669776815 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.04873382963830462, 'learning_rate': 0.007923870310391332, 'beta_warmup_steps': 1715, 'beta_start': 0.002368217867101045, 'beta_end': 0.07596080229505274}. Best is trial 52 with value: 0.03985558669776815.
# [I 2025-05-06 17:08:46,137] Trial 53 finished with value: 0.04039976524778503 and parameters: {'log2_hidden_dim': 5, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.0473685095242689, 'learning_rate': 0.007686895582907938, 'beta_warmup_steps': 1763, 'beta_start': 0.005731836439135545, 'beta_end': 0.08377380718202125}. Best is trial 52 with value: 0.03985558669776815.
# [I 2025-05-06 17:08:54,403] Trial 54 finished with value: 0.03836117528421967 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05575436177214538, 'learning_rate': 0.008087595213132301, 'beta_warmup_steps': 1335, 'beta_start': 0.009952631744116591, 'beta_end': 0.06025301711451015}. Best is trial 54 with value: 0.03836117528421967.
# [I 2025-05-06 17:09:02,865] Trial 55 finished with value: 0.03833008174629288 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.06479910451220773, 'learning_rate': 0.008320016094366528, 'beta_warmup_steps': 1384, 'beta_start': 0.009508003003798591, 'beta_end': 0.05734006734281715}. Best is trial 55 with value: 0.03833008174629288.
# [I 2025-05-06 17:09:11,063] Trial 56 finished with value: 0.03430959195297253 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.06611096768364326, 'learning_rate': 0.009800126043934333, 'beta_warmup_steps': 1361, 'beta_start': 0.009416592927317852, 'beta_end': 0.05917359418183535}. Best is trial 56 with value: 0.03430959195297253.
# [I 2025-05-06 17:09:19,227] Trial 57 finished with value: 0.03580246897116702 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008432527036819768, 'beta_warmup_steps': 1348, 'beta_start': 0.018745757422280893, 'beta_end': 0.0565681692371857}. Best is trial 56 with value: 0.03430959195297253.
# [I 2025-05-06 17:09:25,996] Trial 58 finished with value: 0.02866911032185009 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009859649207298147, 'beta_warmup_steps': 1060, 'beta_start': 0.02089774281468167, 'beta_end': 0.06072491848147335}. Best is trial 58 with value: 0.02866911032185009.
# [I 2025-05-06 17:09:34,753] Trial 59 finished with value: 0.03024181261232798 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008899190838437007, 'beta_warmup_steps': 1340, 'beta_start': 0.01871327370095709, 'beta_end': 0.059542924372182025}. Best is trial 58 with value: 0.02866911032185009.
# [I 2025-05-06 17:09:44,927] Trial 60 finished with value: 0.04189564966534355 and parameters: {'log2_hidden_dim': 7, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.009814305421185231, 'beta_warmup_steps': 1376, 'beta_start': 0.019180109515001084, 'beta_end': 0.058469627722005}. Best is trial 58 with value: 0.02866911032185009.
# [I 2025-05-06 17:09:53,635] Trial 61 finished with value: 0.02724172485868463 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008258946940873995, 'beta_warmup_steps': 1079, 'beta_start': 0.021415319028081196, 'beta_end': 0.061786997679462274}. Best is trial 61 with value: 0.02724172485868463.
# [I 2025-05-06 17:10:01,868] Trial 62 finished with value: 0.031023194488121596 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008929899669007684, 'beta_warmup_steps': 1302, 'beta_start': 0.020785383069121748, 'beta_end': 0.06276172587575388}. Best is trial 61 with value: 0.02724172485868463.
# [I 2025-05-06 17:10:08,895] Trial 63 finished with value: 0.027822961214696722 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009962865631994314, 'beta_warmup_steps': 1096, 'beta_start': 0.022721704255966382, 'beta_end': 0.06253774991865704}. Best is trial 61 with value: 0.02724172485868463.
# [I 2025-05-06 17:10:15,841] Trial 64 finished with value: 0.027249865010213637 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009078635327448525, 'beta_warmup_steps': 1084, 'beta_start': 0.022529618937993552, 'beta_end': 0.06461059097320034}. Best is trial 61 with value: 0.02724172485868463.
# [I 2025-05-06 17:10:22,874] Trial 65 finished with value: 0.026888914872898812 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00979236292838015, 'beta_warmup_steps': 1066, 'beta_start': 0.022958846382381444, 'beta_end': 0.06393432643662066}. Best is trial 65 with value: 0.026888914872898812.
# [I 2025-05-06 17:10:29,875] Trial 66 finished with value: 0.028747068235021246 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00994904565702778, 'beta_warmup_steps': 1066, 'beta_start': 0.02290688505771762, 'beta_end': 0.06679661463615717}. Best is trial 65 with value: 0.026888914872898812.
# [I 2025-05-06 17:10:36,549] Trial 67 finished with value: 0.03179897378963444 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.005679564314209575, 'beta_warmup_steps': 1052, 'beta_start': 0.023488373158304092, 'beta_end': 0.07155705522973849}. Best is trial 65 with value: 0.026888914872898812.
# [I 2025-05-06 17:10:42,957] Trial 68 finished with value: 0.026434795464708456 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00969427996374244, 'beta_warmup_steps': 988, 'beta_start': 0.022117170599905405, 'beta_end': 0.050422265024403654}. Best is trial 68 with value: 0.026434795464708456.
# [I 2025-05-06 17:10:49,311] Trial 69 finished with value: 0.033135351930229526 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009990547439857972, 'beta_warmup_steps': 972, 'beta_start': 0.025701004187344105, 'beta_end': 0.0808411328462126}. Best is trial 68 with value: 0.026434795464708456.
# [I 2025-05-06 17:10:54,462] Trial 70 finished with value: 0.050154884585605776 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0008128565285986834, 'beta_warmup_steps': 777, 'beta_start': 0.021197328670598325, 'beta_end': 0.051942888460599496}. Best is trial 68 with value: 0.026434795464708456.
# [I 2025-05-06 17:11:01,862] Trial 71 finished with value: 0.02900753044529005 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008583273857282948, 'beta_warmup_steps': 1129, 'beta_start': 0.024416461902975133, 'beta_end': 0.06687712971201445}. Best is trial 68 with value: 0.026434795464708456.
# [I 2025-05-06 17:11:09,493] Trial 72 finished with value: 0.031882750867268744 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007346241536537918, 'beta_warmup_steps': 1132, 'beta_start': 0.02208157065213588, 'beta_end': 0.09010350316175107}. Best is trial 68 with value: 0.026434795464708456.
# [I 2025-05-06 17:11:16,147] Trial 73 finished with value: 0.03308176921312828 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0058169649954306355, 'beta_warmup_steps': 988, 'beta_start': 0.024771958345169896, 'beta_end': 0.06752158784614282}. Best is trial 68 with value: 0.026434795464708456.
# [I 2025-05-06 17:11:23,026] Trial 74 finished with value: 0.025638006172391908 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008501667470994602, 'beta_warmup_steps': 1101, 'beta_start': 0.03134839471407477, 'beta_end': 0.05112778523627416}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:11:28,702] Trial 75 finished with value: 0.028975923039914187 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007110225760335439, 'beta_warmup_steps': 873, 'beta_start': 0.027127625888664852, 'beta_end': 0.07760711400592046}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:11:35,182] Trial 76 finished with value: 0.027593457930861938 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006472541989060826, 'beta_warmup_steps': 1014, 'beta_start': 0.030170015721444978, 'beta_end': 0.05268417045323953}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:11:42,614] Trial 77 finished with value: 0.030125891623246758 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006227942058410134, 'beta_warmup_steps': 1206, 'beta_start': 0.03184719487546892, 'beta_end': 0.05095086217456682}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:11:48,840] Trial 78 finished with value: 0.029837706680920777 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007741557789541772, 'beta_warmup_steps': 924, 'beta_start': 0.02982997672454055, 'beta_end': 0.07400611139525462}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:11:56,226] Trial 79 finished with value: 0.08673467878869676 and parameters: {'log2_hidden_dim': 7, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.0002953036283896378, 'beta_warmup_steps': 1007, 'beta_start': 0.03200850928669682, 'beta_end': 0.051329104510575395}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:03,810] Trial 80 finished with value: 0.03341371099461989 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.005487248827339863, 'beta_warmup_steps': 1102, 'beta_start': 0.01686079545866627, 'beta_end': 0.0897292404650579}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:10,422] Trial 81 finished with value: 0.027980635998332094 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008985487320313084, 'beta_warmup_steps': 1021, 'beta_start': 0.022286447744848777, 'beta_end': 0.06543984189657523}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:15,740] Trial 82 finished with value: 0.027537508732659605 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00869630786192641, 'beta_warmup_steps': 804, 'beta_start': 0.027985580948738424, 'beta_end': 0.06252941410505405}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:20,898] Trial 83 finished with value: 0.027663986492746852 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006621788650052439, 'beta_warmup_steps': 792, 'beta_start': 0.02884950319369752, 'beta_end': 0.05034372751472981}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:26,346] Trial 84 finished with value: 0.030509805144994073 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.004177851266554227, 'beta_warmup_steps': 803, 'beta_start': 0.02776942939418139, 'beta_end': 0.07291734817106847}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:30,358] Trial 85 finished with value: 0.03037416306146759 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0064344472976667405, 'beta_warmup_steps': 564, 'beta_start': 0.0329882898615371, 'beta_end': 0.05193153580668464}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:35,350] Trial 86 finished with value: 0.033162648169618246 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007262135386421372, 'beta_warmup_steps': 737, 'beta_start': 0.028294455623178085, 'beta_end': 0.0815078942614591}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:41,308] Trial 87 finished with value: 0.028136389442149197 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008229082780008662, 'beta_warmup_steps': 904, 'beta_start': 0.03731909769953452, 'beta_end': 0.06353873877680005}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:47,240] Trial 88 finished with value: 0.03491607506361912 and parameters: {'log2_hidden_dim': 8, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.005199637781927677, 'beta_warmup_steps': 838, 'beta_start': 0.030070585081954558, 'beta_end': 0.05026835784326513}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:51,208] Trial 89 finished with value: 0.28362648084743985 and parameters: {'log2_hidden_dim': 2, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0065481662078344365, 'beta_warmup_steps': 606, 'beta_start': 0.026510614105979338, 'beta_end': 0.07194015836020973}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:12:58,317] Trial 90 finished with value: 0.06875588258623715 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0005159413067616283, 'beta_warmup_steps': 1196, 'beta_start': 0.029054505878569087, 'beta_end': 0.07999881787634525}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:04,927] Trial 91 finished with value: 0.028342403716101017 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008804468890975433, 'beta_warmup_steps': 1012, 'beta_start': 0.022366339420618244, 'beta_end': 0.0665780239340798}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:13,169] Trial 92 finished with value: 0.03193739613131968 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00889465995329453, 'beta_warmup_steps': 1260, 'beta_start': 0.024937384267973747, 'beta_end': 0.06543711088576809}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:20,062] Trial 93 finished with value: 0.02854536182542281 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007667136068800896, 'beta_warmup_steps': 1026, 'beta_start': 0.019608276123217916, 'beta_end': 0.06367233261348024}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:26,227] Trial 94 finished with value: 0.028149400708412858 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006745496496443783, 'beta_warmup_steps': 947, 'beta_start': 0.024061635252636555, 'beta_end': 0.05570867984500327}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:33,428] Trial 95 finished with value: 0.03280342733520237 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008938190887534989, 'beta_warmup_steps': 1089, 'beta_start': 0.01713057636286084, 'beta_end': 0.09215998761929389}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:40,822] Trial 96 finished with value: 0.03313466115815226 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007626003394161827, 'beta_warmup_steps': 1166, 'beta_start': 0.03090592015342139, 'beta_end': 0.08507823437488651}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:46,304] Trial 97 finished with value: 0.033908402924308634 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.005897426504270087, 'beta_warmup_steps': 891, 'beta_start': 0.025769037915322503, 'beta_end': 0.0714600808401866}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:51,194] Trial 98 finished with value: 0.08545172144340452 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': False, 'learning_rate': 0.007182130037661514, 'beta_warmup_steps': 735, 'beta_start': 0.033572213758258605, 'beta_end': 0.055528212701704605}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:13:58,593] Trial 99 finished with value: 0.042304451587596874 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.008278144491152165, 'beta_warmup_steps': 961, 'beta_start': 0.019852759440165898, 'beta_end': 0.10437353312759717}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:05,599] Trial 100 finished with value: 0.03439655237271127 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0045818852575871165, 'beta_warmup_steps': 1150, 'beta_start': 0.022297817256344842, 'beta_end': 0.06279807411609478}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:11,697] Trial 101 finished with value: 0.028504521176121022 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008873431573598644, 'beta_warmup_steps': 922, 'beta_start': 0.03696233207290227, 'beta_end': 0.060760696223048055}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:17,192] Trial 102 finished with value: 0.02764975342708497 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008148179223251999, 'beta_warmup_steps': 821, 'beta_start': 0.035895000772025544, 'beta_end': 0.05586519331395935}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:22,674] Trial 103 finished with value: 0.030662432580594996 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009175392423376812, 'beta_warmup_steps': 826, 'beta_start': 0.02846840639843917, 'beta_end': 0.07749146041875}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:29,630] Trial 104 finished with value: 0.02957008890574823 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006520959870129443, 'beta_warmup_steps': 1104, 'beta_start': 0.02696832211256859, 'beta_end': 0.050000139927024914}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:34,973] Trial 105 finished with value: 0.027999057928401634 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007950373272121069, 'beta_warmup_steps': 764, 'beta_start': 0.041794869692364345, 'beta_end': 0.055861035615377}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:42,733] Trial 106 finished with value: 0.03608173243251017 and parameters: {'log2_hidden_dim': 8, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.005468511432104812, 'beta_warmup_steps': 1029, 'beta_start': 0.03570751766877648, 'beta_end': 0.07117872645964697}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:50,492] Trial 107 finished with value: 0.027026821950369262 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00700074243087924, 'beta_warmup_steps': 1226, 'beta_start': 0.021313142820035304, 'beta_end': 0.059430716702016814}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:14:57,820] Trial 108 finished with value: 0.03846243316411804 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0019774785928692988, 'beta_warmup_steps': 1244, 'beta_start': 0.02356751954736966, 'beta_end': 0.05686841540487354}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:05,864] Trial 109 finished with value: 0.04453428405221267 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007095744373114749, 'beta_warmup_steps': 1196, 'beta_start': 0.030803143373591028, 'beta_end': 0.21291227403255214}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:10,839] Trial 110 finished with value: 0.1014359540308144 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': False, 'learning_rate': 0.006093559945983012, 'beta_warmup_steps': 667, 'beta_start': 0.021366228729767654, 'beta_end': 0.2832731911871743}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:17,415] Trial 111 finished with value: 0.030983216574584783 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009168282271043014, 'beta_warmup_steps': 985, 'beta_start': 0.02530573981550588, 'beta_end': 0.06304982997031458}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:23,336] Trial 112 finished with value: 0.030102207555966688 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00814797046578686, 'beta_warmup_steps': 868, 'beta_start': 0.02049531992569147, 'beta_end': 0.06685377639060187}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:30,339] Trial 113 finished with value: 0.026973291493848344 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009911551741407083, 'beta_warmup_steps': 1102, 'beta_start': 0.01794147366910461, 'beta_end': 0.0551028249849148}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:32,655] Trial 114 finished with value: 0.03617396478851865 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009789410190487336, 'beta_warmup_steps': 117, 'beta_start': 0.016327896442958373, 'beta_end': 0.05519891092417176}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:39,977] Trial 115 finished with value: 0.026259557681520683 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006998015372958182, 'beta_warmup_steps': 1114, 'beta_start': 0.017278238719991935, 'beta_end': 0.050118246244962514}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:47,539] Trial 116 finished with value: 0.030324194016342166 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.005157570358022938, 'beta_warmup_steps': 1130, 'beta_start': 0.014400711592955681, 'beta_end': 0.05013554957512706}. Best is trial 74 with value: 0.025638006172391908.
# [I 2025-05-06 17:15:55,865] Trial 117 finished with value: 0.024491751169369858 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006908652157076926, 'beta_warmup_steps': 1302, 'beta_start': 0.01730647671807797, 'beta_end': 0.058547985250044204}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:05,201] Trial 118 finished with value: 0.05488587715223785 and parameters: {'log2_hidden_dim': 7, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.007522428264276254, 'beta_warmup_steps': 1236, 'beta_start': 0.017492543758070828, 'beta_end': 0.24081809853561953}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:13,455] Trial 119 finished with value: 0.04583202862724879 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0038011826236127237, 'beta_warmup_steps': 1294, 'beta_start': 0.018328868895696362, 'beta_end': 0.17719745746664387}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:16,162] Trial 120 finished with value: 0.036713625137592645 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.003064083631286625, 'beta_warmup_steps': 291, 'beta_start': 0.013231734454869483, 'beta_end': 0.05971151971553613}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:24,975] Trial 121 finished with value: 0.027083006767657736 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006856955439301011, 'beta_warmup_steps': 1417, 'beta_start': 0.015069946137740974, 'beta_end': 0.05486572569425291}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:34,162] Trial 122 finished with value: 0.029074462101720395 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008232840886255179, 'beta_warmup_steps': 1471, 'beta_start': 0.015277652744517322, 'beta_end': 0.07475056470774868}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:43,064] Trial 123 finished with value: 0.027661998371530515 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006015579180898703, 'beta_warmup_steps': 1424, 'beta_start': 0.015672614250055797, 'beta_end': 0.05638035319747066}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:50,688] Trial 124 finished with value: 0.030412111178564044 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007017236904822744, 'beta_warmup_steps': 1212, 'beta_start': 0.013799956523200882, 'beta_end': 0.05921681470742618}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:16:58,929] Trial 125 finished with value: 0.030986928591896463 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007588788923924564, 'beta_warmup_steps': 1268, 'beta_start': 0.011618638120700533, 'beta_end': 0.06867043536440216}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:17:05,641] Trial 126 finished with value: 0.03999106492443391 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0015085236187256422, 'beta_warmup_steps': 1064, 'beta_start': 0.017963228289146753, 'beta_end': 0.05427123513153528}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:17:15,384] Trial 127 finished with value: 0.03504459005182489 and parameters: {'log2_hidden_dim': 7, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.009999250140390544, 'beta_warmup_steps': 1413, 'beta_start': 0.020166713282763357, 'beta_end': 0.07006952629484854}. Best is trial 117 with value: 0.024491751169369858.
# [I 2025-05-06 17:17:22,864] Trial 128 finished with value: 0.03369751405414985 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008218680164273373, 'beta_warmup_steps': 1167, 'beta_start': 0.021517460393103767, 'beta_end': 0.08520826186502492}. Best is trial 117 with value: 0.024491751169369858.
# ...
# [I 2025-05-06 17:56:29,965] Trial 456 finished with value: 0.03329422547190423 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008154315102050324, 'beta_warmup_steps': 1302, 'beta_start': 0.011951704182977908, 'beta_end': 0.061862550955051776}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:56:36,523] Trial 457 finished with value: 0.02946241149767072 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.022050121397616224, 'learning_rate': 0.007215865109359806, 'beta_warmup_steps': 1048, 'beta_start': 0.026633281826259684, 'beta_end': 0.07184111466429839}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:56:42,797] Trial 458 finished with value: 0.03151803384676885 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009092692165112382, 'beta_warmup_steps': 941, 'beta_start': 0.026060014822395096, 'beta_end': 0.0574242667384958}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:56:50,691] Trial 459 finished with value: 0.038362452043397284 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': 'ReLU', 'learning_rate': 0.007870305061901955, 'beta_warmup_steps': 1080, 'beta_start': 0.024309096607158492, 'beta_end': 0.05021183296367919}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:56:57,761] Trial 460 finished with value: 0.0473740194290797 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00854088543886507, 'beta_warmup_steps': 1008, 'beta_start': 0.026788439510091338, 'beta_end': 0.24107732884936464}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:05,025] Trial 461 finished with value: 0.03273144773005603 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0067601547101924205, 'beta_warmup_steps': 1124, 'beta_start': 0.02547216445995197, 'beta_end': 0.06457376366444614}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:14,161] Trial 462 finished with value: 0.029296664280721734 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009249458343165816, 'beta_warmup_steps': 1395, 'beta_start': 0.020280172772657278, 'beta_end': 0.05526525828276834}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:22,392] Trial 463 finished with value: 0.08532138932022393 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': False, 'learning_rate': 0.007613274577520011, 'beta_warmup_steps': 1353, 'beta_start': 0.0237201058832867, 'beta_end': 0.05009203401875095}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:29,399] Trial 464 finished with value: 0.026751849270621825 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008452469361076832, 'beta_warmup_steps': 1065, 'beta_start': 0.027223836051011568, 'beta_end': 0.05987546406436779}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:36,441] Trial 465 finished with value: 0.025147400881231068 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009250487553906707, 'beta_warmup_steps': 1123, 'beta_start': 0.026428726670181014, 'beta_end': 0.055454969254072006}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:43,698] Trial 466 finished with value: 0.02798084704534895 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009987049055439968, 'beta_warmup_steps': 1137, 'beta_start': 0.02504920035573022, 'beta_end': 0.07654662639042487}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:52,374] Trial 467 finished with value: 0.0329007089741934 and parameters: {'log2_hidden_dim': 8, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.0053444432341286825, 'beta_warmup_steps': 1281, 'beta_start': 0.025828339426883097, 'beta_end': 0.0676428698791969}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:57:56,952] Trial 468 finished with value: 0.06393245074259311 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0007613046522816972, 'beta_warmup_steps': 592, 'beta_start': 0.026369123845857774, 'beta_end': 0.06261472453587386}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:04,901] Trial 469 finished with value: 0.026341091589514774 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009258082959076113, 'beta_warmup_steps': 1200, 'beta_start': 0.023224995886712334, 'beta_end': 0.05809631107224814}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:11,170] Trial 470 finished with value: 0.07606148640759021 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.06764734272700869, 'learning_rate': 0.00019314581833026158, 'beta_warmup_steps': 979, 'beta_start': 0.024603473679282006, 'beta_end': 0.0550569102908664}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:17,961] Trial 471 finished with value: 0.03576030334819561 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007920423713950945, 'beta_warmup_steps': 1049, 'beta_start': 0.02201135440852277, 'beta_end': 0.11803283209952727}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:24,730] Trial 472 finished with value: 0.026407057333134885 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008555615266265866, 'beta_warmup_steps': 1029, 'beta_start': 0.02585186944254573, 'beta_end': 0.060757246523468984}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:31,739] Trial 473 finished with value: 0.026327247345184483 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009250366360788647, 'beta_warmup_steps': 1097, 'beta_start': 0.027000763134677277, 'beta_end': 0.067436884281056}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:38,973] Trial 474 finished with value: 0.024902902294085285 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007374237848000701, 'beta_warmup_steps': 1141, 'beta_start': 0.025231756142718043, 'beta_end': 0.05491170452053312}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:46,028] Trial 475 finished with value: 0.03215673448346413 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006020759866376785, 'beta_warmup_steps': 1140, 'beta_start': 0.024970879620416504, 'beta_end': 0.05499940419530335}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:58:53,708] Trial 476 finished with value: 0.02766263009590051 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0067123467437457725, 'beta_warmup_steps': 1174, 'beta_start': 0.023768152273629887, 'beta_end': 0.055018865543645906}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:00,985] Trial 477 finished with value: 0.035146750265960335 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.0018462608446455438, 'beta_warmup_steps': 1123, 'beta_start': 0.014090890465648117, 'beta_end': 0.05410987723375334}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:08,279] Trial 478 finished with value: 0.026329593350735165 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007121798519335334, 'beta_warmup_steps': 1106, 'beta_start': 0.024293421313333487, 'beta_end': 0.05004188559018038}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:15,717] Trial 479 finished with value: 0.02871559047490226 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00744994851306758, 'beta_warmup_steps': 1188, 'beta_start': 0.019164218990995296, 'beta_end': 0.05871007209270492}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:22,384] Trial 480 finished with value: 0.029584222407336262 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006616217828204898, 'beta_warmup_steps': 1070, 'beta_start': 0.025291709042899152, 'beta_end': 0.05770321963711289}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:29,941] Trial 481 finished with value: 0.04748824484727033 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007904482811419773, 'beta_warmup_steps': 1150, 'beta_start': 0.026056249032710116, 'beta_end': 0.2749325671109213}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:38,839] Trial 482 finished with value: 0.040788023694231665 and parameters: {'log2_hidden_dim': 8, 'normalization': 'batch', 'activation': 'LeakyReLU', 'negative_slope': 0.07387470228489962, 'learning_rate': 0.007659372636698075, 'beta_warmup_steps': 1231, 'beta_start': 0.022884656446002703, 'beta_end': 0.05454763379831243}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:45,582] Trial 483 finished with value: 0.026471114591430978 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009986805710463996, 'beta_warmup_steps': 1012, 'beta_start': 0.024835516662848108, 'beta_end': 0.0601307274140257}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:52,721] Trial 484 finished with value: 0.02615807258348805 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008069202836021286, 'beta_warmup_steps': 1074, 'beta_start': 0.026888739442402686, 'beta_end': 0.05460523673871099}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 17:59:58,907] Trial 485 finished with value: 0.03059475305606347 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.004637437610752287, 'beta_warmup_steps': 958, 'beta_start': 0.026102905546031424, 'beta_end': 0.050239562366551895}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:05,499] Trial 486 finished with value: 0.08561736654669042 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': False, 'learning_rate': 0.007079184909444963, 'beta_warmup_steps': 1110, 'beta_start': 0.023981664733104837, 'beta_end': 0.06242342821886137}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:12,922] Trial 487 finished with value: 0.030013197317354322 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008618183612207671, 'beta_warmup_steps': 1147, 'beta_start': 0.02532798554700509, 'beta_end': 0.05000201597163075}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:19,614] Trial 488 finished with value: 0.030302931045497757 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.005908204502009219, 'beta_warmup_steps': 1042, 'beta_start': 0.027131324649976103, 'beta_end': 0.05836557323055298}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:31,332] Trial 489 finished with value: 0.027190476160332166 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009097007920228242, 'beta_warmup_steps': 1977, 'beta_start': 0.023166404746443266, 'beta_end': 0.05003440432818626}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:38,815] Trial 490 finished with value: 0.03230597804834201 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008214349033959279, 'beta_warmup_steps': 1188, 'beta_start': 0.026000620126826555, 'beta_end': 0.0655033132184833}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:46,713] Trial 491 finished with value: 0.04535683505103129 and parameters: {'log2_hidden_dim': 8, 'normalization': 'layer', 'activation': 'ReLU', 'learning_rate': 0.007316063706798128, 'beta_warmup_steps': 1104, 'beta_start': 0.024179669887345604, 'beta_end': 0.20841260561845437}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:52,829] Trial 492 finished with value: 0.029244111097499848 and parameters: {'log2_hidden_dim': 7, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009266796865897617, 'beta_warmup_steps': 998, 'beta_start': 0.02653605618464801, 'beta_end': 0.054458931610152805}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:00:59,831] Trial 493 finished with value: 0.03625831923574725 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.008363970620546734, 'beta_warmup_steps': 1079, 'beta_start': 0.025234957517623547, 'beta_end': 0.1556500737218849}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:01:05,839] Trial 494 finished with value: 0.031023357517741934 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.006652141097719469, 'beta_warmup_steps': 899, 'beta_start': 0.02762259933264464, 'beta_end': 0.05843245553085302}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:01:13,207] Trial 495 finished with value: 0.027426391758706554 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'LeakyReLU', 'negative_slope': 0.05311579177422949, 'learning_rate': 0.009985747344742075, 'beta_warmup_steps': 1146, 'beta_start': 0.021089983006610708, 'beta_end': 0.05481258147860049}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:01:19,753] Trial 496 finished with value: 0.03139419080460222 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007628287629832287, 'beta_warmup_steps': 1030, 'beta_start': 0.03246617134524202, 'beta_end': 0.06212952961259023}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:01:26,811] Trial 497 finished with value: 0.04748903572263274 and parameters: {'log2_hidden_dim': 4, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.00852434517464544, 'beta_warmup_steps': 1216, 'beta_start': 0.02233121399377143, 'beta_end': 0.07242441455868687}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:01:32,555] Trial 498 finished with value: 0.034171770695023154 and parameters: {'log2_hidden_dim': 6, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.009203849605153287, 'beta_warmup_steps': 938, 'beta_start': 0.027549367415347567, 'beta_end': 0.058270616466072706}. Best is trial 394 with value: 0.024453199332001022.
# [I 2025-05-06 18:01:38,846] Trial 499 finished with value: 0.0273610520075079 and parameters: {'log2_hidden_dim': 8, 'normalization': False, 'activation': 'ReLU', 'learning_rate': 0.007888883913035626, 'beta_warmup_steps': 981, 'beta_start': 0.024759526537858498, 'beta_end': 0.05444514398856313}. Best is trial 394 with value: 0.024453199332001022.
# raw best_params
# {'log2_hidden_dim': 8,
#  'normalization': False,
#  'activation': 'ReLU',
#  'learning_rate': 0.007952374827667351,
#  'beta_warmup_steps': 1146,
#  'beta_start': 0.027556365112939633,
#  'beta_end': 0.050027291572060005}

# %%
def get_vae_params(
    raw_vae_params:dict,
):
    hidden_dim = 2**raw_vae_params['log2_hidden_dim']
    suggested_transformer_params = {
        'VAE_params': {
            'hidden_dim': hidden_dim,
            'normalization': raw_vae_params['normalization'],
            'activation': raw_vae_params['activation'],
        },
        'learning_rate':    raw_vae_params['learning_rate'],
        'beta_warmup_steps': raw_vae_params['beta_warmup_steps'],
        'beta_start':       raw_vae_params['beta_start'],
        'beta_end':         raw_vae_params['beta_end'],
    }
    
    if 'negative_slope' in raw_vae_params:
        suggested_transformer_params['VAE_params']['negative_slope'] = (
            raw_vae_params['negative_slope']
        )
    
    return suggested_transformer_params
    
suggested_transformer_params = get_vae_params(
    raw_vae_params=raw_vae_params
)

dim_transformer_params = deepcopy(dim_transformer_params)

deep_update(
    original=dim_transformer_params,
    updates=suggested_transformer_params,
)
dim_transformer_params['verbose'] = True
display(dim_transformer_params)
# Out:
# {'VAE_params': {'latent_dim': 5,
#   'hidden_dim': 256,
#   'normalization': False,
#   'activation': 'ReLU'},
#  'verbose': True,
#  'early_stopping': True,
#  'early_stopping_patience': 10,
#  'max_epochs': 500,
#  'learning_rate': 0.007952374827667351,
#  'beta_warmup_steps': 1146,
#  'beta_start': 0.027556365112939633,
#  'beta_end': 0.050027291572060005}

# %%
dim_transformer_params['verbose'] = True
# To simplify data extraction, initialize ml_pipe
target = 'splashing'

ml_pipe = MLPipeline(
    target=target,
    estimator=CatBoostClassifier,
    estimator_params={'verbose': False,},
    # dim_transformer=PCA,
    # dim_transformer_params={'n_components': 6},
    dim_transformer=BetaVAEncoder,
    dim_transformer_params=dim_transformer_params,
    features_to_drop=features_to_drop,
    model_postfix=model_postfix,
    verbose=True,
)

# X_train = ml_pipe.train.drop(columns=[target])
# X_test = ml_pipe.test.drop(columns=[target])
# display(X_train.info())
# display(X_test.info())

ml_pipe.run(
    save_model_and_metrics=False,
    cv_verbose=False,
)
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Re',
#  'sedimentation_Stk',
#  'particle_liquid_density_ratio',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'Re',
#  'We',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'init_volume_fraction',
#                                   'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Re', 'sedimentation_Stk',
#                                   'particle_liquid_density_ratio',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'Re', 'We', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# [CV] END .................................................... total time=   2.3s
# [CV] END .................................................... total time=   2.0s
# [CV] END .................................................... total time=   2.2s
# [CV] END .................................................... total time=   2.0s
# [CV] END .................................................... total time=   2.1s
# [CV] END .................................................... total time=   2.1s
# [CV] END .................................................... total time=   2.1s
# VAE_params: {'latent_dim': 5, 'hidden_dim': 256, 'normalization': False, 'activation': 'ReLU', 'input_dim': 12, 'verbose': True}
# Encoder: Sequential(
#   (0): Linear(in_features=12, out_features=256, bias=True)
#   (1): ReLU(inplace=True)
# )
# Latent space:
# 	Mu: Linear(in_features=256, out_features=5, bias=True)
# 	log_sigma2: Linear(in_features=256, out_features=5, bias=True)
# Decoder: Sequential(
#   (0): Linear(in_features=5, out_features=256, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Linear(in_features=256, out_features=12, bias=True)
# )
# Epochs:   0%|          | 0/500 [00:00<?, ?it/s]
# Early stopping at epoch 115.
# no summary in estimator class "CatBoostClassifier"
#                                                                        0
# target                                                         splashing
# model                             CatBoostClassifier_splashing_smote_vae
# holdout_test_f1_macro                                               0.85
# holdout_test_accuracy_balanced                                   0.83912
# holdout_test_roc_auc                                            0.937886
# holdout_test_f1                                                      0.9
# holdout_test_accuracy                                           0.866667
# cv_test_f1_macro_median                                          0.87381
# cv_test_accuracy_balanced_median                                0.885449
# cv_test_roc_auc_median                                          0.928571
# cv_test_f1_median                                                0.90625
# cv_test_accuracy_median                                         0.886792
# cv_test_precision_class_0_median                                0.809524
# cv_test_recall_class_0_median                                   0.894737
# cv_test_f1_class_0_median                                       0.837209

# %% [markdown]
# Total Loss increases because beta increases!
