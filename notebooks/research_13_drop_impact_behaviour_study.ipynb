# %% [markdown]
# This notebook is used to get the Experiment results for the dropclass-publication.
# It proceeds work from `research_9.0_labels_dependencies.ipynb`

# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Import Libs

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, AutoMinorLocator
import seaborn as sns

import pickle

sns.set_style('darkgrid')

from catboost import CatBoostClassifier

from sklearn.preprocessing import PolynomialFeatures

from statannotations.Annotator import Annotator

from scipy.stats import shapiro, chi2_contingency

# %% [markdown]
# Prepare impact types

# %%
splash_impact_type_dt = {
    'impact_type': ['no splashing', 'splashing', 'semi splashing',],
    'value': [0, 2, 1,],
    'color': ['b', 'r', 'g',],
    'marker': ['x', 'o', 's',],
    'order': [0, 2, 1,] # legend order
}

splash_impact_type_df = pd.DataFrame(splash_impact_type_dt)
display(splash_impact_type_df)

no_fragmentation_type_dt = {
    'impact_type': ['fragmentation', 'no fragmentation'],
    'value': [0, 1],
    'color': ['r', 'b'],
    'marker': ['x', 'o'],
    'order': [0, 1] # legend order
}

no_fragmentation_type_df = pd.DataFrame(no_fragmentation_type_dt)
no_fragmentation_type_df
# Out:
#       impact_type  value color marker  order
# 0    no splashing      0     b      x      0
# 1       splashing      2     r      o      2
# 2  semi splashing      1     g      s      1
#         impact_type  value color marker  order
# 0     fragmentation      0     r      x      0
# 1  no fragmentation      1     b      o      1

# %%
# import new main notebook
df_main = pd.read_excel('../data/df_main.xlsx')
display(df_main.head())
df_main.info()
# Out:
#    test  no_fragmentation  splashing  splashing_spectrum  breaking_up  \
# 0     3                 0          1                   2            0
# 1     4                 0          1                   2            0
# 2     5                 0          1                   2            0
# 3     7                 0          1                   2            0
# 4     8                 0          1                   2            0
#
#    rebound  one_drop  voltage  long_impulse_duration long_impulse_dur_binary  \
# 0        0         1    105.0                     10                     low
# 1        0         1    105.0                     10                     low
# 2        0         1    105.0                     10                     low
# 3        0         0    105.0                     10                     low
# 4        0         0    105.0                     10                     low
#
#    ... sedimentation_velocity  sedimentation_Re  sedimentation_Stk  \
# 0  ...               0.000018          0.000092       8.252778e-08
# 1  ...               0.000018          0.000092       8.252778e-08
# 2  ...               0.000018          0.000092       8.252778e-08
# 3  ...               0.000018          0.000092       8.582889e-08
# 4  ...               0.000018          0.000092       8.582889e-08
#
#    sign_sedimentation_Re  sign_sedimentation_Stk  \
# 0               0.000092            8.252778e-08
# 1               0.000092            8.252778e-08
# 2               0.000092            8.252778e-08
# 3               0.000092            8.582889e-08
# 4               0.000092            8.582889e-08
#
#    sign_particle_droplet_diameter_ratio  droplet_density  free_fall_velocity  \
# 0                              0.013301       836.828587            3.961141
# 1                              0.013301       835.298244            3.961141
# 2                              0.013301       835.298244            3.961141
# 3                              0.013833       836.869874            3.961141
# 4                              0.013833       836.795029            3.961141
#
#    drag_velocity  relative_roughness
# 0       3.682513            0.000032
# 1       3.682027            0.000032
# 2       3.682027            0.000032
# 3       3.668435            0.000013
# 4       3.668410            0.000013
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 42 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   test                                  372 non-null    int64
#  1   no_fragmentation                      372 non-null    int64
#  2   splashing                             372 non-null    int64
#  3   splashing_spectrum                    372 non-null    int64
#  4   breaking_up                           372 non-null    int64
#  5   rebound                               372 non-null    int64
#  6   one_drop                              372 non-null    int64
#  7   voltage                               372 non-null    float64
#  8   long_impulse_duration                 372 non-null    int64
#  9   long_impulse_dur_binary               372 non-null    object
#  10  wettability                           372 non-null    object
#  11  roughness                             372 non-null    float64
#  12  liquid_density                        372 non-null    int64
#  13  surface_tension                       372 non-null    float64
#  14  viscosity                             372 non-null    float64
#  15  particle_mean_diameter                372 non-null    float64
#  16  particle_density                      372 non-null    int64
#  17  volume_fraction                       372 non-null    float64
#  18  droplet_diameter                      372 non-null    float64
#  19  height                                372 non-null    float64
#  20  inclination                           372 non-null    float64
#  21  roughness_binary                      372 non-null    int64
#  22  particle_liquid_density_ratio         372 non-null    float64
#  23  volume_fraction_binary                372 non-null    int64
#  24  particle_diameter_cat                 372 non-null    object
#  25  particle_droplet_diameter_ratio       372 non-null    float64
#  26  velocity                              372 non-null    float64
#  27  Re                                    372 non-null    float64
#  28  We                                    372 non-null    float64
#  29  K                                     372 non-null    float64
#  30  no_mixing_time                        372 non-null    float64
#  31  init_volume_fraction                  372 non-null    float64
#  32  sedimentation_velocity                372 non-null    float64
#  33  sedimentation_Re                      372 non-null    float64
#  34  sedimentation_Stk                     372 non-null    float64
#  35  sign_sedimentation_Re                 372 non-null    float64
#  36  sign_sedimentation_Stk                372 non-null    float64
#  37  sign_particle_droplet_diameter_ratio  372 non-null    float64
#  38  droplet_density                       372 non-null    float64
#  39  free_fall_velocity                    372 non-null    float64
#  40  drag_velocity                         372 non-null    float64
#  41  relative_roughness                    372 non-null    float64
# dtypes: float64(27), int64(12), object(3)
# memory usage: 122.2+ KB

# %% [markdown]
# ## Description

# %% [markdown]
# ### Labels description:
#
# - **splashing_spectrum**:
#     - **0 - no splashing**, when *'Number of detached small droplets during Spreading' == 0*
#     - **1 - semi splashing**, when **gear** occurs, or when few droplets detach
#     - **2 - splashing**. Pure splashing, when **many** droplets or **many small** droplets detach
#
# - **splashing**: 1 - when *'Number of detached small droplets during Spreading' != 0*;
# - **breaking_up**: when *'Number of detached small droplets during Receding or Rim merging' > 0*
# - **rebound** consists of next cases:
#     - **2 - true rebound**, when droplets detaching during partial rebound, or when droplet rebounds totally.
#
#     *True rebound: 'Rebound' == 2 OR ('Rebound' == 1 AND 'Number of detached droplets during Rebound' > 0)*
#     - **1 - jet ejection**, when true rebound does not appear.
#
#     *'Rim merging or Central jet ejecting' == 2 AND NOT True rebound*
#     - **0** - no true rebound and no jet ejection. *Other cases*
#
# - **no_fragmentation**: when there is
#     - **no Splashing** (no small droplets detached during spreading, *'Number of detached small droplets during Spreading'==0*),
#     - **no Breaking up** (when *'Number of detached small droplets during Receding or Rim merging' == 0*)
#     - **no True Rebound** (see True rebound definition early)

# %% [markdown]
# ### Physical properties

# %% [markdown]
# $velocity = \sqrt{2g\cdot height}$
#
# $Re=\frac{velocity \cdot droplet\_diameter \cdot liquid\_density}{viscosity}$
#
# $We=\frac{velocity^2 \cdot droplet\_diameter \cdot liquid\_density}{surface\_tension}$
#
# $K = We^{1/2}Re^{1/4}$
#
# particle_droplet_diameter_ratio = particle_mean_diameter / droplet_diameter
#
# particle_liquid_density_ratio = particle_density / liquid_density
#
# *Params above were checked*

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Main column groups

# %%
targets = ['no_fragmentation', 'splashing']
impact_labels = ['splashing_spectrum', 'breaking_up', 'rebound']

# Unnecesary to model
generation_features = [
    'one_drop', 'voltage', 'long_impulse_duration', 'long_impulse_dur_binary'
]

# do not forget 'test'
features_original = [
    'wettability', 'roughness', 'liquid_density', 'surface_tension', 
    'viscosity', 'particle_mean_diameter', 'particle_density', 
    'volume_fraction', 'droplet_diameter', 'height', 'inclination'
]

features_aggregated = [
    'roughness_binary', 'particle_liquid_density_ratio', 
    'volume_fraction_binary', 'particle_diameter_cat', 
    'particle_droplet_diameter_ratio', 
    'velocity', 'Re', 'We', 'K'
]

# %% [markdown]
# ### Drop unnecessary features

# %%
features_to_drop = generation_features + [
    'height', # velocity is more informative
    # 'volume_fraction' # 0.04 and 0.05 are the same group of low volume fraction, as well as 0.08 and 0.10
]

df = df_main.drop(
    features_to_drop, 
    axis=1,
)
display(df.head())
df.info()
# Out:
#    test  no_fragmentation  splashing  splashing_spectrum  breaking_up  \
# 0     3                 0          1                   2            0
# 1     4                 0          1                   2            0
# 2     5                 0          1                   2            0
# 3     7                 0          1                   2            0
# 4     8                 0          1                   2            0
#
#    rebound wettability  roughness  liquid_density  surface_tension  ...  \
# 0        0   lyophilic       0.10             820           0.0269  ...
# 1        0   lyophilic       0.10             820           0.0269  ...
# 2        0   lyophilic       0.10             820           0.0269  ...
# 3        0     neutral       0.04             820           0.0269  ...
# 4        0     neutral       0.04             820           0.0269  ...
#
#    sedimentation_velocity  sedimentation_Re  sedimentation_Stk  \
# 0                0.000018          0.000092       8.252778e-08
# 1                0.000018          0.000092       8.252778e-08
# 2                0.000018          0.000092       8.252778e-08
# 3                0.000018          0.000092       8.582889e-08
# 4                0.000018          0.000092       8.582889e-08
#
#    sign_sedimentation_Re  sign_sedimentation_Stk  \
# 0               0.000092            8.252778e-08
# 1               0.000092            8.252778e-08
# 2               0.000092            8.252778e-08
# 3               0.000092            8.582889e-08
# 4               0.000092            8.582889e-08
#
#    sign_particle_droplet_diameter_ratio  droplet_density  free_fall_velocity  \
# 0                              0.013301       836.828587            3.961141
# 1                              0.013301       835.298244            3.961141
# 2                              0.013301       835.298244            3.961141
# 3                              0.013833       836.869874            3.961141
# 4                              0.013833       836.795029            3.961141
#
#    drag_velocity relative_roughness
# 0       3.682513           0.000032
# 1       3.682027           0.000032
# 2       3.682027           0.000032
# 3       3.668435           0.000013
# 4       3.668410           0.000013
#
# [5 rows x 37 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 37 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   test                                  372 non-null    int64
#  1   no_fragmentation                      372 non-null    int64
#  2   splashing                             372 non-null    int64
#  3   splashing_spectrum                    372 non-null    int64
#  4   breaking_up                           372 non-null    int64
#  5   rebound                               372 non-null    int64
#  6   wettability                           372 non-null    object
#  7   roughness                             372 non-null    float64
#  8   liquid_density                        372 non-null    int64
#  9   surface_tension                       372 non-null    float64
#  10  viscosity                             372 non-null    float64
#  11  particle_mean_diameter                372 non-null    float64
#  12  particle_density                      372 non-null    int64
#  13  volume_fraction                       372 non-null    float64
#  14  droplet_diameter                      372 non-null    float64
#  15  inclination                           372 non-null    float64
#  16  roughness_binary                      372 non-null    int64
#  17  particle_liquid_density_ratio         372 non-null    float64
#  18  volume_fraction_binary                372 non-null    int64
#  19  particle_diameter_cat                 372 non-null    object
#  20  particle_droplet_diameter_ratio       372 non-null    float64
#  21  velocity                              372 non-null    float64
#  22  Re                                    372 non-null    float64
#  23  We                                    372 non-null    float64
#  24  K                                     372 non-null    float64
#  25  no_mixing_time                        372 non-null    float64
#  26  init_volume_fraction                  372 non-null    float64
#  27  sedimentation_velocity                372 non-null    float64
#  28  sedimentation_Re                      372 non-null    float64
#  29  sedimentation_Stk                     372 non-null    float64
#  30  sign_sedimentation_Re                 372 non-null    float64
#  31  sign_sedimentation_Stk                372 non-null    float64
#  32  sign_particle_droplet_diameter_ratio  372 non-null    float64
#  33  droplet_density                       372 non-null    float64
#  34  free_fall_velocity                    372 non-null    float64
#  35  drag_velocity                         372 non-null    float64
#  36  relative_roughness                    372 non-null    float64
# dtypes: float64(25), int64(10), object(2)
# memory usage: 107.7+ KB

# %% [markdown]
# ## Prepare text definitions of the features

# %%
df['no_fragmentation_type'] = df['no_fragmentation'].map(
    no_fragmentation_type_df['impact_type'].to_dict()
)
df['no_fragmentation_type'].value_counts()
# Out:
# fragmentation       273
# no fragmentation     99
# Name: no_fragmentation_type, dtype: int64

# %%
# def get_splashing_type(value):
#     if value == 0:
#         return 'no splashing'
#     if value == 1:
#         return 'semi splashing'
#     else:
#         return 'splashing'

df['splashing_type'] = df['splashing_spectrum'].map(
    splash_impact_type_df
    .sort_values('value')['impact_type']
    .reset_index(drop=True)
    .to_dict()
)
df['splashing_type'].value_counts()
# Out:
# splashing         185
# no splashing      132
# semi splashing     55
# Name: splashing_type, dtype: int64

# %%
def get_volume_fraction_type(value):
    if value == 1:
        return '0.08 .. 0.10'
    else:
        return '0.04 .. 0.05'

df['volume_fraction_type'] = df['volume_fraction_binary'].apply(get_volume_fraction_type)
df['volume_fraction_type'].value_counts()
# Out:
# 0.08 .. 0.10    271
# 0.04 .. 0.05    101
# Name: volume_fraction_type, dtype: int64

# %%
def get_rebound_type(value):
    if value == 1:
        return 'jet ejection'
    if value == 2:
        return 'rebound'
    else:
        return 'no'

df['rebound_type'] = df['rebound'].apply(get_rebound_type)
df['rebound_type'].value_counts()
# Out:
# no              272
# jet ejection     54
# rebound          46
# Name: rebound_type, dtype: int64

# %%
def get_breaking_up_type(value):
    if value == 1:
        return 'yes'
    else:
        return 'no'

df['breaking_up_type'] = df['breaking_up'].apply(get_breaking_up_type)
df['breaking_up_type'].value_counts()
# Out:
# no     273
# yes     99
# Name: breaking_up_type, dtype: int64

# %% [markdown]
# # Research

# %% [markdown]
# ## Splashing and No fragmentation

# %% [markdown]
# ## Particle-liquid density ratio influence on splashing

# %%
order = ['no splashing', 'semi splashing', 'splashing']

y_feature = 'particle_liquid_density_ratio'

inclination_mask = df['inclination'] == 0
wet_mask = df['wettability'] == 'lyophilic'

sub_df = df[
    inclination_mask
    & wet_mask
]

fig, ax = plt.subplots(figsize=(4,3))
sns.boxplot(
    data=sub_df, 
    x='splashing_type', y=y_feature, 
    order=order, 
    hue='splashing_type',
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('no splashing', 'semi splashing'),
    ('semi splashing', 'splashing'),
    ('no splashing', 'splashing')  
]

annotator = Annotator(ax, pairs, data=sub_df, x='splashing_type', 
        y=y_feature, order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('particle-liquid density ratio')
ax.set_xlabel('splashing type');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/splashing_K.pdf')
# Out:
# no splashing vs. semi splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:4.110e-01 U_stat=3.665e+02
# semi splashing vs. splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:2.198e-01 U_stat=5.470e+02
# no splashing vs. splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:1.476e-01 U_stat=1.082e+03

# %% [markdown]
# There is no statistical significant influence of the "particle-liquid density ratio" on the splashing type.

# %% [markdown]
# ## Particle-droplet diameter rario influence on splashing

# %%
order = ['no splashing', 'semi splashing', 'splashing']

y_feature = 'particle_droplet_diameter_ratio'

inclination_mask = df['inclination'] == 0
wet_mask = df['wettability'] == 'lyophilic'


sub_df = df[
    inclination_mask
    & wet_mask
]


fig, ax = plt.subplots(figsize=(4,3))
sns.boxplot(
    data=sub_df, 
    x='splashing_type', y=y_feature, 
    order=order, 
    hue='splashing_type',
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('no splashing', 'semi splashing'),
    ('semi splashing', 'splashing'),
    ('no splashing', 'splashing')  
]

annotator = Annotator(ax, pairs, data=sub_df, x='splashing_type', 
        y=y_feature, order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('particle-droplet diameter ratio')
ax.set_xlabel('splashing type');
ax.get_legend().remove()
fig.tight_layout()

display(
    sub_df.groupby(
        by='splashing_type'
    )['particle_droplet_diameter_ratio'].median()
)


# fig.savefig('../results/experiments/splashing_K.pdf')
# Out:
# no splashing vs. semi splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:2.701e-02 U_stat=2.030e+02
# semi splashing vs. splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:2.826e-02 U_stat=6.200e+02
# no splashing vs. splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:4.353e-01 U_stat=8.270e+02
# splashing_type
# no splashing      0.013431
# semi splashing    0.041604
# splashing         0.013833
# Name: particle_droplet_diameter_ratio, dtype: float64

# %% [markdown]
# Interesting thing, that there is statistical significant influence of the particle-droplet diameter ratio on splashing labels like "no splashing" and "semi splashing" as well as "splashing" and "semi splashing"
# However, there is no statistical significant influence of the particle-droplet diameter ratio on "no splashing" and "splashing"

# %% [markdown]
# let us look at different masks for test. Also, let us consider exact particle sizes influence also with chi-squared test

# %%
feature = 'particle_diameter_cat'
order = ['small', 'medium', 'large']
target = 'splashing'

sub_df = df

cont_table = pd.crosstab(
    sub_df[feature],
    sub_df[target]
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))

# Group the data by feature and target values, count the number of occurrences for each group,
# and reset the index to create a DataFrame with 'count' as a column
df_plot = sub_df.groupby([feature, target]).size().reset_index(name='count')

# For each row in df_plot, compute the total count for its feature group,
# and broadcast the result to match the original DataFrame's shape
df_total = df_plot.groupby(feature)['count'].transform('sum')

# Calculate the proportion of each target value within its feature group by dividing individual counts by the group total
df_plot['proportion'] = df_plot['count'] / df_total

# Building a stacked bar chart
sns.barplot(data=df_plot, x=feature, y='proportion', hue=target, order=order)
plt.title(f'Proportion of {target} by {feature}')
plt.ylabel('Proportion')
plt.show()
# Out:
# splashing                0    1
# particle_diameter_cat
# large                   14   40
# medium                   4   35
# small                  114  165
# p-value = 0.0002587

# %% [markdown]
# Thus, increase of particle size promotes splashing. And obtained result is statistically significant!

# %%
df['roughness_binary'].value_counts()
# Out:
# 0    329
# 1     43
# Name: roughness_binary, dtype: int64

# %%
feature = 'roughness_binary'
order = [0, 1]
target = 'splashing'

sub_df = df

cont_table = pd.crosstab(
    sub_df[feature],
    sub_df[target]
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))

# Group the data by feature and target values, count the number of occurrences for each group,
# and reset the index to create a DataFrame with 'count' as a column
df_plot = sub_df.groupby([feature, target]).size().reset_index(name='count')

# For each row in df_plot, compute the total count for its feature group,
# and broadcast the result to match the original DataFrame's shape
df_total = df_plot.groupby(feature)['count'].transform('sum')

# Calculate the proportion of each target value within its feature group by dividing individual counts by the group total
df_plot['proportion'] = df_plot['count'] / df_total

# Building a stacked bar chart
sns.barplot(data=df_plot, x=feature, y='proportion', hue=target, order=order)
plt.title(f'Proportion of {target} by {feature}')
plt.ylabel('Proportion')
plt.show()
# Out:
# splashing           0    1
# roughness_binary
# 0                 117  212
# 1                  15   28
# p-value = 1

# %% [markdown]
# No stat. significant outcome for the roughness_binary

# %%
sub_df['roughness'].value_counts()
# Out:
# 0.04     114
# 2.49     111
# 0.10     104
# 10.89     43
# Name: roughness, dtype: int64

# %%
feature = 'roughness'
order = [0.10, 10.89]
target = 'splashing'

sub_df = df[df[feature].isin(order)]

cont_table = pd.crosstab(
    sub_df[feature],
    sub_df[target]
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))

# Group the data by feature and target values, count the number of occurrences for each group,
# and reset the index to create a DataFrame with 'count' as a column
df_plot = sub_df.groupby([feature, target]).size().reset_index(name='count')

# For each row in df_plot, compute the total count for its feature group,
# and broadcast the result to match the original DataFrame's shape
df_total = df_plot.groupby(feature)['count'].transform('sum')

# Calculate the proportion of each target value within its feature group by dividing individual counts by the group total
df_plot['proportion'] = df_plot['count'] / df_total

# Building a stacked bar chart
sns.barplot(data=df_plot, x=feature, y='proportion', hue=target, order=order)
plt.title(f'Proportion of {target} by {feature}')
plt.ylabel('Proportion')
plt.show()
# Out:
# splashing   0   1
# roughness
# 0.10       43  61
# 10.89      15  28
# p-value = 0.586573

# %% [markdown]
# We see, that proportion in splashing is higher for the roughness 10.89, than for the 0.1, however there is no statistically significant difference

# %%
feature = 'volume_fraction_type'
order = ['0.04 .. 0.05', '0.08 .. 0.10']
target = 'splashing'

sub_df = df

cont_table = pd.crosstab(
    sub_df[feature],
    sub_df[target]
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))

# Group the data by feature and target values, count the number of occurrences for each group,
# and reset the index to create a DataFrame with 'count' as a column
df_plot = sub_df.groupby([feature, target]).size().reset_index(name='count')

# For each row in df_plot, compute the total count for its feature group,
# and broadcast the result to match the original DataFrame's shape
df_total = df_plot.groupby(feature)['count'].transform('sum')

# Calculate the proportion of each target value within its feature group by dividing individual counts by the group total
df_plot['proportion'] = df_plot['count'] / df_total

# Building a stacked bar chart
sns.barplot(data=df_plot, x=feature, y='proportion', hue=target, order=order)
plt.title(f'Proportion of {target} by {feature}')
plt.ylabel('Proportion')
plt.show()
# Out:
# splashing               0    1
# volume_fraction_type
# 0.04 .. 0.05           14   87
# 0.08 .. 0.10          118  153
# p-value = 2.00043e-07

# %% [markdown]
# The obtained result contradict other experiments, despite it is statistically significant. Let us fix type of wettability:

# %%
feature = 'volume_fraction_type'
order = ['0.04 .. 0.05', '0.08 .. 0.10']
target = 'splashing'

sub_df = df[
    # (df['inclination'] == 0)
    (df['wettability'] == 'lyophilic')
    & (df['roughness'] == 0.10)
    # & (df['particle_diameter_cat'] == 'small')
    # & (df['particle_density'] == 1000)
]

cont_table = pd.crosstab(
    sub_df[feature],
    sub_df[target]
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))

# Group the data by feature and target values, count the number of occurrences for each group,
# and reset the index to create a DataFrame with 'count' as a column
df_plot = sub_df.groupby([feature, target]).size().reset_index(name='count')

# For each row in df_plot, compute the total count for its feature group,
# and broadcast the result to match the original DataFrame's shape
df_total = df_plot.groupby(feature)['count'].transform('sum')

# Calculate the proportion of each target value within its feature group by dividing individual counts by the group total
df_plot['proportion'] = df_plot['count'] / df_total

# Building a stacked bar chart
sns.barplot(data=df_plot, x=feature, y='proportion', hue=target, order=order)
plt.title(f'Proportion of {target} by {feature}')
plt.ylabel('Proportion')
plt.show()
# Out:
# splashing              0   1
# volume_fraction_type
# 0.04 .. 0.05          10  20
# 0.08 .. 0.10          33  41
# p-value = 0.402722

# %% [markdown]
# If we fix wettability, then the result is not statistically significant

# %% [markdown]
# ## Volume fraction influence on splashing

# %%
df.pivot_table(
    values="Re",
    index='volume_fraction_type',
    columns='splashing_type',
    aggfunc='count'
)
# Out:
# splashing_type        no splashing  semi splashing  splashing
# volume_fraction_type
# 0.04 .. 0.05                    14              17         70
# 0.08 .. 0.10                   118              38        115

# %%
fig, ax = plt.subplots()
sns.boxplot(
    data=df, 
    x='splashing_type', y='K', 
    order=['no splashing', 'semi splashing', 'splashing'], 
    hue='volume_fraction_type',
    hue_order=['0.04 .. 0.05', '0.08 .. 0.10'],
    # flierprops={"marker": "x"},
    ax=ax
)
ax.set_ylabel('$K$')
ax.set_xlabel('splashing type');
fig.tight_layout()

# %%
df['particle_density'].value_counts()
# Out:
# 1000    183
# 1200    147
# 450      23
# 2200     19
# Name: particle_density, dtype: int64

# %%
df['wettability'].value_counts()
# Out:
# lyophilic    147
# neutral      114
# lyophobic    111
# Name: wettability, dtype: int64

# %%
feature = 'volume_fraction_type'
order = ['0.04 .. 0.05', '0.08 .. 0.10']

df_splashing = df[
    (df['splashing_type'] == 'splashing')
    & (df['inclination'] == 0)
    & (df['wettability'] == 'lyophilic')
    & (df['roughness'] == 0.10)
    & (df['particle_diameter_cat'] == 'small')
    & (df['particle_density'] == 1000)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    x=feature, y='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, x=feature, 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.04 .. 0.05 vs. 0.08 .. 0.10: Mann-Whitney-Wilcoxon test two-sided, P_val:1.487e-01 U_stat=3.000e+01

# %%
feature = 'volume_fraction_type'
order = ['0.04 .. 0.05', '0.08 .. 0.10']

df_splashing = df[
    (df['splashing_type'] == 'splashing')
    & (df['inclination'] == 0)
    & (df['wettability'] == 'neutral')
    # & (df['roughness'] == 0.10)
    # & (df['particle_diameter_cat'] == 'small')
    & (df['particle_density'] == 1200)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    x=feature, y='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, x=feature, 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.04 .. 0.05 vs. 0.08 .. 0.10: Mann-Whitney-Wilcoxon test two-sided, P_val:3.333e-01 U_stat=4.000e+00

# %%
feature = 'volume_fraction_type'
order = ['0.08 .. 0.10', '0.04 .. 0.05']

df_splashing = df[
    (df['splashing_spectrum'] == 1)
    # & (df['inclination'] == 0)
    # & (df['wettability'] == 'lyophilic')
    # # & (df['roughness'] == 0.10)
    # & (df['particle_diameter_cat'] == 'small')
    # # & (df['particle_density'] == 1200)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    y=feature, x='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, y=feature, 
        x='K', order=order, orient='h')
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside',)
annotator.apply_and_annotate()

ax.set_xlabel('$K$')
ax.set_ylabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.08 .. 0.10 vs. 0.04 .. 0.05: Mann-Whitney-Wilcoxon test two-sided, P_val:4.813e-02 U_stat=2.140e+02

# %%
feature = 'volume_fraction_type'
order = ['0.08 .. 0.10', '0.04 .. 0.05']

df_splashing = df[
    (df['splashing_spectrum'] == 1)
    & (df['inclination'] == 0)
    & (df['wettability'] == 'lyophilic')
    # # & (df['roughness'] == 0.10)
    # & (df['particle_diameter_cat'] == 'small')
    # # & (df['particle_density'] == 1200)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    y=feature, x='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, y=feature, 
        x='K', order=order, orient='h')
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside',)
annotator.apply_and_annotate()

ax.set_xlabel('$K$')
ax.set_ylabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.08 .. 0.10 vs. 0.04 .. 0.05: Mann-Whitney-Wilcoxon test two-sided, P_val:1.853e-01 U_stat=2.500e+01

# %%
feature = 'volume_fraction_type'
order = ['0.08 .. 0.10', '0.04 .. 0.05']

df_splashing = df[
    (df['splashing_spectrum'] == 1)
    & (df['inclination'] == 0)
    & (df['wettability'] == 'lyophilic')
    # & (df['roughness'] == 0.10)
    & (df['particle_diameter_cat'] == 'small')
    # & (df['particle_density'] == 1200)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    y=feature, x='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, y=feature, 
        x='K', order=order, orient='h')
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside',)
annotator.apply_and_annotate()

ax.set_xlabel('$K$')
ax.set_ylabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.08 .. 0.10 vs. 0.04 .. 0.05: Mann-Whitney-Wilcoxon test two-sided, P_val:2.000e-01 U_stat=0.000e+00

# %%
feature = 'volume_fraction_type'
order = ['0.08 .. 0.10', '0.04 .. 0.05']

df_splashing = df[
    (df['splashing_spectrum'] == 1)
    & (df['inclination'] == 0)
    & (df['wettability'] == 'neutral')
    # & (df['roughness'] == 0.10)
    & (df['particle_diameter_cat'] == 'small')
    # & (df['particle_density'] == 1200)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    y=feature, x='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, y=feature, 
        x='K', order=order, orient='h')
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside',)
annotator.apply_and_annotate()

ax.set_xlabel('$K$')
ax.set_ylabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.08 .. 0.10 vs. 0.04 .. 0.05: Mann-Whitney-Wilcoxon test two-sided, P_val:6.286e-01 U_stat=8.000e+00

# %%
feature = 'volume_fraction_type'
order = ['0.08 .. 0.10', '0.04 .. 0.05']

df_splashing = df[
    (df['splashing_spectrum'] == 1)
    & (df['inclination'] == 0)
    & (df['wettability'] == 'lyophobic')
    # & (df['roughness'] == 0.10)
    # & (df['particle_diameter_cat'] == 'small')
    # & (df['particle_density'] == 1200)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    y=feature, x='K', 
    order=order,
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df_splashing, y=feature, 
        x='K', order=order, orient='h')
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside',)
annotator.apply_and_annotate()

ax.set_xlabel('$K$')
ax.set_ylabel('volume fraction');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# 0.08 .. 0.10 vs. 0.04 .. 0.05: Mann-Whitney-Wilcoxon test two-sided, P_val:1.000e+00 U_stat=2.000e+00

# %% [markdown]
# ~~Looks like less volume fraction - less variance in K.~~
#
# However, no statistical significant difference were obtained.
# Necessary to conduct more experiments.
#
# Let us plot without phi differentiation

# %% [markdown]
# NOTE: NECESSARY TO COMPARE WITH MEAN VALUE BETWEEN NON-SPLASHING AND SPLASHING

# %% [markdown]
# ## Roughness influence on splashing

# %%
feature = 'roughness'
order = [0.10, 10.89]

df_splashing = df[
    (df['splashing_type'] == 'splashing')
    & (df['inclination'] == 0)
    & (df['wettability'] == 'lyophilic')
    # & (df['roughness'] == 0.10)
    & (df['particle_diameter_cat'] == 'small')
    & (df['particle_density'] == 1000)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    x=feature, y='K', 
    order=order, 
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    (0.10, 10.89),
]

annotator = Annotator(ax, pairs, data=df_splashing, x=feature, 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('roughness $R_a$ [µm]');
ax.get_legend().remove()
fig.tight_layout()
# Out:
# 0.1 vs. 10.89: Mann-Whitney-Wilcoxon test two-sided, P_val:8.683e-01 U_stat=1.350e+02

# %% [markdown]
# Let us consider only one inclination, but any other properties

# %%
feature = 'roughness'
order = [0.10, 10.89]

df_splashing = df[
    (df['splashing_type'] == 'splashing')
    & (df['inclination'] == 0)
]

fig, ax = plt.subplots()
sns.boxplot(
    data=df_splashing, 
    x=feature, y='K', 
    order=order, 
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    (0.10, 10.89),
]

annotator = Annotator(ax, pairs, data=df_splashing, x=feature, 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('roughness $R_a$ [µm]');
ax.get_legend().remove()
fig.tight_layout()
# Out:
# 0.1 vs. 10.89: Mann-Whitney-Wilcoxon test two-sided, P_val:2.578e-01 U_stat=3.790e+02

# %% [markdown]
# Thus, we have not found statistical significant influence of roughness on splashing.
# Necessary to conduct more experiments.

# %%
df
# Out:
#      test  no_fragmentation  splashing  splashing_spectrum  breaking_up  \
# 0       3                 0          1                   2            0
# 1       4                 0          1                   2            0
# 2       5                 0          1                   2            0
# 3       7                 0          1                   2            0
# 4       8                 0          1                   2            0
# ..    ...               ...        ...                 ...          ...
# 367   391                 0          0                   0            0
# 368   392                 0          1                   1            0
# 369   393                 0          1                   1            0
# 370   394                 0          0                   0            1
# 371   395                 0          0                   0            0
#
#      rebound wettability  roughness  liquid_density  surface_tension  ...  \
# 0          0   lyophilic       0.10             820           0.0269  ...
# 1          0   lyophilic       0.10             820           0.0269  ...
# 2          0   lyophilic       0.10             820           0.0269  ...
# 3          0     neutral       0.04             820           0.0269  ...
# 4          0     neutral       0.04             820           0.0269  ...
# ..       ...         ...        ...             ...              ...  ...
# 367        2   lyophobic       2.49            1180           0.0679  ...
# 368        0   lyophilic       0.10            1180           0.0679  ...
# 369        0   lyophilic       0.10            1180           0.0679  ...
# 370        0     neutral       0.04            1180           0.0679  ...
# 371        2   lyophobic       2.49            1180           0.0679  ...
#
#      sign_particle_droplet_diameter_ratio  droplet_density  \
# 0                                0.013301       836.828587
# 1                                0.013301       835.298244
# 2                                0.013301       835.298244
# 3                                0.013833       836.869874
# 4                                0.013833       836.795029
# ..                                    ...              ...
# 367                              0.082335      1182.252227
# 368                              0.083333      1182.325495
# 369                              0.084098      1182.980827
# 370                              0.082090      1182.143664
# 371                              0.080645      1182.082998
#
#      free_fall_velocity  drag_velocity  relative_roughness  \
# 0              3.961141       3.682513            0.000032
# 1              3.961141       3.682027            0.000032
# 2              3.961141       3.682027            0.000032
# 3              3.961141       3.668435            0.000013
# 4              3.961141       3.668410            0.000013
# ..                  ...            ...                 ...
# 367            1.980571       1.950940            0.000746
# 368            1.980571       1.950448            0.000030
# 369            1.980571       1.950085            0.000031
# 370            1.980571       1.951058            0.000012
# 371            1.980571       1.951766            0.000730
#
#      no_fragmentation_type  splashing_type  volume_fraction_type  \
# 0            fragmentation       splashing          0.08 .. 0.10
# 1            fragmentation       splashing          0.08 .. 0.10
# 2            fragmentation       splashing          0.08 .. 0.10
# 3            fragmentation       splashing          0.08 .. 0.10
# 4            fragmentation       splashing          0.08 .. 0.10
# ..                     ...             ...                   ...
# 367          fragmentation    no splashing          0.08 .. 0.10
# 368          fragmentation  semi splashing          0.08 .. 0.10
# 369          fragmentation  semi splashing          0.08 .. 0.10
# 370          fragmentation    no splashing          0.08 .. 0.10
# 371          fragmentation    no splashing          0.08 .. 0.10
#
#      rebound_type breaking_up_type
# 0              no               no
# 1              no               no
# 2              no               no
# 3              no               no
# 4              no               no
# ..            ...              ...
# 367       rebound               no
# 368            no               no
# 369            no               no
# 370            no              yes
# 371       rebound               no
#
# [372 rows x 42 columns]

# %% [markdown]
# Let us get datasets with equal number of tests (OLD). Now no need for this

# %%
# # Get dataset with equal number of tests
# min_count = df['splashing_type'].value_counts().min()
# groups_idx = df.groupby(by='splashing_type').groups

# indexes = []

# for key in groups_idx:
#     indexes.extend(groups_idx[key][:min_count])
    
# df_stat_splash = df.iloc[indexes, :]

# %% [markdown]
# Before conducting tests let us check distribution

# %%
df['K'].hist()

feature = "K"

# Hypothesis
H0 = f'Normal distribution for {feature}'
Ha = f'Non-normal distribution for {feature}'

# Set significance level
alpha = 0.05

p_value = shapiro(df[feature])[1]
print(f'p={p_value:.4f}')

# Interpetation
if p_value > alpha:
  print(H0)
else:
  print(Ha)
# Out:
# p=0.0000
# Non-normal distribution for K

# %% [markdown]
# - According to histogram, as well as to Shapiro test, we can not say, that feature is normally distributed;
# - Comparison conducted for independent samples
#
# So, let us use **Mann-Whitney-Wilcoxon** (U-test; Wilcoxon rank-sum test) for the paired samples

# %%
order = ['no splashing', 'semi splashing', 'splashing']

fig, ax = plt.subplots(figsize=(4,3))
sns.boxplot(
    data=df, 
    x='splashing_type', y='K', 
    order=order, 
    hue='splashing_type',
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('no splashing', 'semi splashing'),
    ('semi splashing', 'splashing'),
    ('no splashing', 'splashing')  
]

annotator = Annotator(ax, pairs, data=df, x='splashing_type', 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('splashing type');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/splashing_K.pdf')
# Out:
# no splashing vs. semi splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:1.349e-08 U_stat=1.714e+03
# semi splashing vs. splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:2.313e-04 U_stat=3.422e+03
# no splashing vs. splashing: Mann-Whitney-Wilcoxon test two-sided, P_val:4.906e-31 U_stat=2.890e+03

# %% [markdown]
# ### Check outliers

# %%
def get_outliers(series:pd.Series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    median = series.median()
    
    IQR = Q3 - Q1
    
    outliers_tuple = (Q1 - 1.5*IQR, Q3 + 1.5*IQR)
    
    return outliers_tuple

K_high_outlier = get_outliers(df[df['splashing'] == 0]['K'])[1]
print(f'K high outlier boundary: {K_high_outlier:.2f}')
df[(df['splashing'] == 0) & (df['K'] >= K_high_outlier)]
# Out:
# K high outlier boundary: 256.32
# Empty DataFrame
# Columns: [test, no_fragmentation, splashing, splashing_spectrum, breaking_up, rebound, wettability, roughness, liquid_density, surface_tension, viscosity, particle_mean_diameter, particle_density, volume_fraction, droplet_diameter, inclination, roughness_binary, particle_liquid_density_ratio, volume_fraction_binary, particle_diameter_cat, particle_droplet_diameter_ratio, velocity, Re, We, K, no_mixing_time, init_volume_fraction, sedimentation_velocity, sedimentation_Re, sedimentation_Stk, sign_sedimentation_Re, sign_sedimentation_Stk, sign_particle_droplet_diameter_ratio, droplet_density, free_fall_velocity, drag_velocity, relative_roughness, no_fragmentation_type, splashing_type, volume_fraction_type, rebound_type, breaking_up_type]
# Index: []
#
# [0 rows x 42 columns]

# %% [markdown]
# No outliers for "no splashing"

# %% [markdown]
# ## Rebound

# %%
# # Get dataset with equal number of tests
# min_count = df['rebound_type'].value_counts().min()
# groups_idx = df.groupby(by='rebound_type').groups

# indexes = []

# for key in groups_idx:
#     indexes.extend(groups_idx[key][:min_count])
    
# df_stat_rebound = df.iloc[indexes, :]

# %%
df['rebound_type'].value_counts()
# Out:
# no              272
# jet ejection     54
# rebound          46
# Name: rebound_type, dtype: int64

# %%
order = ['no', 'jet ejection', 'rebound']

feature = 'rebound_type'

fig, ax = plt.subplots(figsize=(5,4))
sns.boxplot(
    data=df, 
    x=feature, y='K', 
    order=order, 
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('no', 'jet ejection'),
    ('jet ejection', 'rebound'),
    ('no', 'rebound')  
]

annotator = Annotator(ax, pairs, data=df, x=feature, 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('rebound type');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/rebound_K.pdf')
# Out:
# no vs. jet ejection: Mann-Whitney-Wilcoxon test two-sided, P_val:8.120e-01 U_stat=7.193e+03
# jet ejection vs. rebound: Mann-Whitney-Wilcoxon test two-sided, P_val:4.935e-01 U_stat=1.342e+03
# no vs. rebound: Mann-Whitney-Wilcoxon test two-sided, P_val:8.055e-01 U_stat=6.398e+03

# %% [markdown]
# No sufficient difference

# %% [markdown]
# ## Breaking up

# %%
order = ['no', 'yes']

feature = 'breaking_up_type'

fig, ax = plt.subplots(figsize=(4,3))
sns.boxplot(
    data=df, 
    x=feature, y='K', 
    order=order, 
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('no', 'yes'),
]

annotator = Annotator(ax, pairs, data=df, x=feature, 
        y='K', order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('$K$')
ax.set_xlabel('breaking up');
ax.get_legend().remove()
fig.tight_layout()

# fig.savefig('../results/experiments/breaking_up_K.pdf')
# Out:
# no vs. yes: Mann-Whitney-Wilcoxon test two-sided, P_val:2.015e-05 U_stat=9.606e+03

# %% [markdown]
# ## Chi-squared test

# %% [markdown]
# ### Volume fraction

# %%
mask_wet = df['wettability'] == 'lyophilic'
mask_inclination = df['inclination'] == 0
mask_part_diam = df['particle_diameter_cat'] == 'large'

sub_df = df

cont_table = pd.crosstab(
    sub_df['volume_fraction_binary'],
    sub_df['splashing_spectrum']
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))
# Out:
# splashing_spectrum        0   1    2
# volume_fraction_binary
# 0                        14  17   70
# 1                       118  38  115
# p-value = 4.24777e-07

# %%
mask_wet = df['wettability'] == 'lyophilic'
mask_inclination = df['inclination'] == 0
mask_part_diam = df['particle_diameter_cat'] == 'large'

sub_df = df[
    mask_wet
    & mask_inclination
    # & mask_part_diam
]

cont_table = pd.crosstab(
    sub_df['volume_fraction_binary'],
    sub_df['splashing_spectrum']
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))
# Out:
# splashing_spectrum       0  1   2
# volume_fraction_binary
# 0                       11  9  17
# 1                       25  9  34
# p-value = 0.342021

# %%
mask_wet = df['wettability'] == 'neutral'
mask_inclination = df['inclination'] == 0
mask_part_diam = df['particle_diameter_cat'] == 'small'
mask_liquid_density = df['liquid_density'] == 1180
mask_height = df_main['height'] == 0.8

sub_df = df[
    mask_wet
    & mask_inclination
    # & mask_part_diam
    # & mask_liquid_density
    # & mask_height
]

cont_table = pd.crosstab(
    sub_df['volume_fraction_binary'],
    sub_df['splashing']
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))
# Out:
# splashing                0   1
# volume_fraction_binary
# 0                        3  27
# 1                       25  22
# p-value = 0.000319112

# %%
mask_wet = df['wettability'] == 'neutral'
mask_inclination = df['inclination'] == 0
mask_part_diam = df['particle_diameter_cat'] == 'small'
mask_liquid_density = df['liquid_density'] == 1180
mask_height = df_main['height'] == 0.8

sub_df = df[
    mask_wet
    & mask_inclination
    # & mask_part_diam
    & mask_liquid_density
    & mask_height
]

cont_table = pd.crosstab(
    sub_df['volume_fraction_binary'],
    sub_df['splashing']
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))
# Out:
# splashing               0   1
# volume_fraction_binary
# 0                       3  10
# 1                       9   5
# p-value = 0.0774679

# %%
mask_wet = df['wettability'] == 'lyophobic'
mask_inclination = df['inclination'] == 0
mask_part_diam = df['particle_diameter_cat'] == 'small'
# mask_liquid_density = df['liquid_density'] == 1180
mask_height = df_main['height'] == 0.8

sub_df = df[
    mask_wet
    & mask_inclination
    # & mask_part_diam
    # & mask_liquid_density
    & mask_height
]

cont_table = pd.crosstab(
    sub_df['volume_fraction_binary'],
    sub_df['splashing']
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))
# Out:
# splashing               0   1
# volume_fraction_binary
# 0                       0  34
# 1                       3  21
# p-value = 0.12974

# %% [markdown]
# Check volume fraction influence on diameter

# %%
order = ['0.04 .. 0.05', '0.08 .. 0.10']

feature = 'volume_fraction_type'
y_feature = 'droplet_diameter'

fig, ax = plt.subplots(figsize=(4,3))
sns.boxplot(
    data=df, 
    x=feature, y=y_feature, 
    order=order, 
    hue=feature,
    # flierprops={"marker": "x"},
    ax=ax
)

pairs = [
    ('0.04 .. 0.05', '0.08 .. 0.10'),
]

annotator = Annotator(ax, pairs, data=df, x=feature, 
        y=y_feature, order=order)
annotator.configure(test='Mann-Whitney', text_format='simple', loc='inside')
annotator.apply_and_annotate()

ax.set_ylabel('droplet diameter [m]')
ax.set_xlabel('volume fraction [%]');
ax.get_legend().remove()
fig.tight_layout()
# Out:
# 0.04 .. 0.05 vs. 0.08 .. 0.10: Mann-Whitney-Wilcoxon test two-sided, P_val:2.375e-01 U_stat=1.478e+04

# %% [markdown]
# There is no statistical significant influence of the volume fraction on droplet diameter

# %% [markdown]
# ### Roughness

# %%
mask_wet = df['wettability'] == 'lyophilic'
mask_inclination = df['inclination'] == 0
# mask_part_diam = df['particle_diameter_cat'] == 'large'

sub_df = df[
    mask_wet
    & mask_inclination
    # & mask_part_diam
]

cont_table = pd.crosstab(
    sub_df['roughness_binary'],
    sub_df['splashing_spectrum']
)

display(cont_table)

stat, p, dot, exprcted = chi2_contingency(cont_table)

print("p-value = {:g}".format(p))
# Out:
# splashing_spectrum   0   1   2
# roughness_binary
# 0                   27  15  29
# 1                    9   3  22
# p-value = 0.0601865

# %% [markdown]
# No statistical significance

# %% [markdown]
# ## Glycerol data

# %% [markdown]
# Let us set horisontal lyophillic smooth substrate (inclination = 0; wettability = 'lyophillic', roughness = 0.1).
#
# Also, let us consider water-glycerol solution (liquid_density = 1180; viscosity = 0.0231; surface_tension = 0.0679),
# and droplets with some median diameter (droplet_diameter = 0.00318).
#
# Let us consider 8-10% suspension concentration (volume_fraction_binary = 1).
#
# We will vary both (in two plots) **particle_mean_diameter** (in range 0.0000415...0.000275) and **particle_liquid_density_ratio** (in range 0.38 .. 1.86) - for y-axis.
#
# Also we will vary droplet **velocity** in range (1.98 .. 5.94) to get different K values for x-axis.

# %% [markdown]
# Let us consider the statistics of the selected experiments:

# %%
wet_mask = df['wettability'] == 'lyophilic'
roughness_mask = df['roughness'] == 0.1
inclination_mask = df['inclination'] == 0
density_mask = df['liquid_density'] == 1180

glycerol_mask = wet_mask & roughness_mask & inclination_mask & density_mask

glycerol_df = df[glycerol_mask]
display(glycerol_df.describe().T)
display(glycerol_df.describe(include='object').T)
# Out:
#                                       count          mean           std  \
# test                                   43.0  1.834651e+02  9.041606e+01
# no_fragmentation                       43.0  5.581395e-01  5.024855e-01
# splashing                              43.0  3.953488e-01  4.947118e-01
# splashing_spectrum                     43.0  5.813953e-01  7.938021e-01
# breaking_up                            43.0  4.651163e-02  2.130826e-01
# rebound                                43.0  0.000000e+00  0.000000e+00
# roughness                              43.0  1.000000e-01  2.808406e-17
# liquid_density                         43.0  1.180000e+03  0.000000e+00
# surface_tension                        43.0  6.790000e-02  1.404203e-17
# viscosity                              43.0  2.310000e-02  0.000000e+00
# particle_mean_diameter                 43.0  1.091977e-04  9.801003e-05
# particle_density                       43.0  1.160465e+03  4.239213e+02
# volume_fraction                        43.0  7.282638e-02  2.628708e-02
# droplet_diameter                       43.0  3.142279e-03  2.318781e-04
# inclination                            43.0  0.000000e+00  0.000000e+00
# roughness_binary                       43.0  0.000000e+00  0.000000e+00
# particle_liquid_density_ratio          43.0  9.834450e-01  3.592554e-01
# volume_fraction_binary                 43.0  6.279070e-01  4.890835e-01
# particle_droplet_diameter_ratio        43.0  3.464960e-02  3.109125e-02
# velocity                               43.0  3.733811e+00  9.169427e-01
# Re                                     43.0  6.025929e+02  1.642531e+02
# We                                     43.0  8.135198e+02  3.910452e+02
# K                                      43.0  1.384282e+02  4.385251e+01
# no_mixing_time                         43.0  7.274419e+01  4.315150e+01
# init_volume_fraction                   43.0  6.953488e-02  2.192558e-02
# sedimentation_velocity                 43.0  6.773382e-06  1.795363e-05
# sedimentation_Re                       43.0  1.119438e-04  1.554250e-04
# sedimentation_Stk                      43.0  4.702291e-07  8.012712e-07
# sign_sedimentation_Re                  43.0  9.560068e-05  1.662216e-04
# sign_sedimentation_Stk                 43.0  4.644794e-07  8.046973e-07
# sign_particle_droplet_diameter_ratio   43.0  2.707880e-02  3.801482e-02
# droplet_density                        43.0  1.180121e+03  2.990859e+01
# free_fall_velocity                     43.0  3.961141e+00  1.058660e+00
# drag_velocity                          43.0  3.733811e+00  9.169427e-01
# relative_roughness                     43.0  3.200746e-05  2.557226e-06
#
#                                                min           25%  \
# test                                  5.000000e+01  1.135000e+02
# no_fragmentation                      0.000000e+00  0.000000e+00
# splashing                             0.000000e+00  0.000000e+00
# splashing_spectrum                    0.000000e+00  0.000000e+00
# breaking_up                           0.000000e+00  0.000000e+00
# rebound                               0.000000e+00  0.000000e+00
# roughness                             1.000000e-01  1.000000e-01
# liquid_density                        1.180000e+03  1.180000e+03
# surface_tension                       6.790000e-02  6.790000e-02
# viscosity                             2.310000e-02  2.310000e-02
# particle_mean_diameter                4.150000e-05  4.150000e-05
# particle_density                      4.500000e+02  1.000000e+03
# volume_fraction                       3.704341e-02  4.563624e-02
# droplet_diameter                      2.500000e-03  3.025000e-03
# inclination                           0.000000e+00  0.000000e+00
# roughness_binary                      0.000000e+00  0.000000e+00
# particle_liquid_density_ratio         3.813559e-01  8.474576e-01
# volume_fraction_binary                0.000000e+00  0.000000e+00
# particle_droplet_diameter_ratio       1.165730e-02  1.302986e-02
# velocity                              1.939862e+00  3.752103e+00
# Re                                    2.625951e+02  5.759593e+02
# We                                    1.733004e+02  7.339907e+02
# K                                     5.299336e+01  1.327216e+02
# no_mixing_time                        3.800000e+01  4.750000e+01
# init_volume_fraction                  4.000000e-02  4.500000e-02
# sedimentation_velocity               -2.453051e-05 -4.952515e-06
# sedimentation_Re                      1.265430e-06  5.990072e-06
# sedimentation_Stk                     8.334179e-10  3.710930e-09
# sign_sedimentation_Re                -5.200257e-05 -1.049890e-05
# sign_sedimentation_Stk               -1.465468e-08 -6.312769e-09
# sign_particle_droplet_diameter_ratio -1.571970e-02 -1.250102e-02
# droplet_density                       1.114038e+03  1.171391e+03
# free_fall_velocity                    1.980571e+00  3.961141e+00
# drag_velocity                         1.939862e+00  3.752103e+00
# relative_roughness                    2.808989e-05  3.016598e-05
#
#                                                50%           75%          max
# test                                  1.720000e+02  2.360000e+02   360.000000
# no_fragmentation                      1.000000e+00  1.000000e+00     1.000000
# splashing                             0.000000e+00  1.000000e+00     1.000000
# splashing_spectrum                    0.000000e+00  1.000000e+00     2.000000
# breaking_up                           0.000000e+00  0.000000e+00     1.000000
# rebound                               0.000000e+00  0.000000e+00     0.000000
# roughness                             1.000000e-01  1.000000e-01     0.100000
# liquid_density                        1.180000e+03  1.180000e+03  1180.000000
# surface_tension                       6.790000e-02  6.790000e-02     0.067900
# viscosity                             2.310000e-02  2.310000e-02     0.023100
# particle_mean_diameter                4.150000e-05  1.375000e-04     0.000275
# particle_density                      1.200000e+03  1.200000e+03  2200.000000
# volume_fraction                       8.050489e-02  9.304636e-02     0.140105
# droplet_diameter                      3.180000e-03  3.315000e-03     0.003560
# inclination                           0.000000e+00  0.000000e+00     0.000000
# roughness_binary                      0.000000e+00  0.000000e+00     0.000000
# particle_liquid_density_ratio         1.016949e+00  1.016949e+00     1.864407
# volume_fraction_binary                1.000000e+00  1.000000e+00     1.000000
# particle_droplet_diameter_ratio       1.397306e-02  4.680228e-02     0.103774
# velocity                              3.765884e+00  3.780720e+00     5.447130
# Re                                    6.117462e+02  6.466808e+02   990.575946
# We                                    7.837681e+02  8.311717e+02  1835.683210
# K                                     1.392312e+02  1.453522e+02   240.364769
# no_mixing_time                        5.500000e+01  8.050000e+01   265.000000
# init_volume_fraction                  8.000000e-02  8.000000e-02     0.100000
# sedimentation_velocity                6.987275e-07  2.619450e-05     0.000036
# sedimentation_Re                      4.601923e-05  7.552776e-05     0.000431
# sedimentation_Stk                     1.465468e-08  1.279786e-07     0.000002
# sign_sedimentation_Re                 1.481242e-06  7.552776e-05     0.000431
# sign_sedimentation_Stk                1.133105e-09  1.279786e-07     0.000002
# sign_particle_droplet_diameter_ratio  1.325879e-02  4.680228e-02     0.103774
# droplet_density                       1.181606e+03  1.181756e+03  1281.866693
# free_fall_velocity                    3.961141e+00  3.961141e+00     5.941712
# drag_velocity                         3.765884e+00  3.780720e+00     5.447130
# relative_roughness                    3.144654e-05  3.305794e-05     0.000040
#                       count unique               top freq
# wettability              43      1         lyophilic   43
# particle_diameter_cat    43      3             small   27
# no_fragmentation_type    43      2  no fragmentation   24
# splashing_type           43      3      no splashing   26
# volume_fraction_type     43      2      0.08 .. 0.10   27
# rebound_type             43      1                no   43
# breaking_up_type         43      2                no   41

# %% [markdown]
# Let us check no splashing cases

# %%
glycerol_df[(glycerol_df['splashing'] == 0) & (glycerol_df['K']>200)].T
# Out:
#                                                 327            328
# test                                            351            352
# no_fragmentation                                  0              0
# splashing                                         0              0
# splashing_spectrum                                0              0
# breaking_up                                       1              1
# rebound                                           0              0
# wettability                               lyophilic      lyophilic
# roughness                                       0.1            0.1
# liquid_density                                 1180           1180
# surface_tension                              0.0679         0.0679
# viscosity                                    0.0231         0.0231
# particle_mean_diameter                     0.000041       0.000041
# particle_density                               1200           1200
# volume_fraction                            0.080328       0.080909
# droplet_diameter                            0.00326        0.00313
# inclination                                     0.0            0.0
# roughness_binary                                  0              0
# particle_liquid_density_ratio              1.016949       1.016949
# volume_fraction_binary                            1              1
# particle_diameter_cat                         small          small
# particle_droplet_diameter_ratio             0.01273       0.013259
# velocity                                   5.392602       5.365357
# Re                                       898.019998     857.853209
# We                                      1647.504442    1565.863139
# K                                        222.195265      214.15595
# no_mixing_time                                 62.0          152.0
# init_volume_fraction                           0.08           0.08
# sedimentation_velocity                     0.000001       0.000001
# sedimentation_Re                           0.000001       0.000001
# sedimentation_Stk                               0.0            0.0
# sign_sedimentation_Re                      0.000001       0.000001
# sign_sedimentation_Stk                          0.0            0.0
# sign_particle_droplet_diameter_ratio        0.01273       0.013259
# droplet_density                         1181.606563    1181.618179
# free_fall_velocity                         5.941712       5.941712
# drag_velocity                              5.392602       5.365357
# relative_roughness                         0.000031       0.000032
# no_fragmentation_type                 fragmentation  fragmentation
# splashing_type                         no splashing   no splashing
# volume_fraction_type                   0.08 .. 0.10   0.08 .. 0.10
# rebound_type                                     no             no
# breaking_up_type                                yes            yes
