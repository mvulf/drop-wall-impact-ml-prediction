# %% [markdown]
# Modelling of df_modelling_no_multicollinearity_pf.xlsx

# %% [markdown]
# # Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from pathlib import Path
import sys

from tqdm import tqdm

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
RANDOM_STATE = 42

# %%
# train/test split
sys.path.insert(1, '../utils_functionality/split_utils/')
from split_tools import get_train_test

# %%
# sklearn models pipeline
sys.path.insert(1, '../utils_functionality/models/')
from modelling2_utils import MLPipeline

# %%
dataset_filename = 'df_modelling_no_multicollinearity_pf'

# %% [markdown]
# # Splashing

# %% [markdown]
# ## Train/test datasets creation

# %%
target = 'splashing'
train, test = get_train_test(
    dataset_filename=dataset_filename,
    target=target)

# %% [markdown]
# ## Numerical, categorical features selection

# %%
train.describe()
# Out:
#         splashing  wettability  liquid_density  surface_tension  \
# count  297.000000   297.000000      297.000000       297.000000
# mean     0.646465     0.912458     1116.161616         0.067515
# std      0.478874     0.825530       98.337949         0.008979
# min      0.000000     0.000000      820.000000         0.026900
# 25%      0.000000     0.000000     1000.000000         0.067900
# 50%      1.000000     1.000000     1180.000000         0.067900
# 75%      1.000000     2.000000     1180.000000         0.071300
# max      1.000000     2.000000     1180.000000         0.073200
#
#        droplet_diameter  inclination  roughness_binary  \
# count        297.000000   297.000000        297.000000
# mean           0.003145     9.242424          0.117845
# std            0.000271    15.987172          0.322969
# min            0.002130     0.000000          0.000000
# 25%            0.002990     0.000000          0.000000
# 50%            0.003210     0.000000          0.000000
# 75%            0.003340    20.000000          0.000000
# max            0.003660    45.000000          1.000000
#
#        particle_liquid_density_ratio  volume_fraction_binary  \
# count                     297.000000              297.000000
# mean                        0.990754                0.727273
# std                         0.269354                0.446113
# min                         0.381356                0.000000
# 25%                         0.877193                0.000000
# 50%                         1.000000                1.000000
# 75%                         1.016949                1.000000
# max                         1.864407                1.000000
#
#        particle_droplet_diameter_ratio    Re^(1/4)  We^(1/4)^2  \
# count                       297.000000  297.000000  297.000000
# mean                          0.025974    6.391598   26.427325
# std                           0.024387    2.367570    7.825824
# min                           0.011339    4.003811   11.916747
# 25%                           0.012652    4.951214   25.096339
# 50%                           0.013577    5.092815   28.410070
# 75%                           0.018694    8.868391   30.065485
# max                           0.103774   11.761989   45.132225
#
#        We^(1/4)^2 Re^(1/4)
# count           297.000000
# mean            171.713124
# std              84.738011
# min              52.684981
# 25%             128.988793
# 50%             152.487586
# 75%             236.927284
# max             472.780129

# %%
for column in train.columns:
    print(f'{column}:\t|\t{[round(x, 3) for x in train[column].unique()[:5]]}\t|\tUnique vales: {train[column].nunique()}')
# Out:
# splashing:	|	[0, 1]	|	Unique vales: 2
# wettability:	|	[1, 2, 0]	|	Unique vales: 3
# liquid_density:	|	[1180, 1000, 820, 1060, 1140]	|	Unique vales: 5
# surface_tension:	|	[0.068, 0.073, 0.027, 0.071, 0.069]	|	Unique vales: 5
# droplet_diameter:	|	[0.003, 0.003, 0.003, 0.003, 0.003]	|	Unique vales: 105
# inclination:	|	[45, 0, 20]	|	Unique vales: 3
# roughness_binary:	|	[0, 1]	|	Unique vales: 2
# particle_liquid_density_ratio:	|	[0.847, 1.0, 1.864, 1.017, 1.22]	|	Unique vales: 8
# volume_fraction_binary:	|	[1, 0]	|	Unique vales: 2
# particle_droplet_diameter_ratio:	|	[0.014, 0.044, 0.014, 0.013, 0.012]	|	Unique vales: 148
# Re^(1/4):	|	[4.163, 10.437, 11.345, 8.89, 5.111]	|	Unique vales: 194
# We^(1/4)^2:	|	[14.229, 25.84, 37.399, 13.258, 30.323]	|	Unique vales: 197
# We^(1/4)^2 Re^(1/4):	|	[59.242, 269.684, 424.301, 117.864, 154.976]	|	Unique vales: 197

# %%
binary_features = ['roughness_binary', 'volume_fraction_binary']
categorical_features = ['wettability']
numerical_features = ['droplet_diameter', 'particle_droplet_diameter_ratio',
                      'particle_liquid_density_ratio', 'Re^(1/4)', 'We^(1/4)^2', 
                      'We^(1/4)^2 Re^(1/4)',
                       'liquid_density',
                        'surface_tension', 'inclination']

# %%
assert len((set(train.columns)) & set(binary_features + categorical_features + numerical_features)) + 1 \
    == len(train.columns), 'Some features are not selected'

# %% [markdown]
# ## Modelling

# %% [markdown]
# Models:
# * Sklearn models
#     * LogReg
#     * SVM
#     * KNN
# * CatBoost
# * XGBoost

# %% [markdown]
# ### Sklearn models

# %%
models = [
    LogisticRegression(),
    SVC(),
    KNeighborsClassifier()]
encoders = ['onehot', 'ordenc']
smote_flags = [True, False]

for model in tqdm(models):
    for encoder in encoders:
        for smote_flag in smote_flags:
            pipeline = MLPipeline(train, test, target, model,
                    numerical_features, categorical_features,
                    random_state=RANDOM_STATE,
                    postfix=encoder,
                    smote=smote_flag,
                    dataset_filename=dataset_filename)
            pipeline.full_pipeline()
# Out:
#  33%|███▎      | 1/3 [00:00<00:00,  4.35it/s]
# logisticregression_smote_splashing_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# logisticregression_splashing_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# logisticregression_smote_splashing_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# logisticregression_splashing_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# svc_smote_splashing_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
#  67%|██████▋   | 2/3 [00:00<00:00,  4.66it/s]
# svc_splashing_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# svc_smote_splashing_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# svc_splashing_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# kneighborsclassifier_smote_splashing_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# 100%|██████████| 3/3 [00:00<00:00,  4.40it/s]
# kneighborsclassifier_splashing_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# kneighborsclassifier_smote_splashing_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# kneighborsclassifier_splashing_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models

# %% [markdown]
# ### Boosting Models

# %%
models =  [
    XGBClassifier(),
    CatBoostClassifier(verbose=False)
    ]

for model in tqdm(models):
    for smote_flag in smote_flags:
        pipeline = MLPipeline(train, test, target, model,
                    numerical_features, categorical_features,
                    random_state=RANDOM_STATE,
                    postfix='', dataset_filename=dataset_filename,
                    smote=smote_flag)
        pipeline.full_pipeline()
# Out:
#  50%|█████     | 1/2 [00:00<00:00,  3.72it/s]
# xgbclassifier_smote_splashing_df_modelling_no_multicollinearity_pf was saved in modelling2_models
# xgbclassifier_splashing_df_modelling_no_multicollinearity_pf was saved in modelling2_models
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# catboostclassifier_smote_splashing_df_modelling_no_multicollinearity_pf was saved in modelling2_models
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# 100%|██████████| 2/2 [00:37<00:00, 18.81s/it]
# catboostclassifier_splashing_df_modelling_no_multicollinearity_pf was saved in modelling2_models

# %% [markdown]
# # Net impact

# %% [markdown]
# ## Train/test datasets creation

# %%
target = 'net_impact'
train, test = get_train_test(
    dataset_filename=dataset_filename,
    target=target)

# %% [markdown]
# ## Modelling

# %% [markdown]
# Models:
# * Sklearn models
#     * LogReg
#     * SVM
#     * KNN
# * CatBoost
# * XGBoost

# %% [markdown]
# ### Sklearn models

# %%
models = [
    LogisticRegression(),
    SVC(),
    KNeighborsClassifier()]
encoders = ['onehot', 'ordenc']
smote_flags = [True, False]

for model in tqdm(models):
    for encoder in encoders:
        for smote_flag in smote_flags:
            pipeline = MLPipeline(train, test, target, model,
                    numerical_features, categorical_features,
                    random_state=RANDOM_STATE,
                    postfix=encoder, dataset_filename=dataset_filename,
                    smote=smote_flag)
            pipeline.full_pipeline()
# Out:
#  33%|███▎      | 1/3 [00:00<00:00,  4.84it/s]
# logisticregression_smote_net_impact_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# logisticregression_net_impact_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# logisticregression_smote_net_impact_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# logisticregression_net_impact_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
#  67%|██████▋   | 2/3 [00:00<00:00,  4.33it/s]
# svc_smote_net_impact_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# svc_net_impact_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# svc_smote_net_impact_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# svc_net_impact_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# 100%|██████████| 3/3 [00:00<00:00,  4.34it/s]
# kneighborsclassifier_smote_net_impact_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# kneighborsclassifier_net_impact_df_modelling_no_multicollinearity_pf_onehot was saved in modelling2_models
# kneighborsclassifier_smote_net_impact_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models
# kneighborsclassifier_net_impact_df_modelling_no_multicollinearity_pf_ordenc was saved in modelling2_models

# %% [markdown]
# ### Boosting Models

# %%
models =  [
    XGBClassifier(),
    CatBoostClassifier(verbose=False)]

for model in tqdm(models):
    for smote_flag in smote_flags:
        pipeline = MLPipeline(train, test, target, model,
                    numerical_features, categorical_features,
                    random_state=RANDOM_STATE,
                    postfix='', dataset_filename=dataset_filename,
                    smote=smote_flag)
        pipeline.full_pipeline()
# Out:
#  50%|█████     | 1/2 [00:00<00:00,  3.52it/s]
# xgbclassifier_smote_net_impact_df_modelling_no_multicollinearity_pf was saved in modelling2_models
# xgbclassifier_net_impact_df_modelling_no_multicollinearity_pf was saved in modelling2_models
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# catboostclassifier_smote_net_impact_df_modelling_no_multicollinearity_pf was saved in modelling2_models
# C:\Users\dimaz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\catboost\core.py:1419: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self._init_pool(data, label, cat_features, text_features, embedding_features, embedding_features_data, pairs, weight,
# 100%|██████████| 2/2 [00:31<00:00, 15.91s/it]
# catboostclassifier_net_impact_df_modelling_no_multicollinearity_pf was saved in modelling2_models
