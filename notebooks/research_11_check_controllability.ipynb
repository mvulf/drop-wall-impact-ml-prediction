# %% [markdown]
# Let us check changings in K-parameter depending on droplet size with constant velocity

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import sys
from pathlib import Path

sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

sys.path.append('../')
import utils_functionality.model3_analysis as ma

# %%
source_df = pd.DataFrame(
    {
        'inclination': [0, 0],
        'drag_velocity': [2.5, 2.5],
        'liquid_density': [1000, 1000],
        'viscosity': [0.001, 0.001],
        'surface_tension': [0.072, 0.072],
        'droplet_diameter': [0.0034, 0.0023],
    }
)

df = ma.extract_agg_features(
    source_df
)
df
# Out:
#    inclination  drag_velocity  liquid_density  viscosity  surface_tension  \
# 0            0            2.5            1000      0.001            0.072
# 1            0            2.5            1000      0.001            0.072
#
#    droplet_diameter  velocity      Re          We           K
# 0            0.0034       2.5  8500.0  295.138889  164.955937
# 1            0.0023       2.5  5750.0  199.652778  123.042356
