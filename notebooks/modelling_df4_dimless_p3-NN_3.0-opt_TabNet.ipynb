# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import logging

# Set logging level for PyTorch Tabular
logging.getLogger("pytorch_tabular").setLevel(logging.ERROR)

# Set logging level for PyTorch Lightning
logging.getLogger("pytorch_lightning").setLevel(logging.ERROR)

# Set logging level for Lightning Fabric
logging.getLogger("lightning_fabric").setLevel(logging.ERROR)

# Disable device availability messages
logging.getLogger("lightning.pytorch.utilities.rank_zero").setLevel(logging.FATAL)

import pandas as pd
import numpy as np

from pytorch_tabular.models import CategoryEmbeddingModelConfig, TabNetModelConfig

import optuna

from functools import partial

from pathlib import Path
import sys

from typing import Type
from sklearn.base import BaseEstimator

from sklearn.metrics import (
    make_scorer,
    f1_score,
)

sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from split_tools import get_train_test
from modelling4_utils import (
    # _prepare_df,
    MLPipeline,
    StatsModelsEstimator,
    PytorchTabularEstimator,
    deep_update_estimator_params,
    OptunaOptimizer,
    GridSearchOptimizer,
    RANDOM_STATE,
)

# from pytorch_lightning.loggers import MLFlowLogger
from pytorch_lightning.loggers import TensorBoardLogger

seed = RANDOM_STATE

# Fix error with save weights

# import torch
# # from omegaconf import DictConfig
# # from omegaconf.base import ContainerMetadata
# # import typing
# # torch.serialization.add_safe_globals([DictConfig, ContainerMetadata, typing.Any])
# import pytorch_tabular.utils.python_utils as pt_utils
# pt_utils.pl_load = lambda f, map_location: torch.load(f, map_location=map_location, weights_only=False)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# True
# 1

# %% [markdown]
# # Settings

# %%
model_postfix = 'opt-model'

scoring_metrics = {"f1_macro": make_scorer(f1_score, average="macro"),}
step_scoring_average = "mean"
n_trials = 500 # make 300

save_model_and_metrics = True
metrics_file = "metrics_modelling4_6-neural_networks.xlsx"

# %% [markdown]
# ## Optimization function

# %%
def optimize_estimator_optuna(
    target:str,
    estimator:Type[BaseEstimator],
    estimator_params:dict,
    objective:callable,
    n_trials:int,
    add_smote:bool,
    is_smotenc:bool,
    smote_params:dict,
    step_scoring_average:str=step_scoring_average,
    params_to_process:list=None,
    model_postfix:str=model_postfix,
    scoring_metrics:dict=scoring_metrics,
    save_model_and_metrics:bool=save_model_and_metrics,
    metrics_file:str=metrics_file,
    opt_cv_folds:int=5,
    seed:int=seed,
):
    
    estimator_params = estimator_params.copy()
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=estimator,
        estimator_params=estimator_params,
        model_postfix=model_postfix,
        add_smote=add_smote,
        is_smotenc=is_smotenc,
        smote_params=smote_params,
        scoring_metrics=scoring_metrics,
        step_scoring_average=step_scoring_average,
        cv_folds=opt_cv_folds,
    )
    
    opt = OptunaOptimizer(
        objective=partial(objective, ml_pipe=ml_pipe),
        study_name="model_study",
        direction="maximize",
        seed=seed,
    )
    
    opt.optimize(n_trials=n_trials)
    
    best_params = opt.study.best_params
    
    print('raw best_params')
    display(best_params)
    
    if params_to_process:
        for param in params_to_process:
            if param == 'log2_size':
                keys = [k for k in best_params.keys() if param in k]
                sorted_keys = sorted(keys, key=lambda k: int(k.split("_")[1]))
                layer_sizes = [
                    2**best_params.pop(key)
                    for key in sorted_keys
                ]
                best_params['layers'] = '-'.join(map(str, layer_sizes))
            elif param == 'num_layers':
                key = next((k for k in best_params.keys() if param in k), None)
                if key:
                    best_params.pop(key)
            else: # Other cases
                # Find one key in best_params which contains param
                key = next((k for k in best_params.keys() if param in k), None)
                if key:
                    best_params[param] = best_params.pop(key)

    print('best_params')
    display(best_params)
    
    suggested_estimator_params = {
        "model_config_params": best_params
    }
    best_estimator_params = deep_update_estimator_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_estimator_params,
    )
    
    ml_pipe = MLPipeline(
        target=target,
        estimator=estimator,
        estimator_params={**estimator_params, **best_estimator_params},
        model_postfix=model_postfix,
        add_smote=add_smote,
        is_smotenc=is_smotenc,
        smote_params=smote_params,
        step_scoring_average=step_scoring_average, # No need to pass, it would not be used
        metrics_file=metrics_file,
    )
    
    ml_pipe.run(
        save_model_and_metrics=save_model_and_metrics,
    )

# %% [markdown]
# ## TabNet

# %%
def TabNet_objective(
    trial:optuna.trial.Trial, 
    ml_pipe:MLPipeline,
):
    # decoder dimension
    n_d = trial.suggest_int('n_d', 4, 32, step=4)
    # attention dimension
    n_a = trial.suggest_int('n_a', 4, 32, step=4)
    # number of steps of the attention mechanism
    n_steps = trial.suggest_int('n_steps', 1, 5)
    # sparsity parameter - controls the importance of the sparsity loss
    gamma = trial.suggest_float('gamma', 1.0, 1.8)
    # number of shared GLU layers (shared across steps & features)
    n_shared = trial.suggest_int('n_shared', 1, 3)
    # number of independent GLU layers (shared across decision steps)
    n_independent = trial.suggest_int('n_independent', 1, 4)
    # learning rate
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 1e-1, log=True)
    
    suggested_estimator_params = {
        "model_config_params": {
            'n_d': n_d,
            'n_a': n_a,
            'n_steps': n_steps,
            'gamma': gamma,
            'n_shared': n_shared,
            'n_independent': n_independent,
            'learning_rate': learning_rate,
        }
    }
    
    estimator_params = deep_update_estimator_params(
        ml_pipe=ml_pipe,
        suggested_params=suggested_estimator_params,
    )
    
    score = ml_pipe.step(
        estimator=ml_pipe._pipeline_params['estimator'],
        estimator_params=estimator_params,
    )
    
    return score

# %%
estimator = PytorchTabularEstimator
target = "splashing"

add_smote = True
is_smotenc = False
smote_params = {
    # 'categorical_features': (
    #     'wettability',
    #     'inclination',
    # ),
}

estimator_params = {
    "model_class": CategoryEmbeddingModelConfig,
    # Other params SET in optuna
    "model_config_params": {
        'virtual_batch_size': 32,
    },
    # "data_config_params": {},
    "trainer_config_params": {
        'max_epochs': 300,
        'batch_size': 300, # let's condiser whole dataset
        'early_stopping': 'valid_loss',
        'early_stopping_patience': 15,
        'accelerator': 'gpu',
        'devices': 1,
        'progress_bar': 'none',
    },
    "optimizer_config_params": {
        'optimizer': 'Adam',
        'lr_scheduler': 'ReduceLROnPlateau',
        'lr_scheduler_params': {
            'patience': 5,
            'factor': 0.5,
        },
    },
}

optimize_estimator_optuna(
    target=target,
    estimator=estimator,
    estimator_params=estimator_params,
    objective=TabNet_objective,
    n_trials=n_trials,
    add_smote=add_smote,
    is_smotenc=is_smotenc,
    smote_params=smote_params,
)
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# [I 2025-04-27 02:53:10,527] A new study created in memory with name: model_study
# [I 2025-04-27 02:53:16,048] Trial 0 finished with value: 0.8432636190546837 and parameters: {'num_layers': 2, 'layer_0_log2_size': 7, 'layer_1_log2_size': 5, 'activation': 'ReLU', 'dropout': 0.02904180608409973, 'learning_rate': 0.029154431891537533, 'use_batch_norm': False, 'batch_norm_continuous_input': False}. Best is trial 0 with value: 0.8432636190546837.
# [I 2025-04-27 02:54:07,727] Trial 1 finished with value: 0.78056709506644 and parameters: {'num_layers': 3, 'layer_0_log2_size': 1, 'layer_1_log2_size': 1, 'layer_2_log2_size': 1, 'activation': 'LeakyReLU', 'dropout': 0.14561457009902096, 'learning_rate': 0.0028016351587162596, 'use_batch_norm': False, 'batch_norm_continuous_input': False}. Best is trial 0 with value: 0.8432636190546837.
# [I 2025-04-27 02:54:16,736] Trial 2 finished with value: 0.8133206601263245 and parameters: {'num_layers': 3, 'layer_0_log2_size': 1, 'layer_1_log2_size': 4, 'layer_2_log2_size': 4, 'activation': 'LeakyReLU', 'dropout': 0.03252579649263976, 'learning_rate': 0.06245139574743072, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 0 with value: 0.8432636190546837.
# [I 2025-04-27 02:54:19,595] Trial 3 finished with value: 0.39262730396751017 and parameters: {'num_layers': 3, 'layer_0_log2_size': 3, 'layer_1_log2_size': 0, 'layer_2_log2_size': 3, 'activation': 'LeakyReLU', 'dropout': 0.331261142176991, 'learning_rate': 0.00017654048052495074, 'use_batch_norm': False, 'batch_norm_continuous_input': False}. Best is trial 0 with value: 0.8432636190546837.
# [I 2025-04-27 02:54:56,876] Trial 4 finished with value: 0.8608187139917757 and parameters: {'num_layers': 3, 'layer_0_log2_size': 7, 'layer_1_log2_size': 7, 'layer_2_log2_size': 4, 'activation': 'ReLU', 'dropout': 0.022613644455269033, 'learning_rate': 0.0002001342062287998, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:55:09,117] Trial 5 finished with value: 0.850571247939669 and parameters: {'num_layers': 1, 'layer_0_log2_size': 4, 'activation': 'LeakyReLU', 'dropout': 0.49344346830025865, 'learning_rate': 0.012273800987852962, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:55:12,578] Trial 6 finished with value: 0.2612037037037037 and parameters: {'num_layers': 3, 'layer_0_log2_size': 6, 'layer_1_log2_size': 0, 'layer_2_log2_size': 2, 'activation': 'LeakyReLU', 'dropout': 0.1654490124263246, 'learning_rate': 1.795698422567761e-05, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:56:13,110] Trial 7 finished with value: 0.8208063979296856 and parameters: {'num_layers': 3, 'layer_0_log2_size': 3, 'layer_1_log2_size': 0, 'layer_2_log2_size': 5, 'activation': 'ELU', 'dropout': 0.24689779818219537, 'learning_rate': 0.0012329098365270509, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:57:18,734] Trial 8 finished with value: 0.42676270952640494 and parameters: {'num_layers': 2, 'layer_0_log2_size': 2, 'layer_1_log2_size': 4, 'activation': 'ReLU', 'dropout': 0.37777556927152434, 'learning_rate': 8.226074946221034e-05, 'use_batch_norm': False, 'batch_norm_continuous_input': False}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:57:24,897] Trial 9 finished with value: 0.8497489687305256 and parameters: {'num_layers': 3, 'layer_0_log2_size': 5, 'layer_1_log2_size': 6, 'layer_2_log2_size': 6, 'activation': 'LeakyReLU', 'dropout': 0.40372007758203127, 'learning_rate': 0.038403004190988556, 'use_batch_norm': True, 'batch_norm_continuous_input': False}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:58:34,222] Trial 10 finished with value: 0.8431973610935699 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.12481266542059477, 'learning_rate': 0.00021206551805691206, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:58:51,752] Trial 11 finished with value: 0.8322440988785873 and parameters: {'num_layers': 1, 'layer_0_log2_size': 5, 'activation': 'ELU', 'dropout': 0.49619930784193905, 'learning_rate': 0.006146439247862417, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 4 with value: 0.8608187139917757.
# [I 2025-04-27 02:59:07,187] Trial 12 finished with value: 0.868530910771334 and parameters: {'num_layers': 1, 'layer_0_log2_size': 5, 'activation': 'ReLU', 'dropout': 0.4990662089056309, 'learning_rate': 0.01031344889453027, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 12 with value: 0.868530910771334.
# [I 2025-04-27
and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.05632999991610491, 'learning_rate': 0.01662258173094822, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 110 with value: 0.8911552840003655.
# [I 2025-04-27 03:56:01,713] Trial 296 finished with value: 0.5155000207318325 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.09427177514720896, 'learning_rate': 2.3999735448496406e-05, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 110 with value: 0.8911552840003655.
# [I 2025-04-27 03:56:08,822] Trial 297 finished with value: 0.8810678839055989 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.0348643279136147, 'learning_rate': 0.009648931408739002, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 110 with value: 0.8911552840003655.
# [I 2025-04-27 03:56:27,639] Trial 298 finished with value: 0.8362543828413393 and parameters: {'num_layers': 1, 'layer_0_log2_size': 3, 'activation': 'LeakyReLU', 'dropout': 0.048905100969589804, 'learning_rate': 0.012956513384977839, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 110 with value: 0.8911552840003655.
# [I 2025-04-27 03:56:37,029] Trial 299 finished with value: 0.8802854786807227 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.0734168598504586, 'learning_rate': 0.0059140095467622, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 110 with value: 0.8911552840003655.
# raw best_params
# {'num_layers': 1,
#  'layer_0_log2_size': 7,
#  'activation': 'LeakyReLU',
#  'dropout': 0.05368731404192041,
#  'learning_rate': 0.010100246162580432,
#  'use_batch_norm': False,
#  'batch_norm_continuous_input': True}
# best_params
# {'activation': 'LeakyReLU',
#  'dropout': 0.05368731404192041,
#  'learning_rate': 0.010100246162580432,
#  'use_batch_norm': False,
#  'batch_norm_continuous_input': True,
#  'layers': '128'}
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "PytorchTabularEstimator"
#                                                                                  0
# target                                                                   splashing
# model                             CategoryEmbeddingModel_splashing_smote_opt-model
# holdout_test_f1_macro                                                     0.839525
# holdout_test_accuracy_balanced                                            0.836806
# holdout_test_roc_auc                                                      0.922068
# holdout_test_f1                                                           0.886598
# holdout_test_accuracy                                                     0.853333
# cv_test_f1_macro_median                                                   0.842262
# cv_test_accuracy_balanced_median                                          0.859133
# cv_test_roc_auc_median                                                    0.922601
# cv_test_f1_median                                                         0.878788
# cv_test_accuracy_median                                                   0.849057
# cv_test_precision_class_0_median                                          0.761905
# cv_test_recall_class_0_median                                             0.894737
# cv_test_f1_class_0_median                                                 0.809524
# Model saved in ..\results\models_modelling4\CategoryEmbeddingModel_splashing_smote_opt-model

# %%
estimator = PytorchTabularEstimator
target = "no_fragmentation"

add_smote = True
is_smotenc = True
smote_params = {
    'categorical_features': (
        'wettability',
        'inclination',
    ),
}

params_to_process = [
    'num_layers', # drop this param
    'log2_size', # process to get string of layer sizes
]

estimator_params = {
    "model_class": CategoryEmbeddingModelConfig,
    "model_config_params": {
        'activation': 'LeakyReLU',
        'batch_norm_continuous_input': True, # We already have normalized features    
        'use_batch_norm': False, # For hidden layers
    },
    # "data_config_params": {},
    "trainer_config_params": {
        'max_epochs': 200,
        'batch_size': 300, # let's condiser whole dataset
        'early_stopping': 'valid_loss',
        'early_stopping_patience': 10,
        'accelerator': 'gpu',
        'devices': 1,
        'progress_bar': 'none',
    },
    "optimizer_config_params": {
        'optimizer': 'Adam',
        'lr_scheduler': 'ReduceLROnPlateau',
        'lr_scheduler_params': {
            'patience': 5,
            'factor': 0.5,
        },
    },
}

optimize_estimator_optuna(
    target=target,
    estimator=estimator,
    estimator_params=estimator_params,
    params_to_process=params_to_process,
    objective=MLP_objective,
    n_trials=n_trials,
    add_smote=add_smote,
    is_smotenc=is_smotenc,
    smote_params=smote_params,
)
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "no_fragmentation" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:07,252] Trial 287 finished with value: 0.7568139967996161 and parameters: {'num_layers': 1, 'layer_0_log2_size': 1, 'activation': 'ELU', 'dropout': 0.026478254302823107, 'learning_rate': 0.0011855526592087148, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:12,541] Trial 288 finished with value: 0.875285919573842 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.13559299663103763, 'learning_rate': 0.046894612657541544, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:17,913] Trial 289 finished with value: 0.8673333713636222 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.10919104033894925, 'learning_rate': 0.03786762344880401, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:23,184] Trial 290 finished with value: 0.8729089582725859 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.12698238563173556, 'learning_rate': 0.057357234652781294, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:29,757] Trial 291 finished with value: 0.8519615739177983 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.09431562246297888, 'learning_rate': 0.027486789130149538, 'use_batch_norm': True, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:34,728] Trial 292 finished with value: 0.8580767021396296 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.15017101642494826, 'learning_rate': 0.07093110057692738, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:41,001] Trial 293 finished with value: 0.8589757749470472 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.1177267986953541, 'learning_rate': 0.021103652300112092, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:49:46,398] Trial 294 finished with value: 0.8710855699174622 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.047525806808266235, 'learning_rate': 0.04646552736193511, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:50:48,645] Trial 295 finished with value: 0.8423089224002899 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.1339747411741534, 'learning_rate': 0.0005461325618940127, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:50:54,300] Trial 296 finished with value: 0.8673333713636222 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'ReLU', 'dropout': 0.10923902231640678, 'learning_rate': 0.036761388119821, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:50:59,739] Trial 297 finished with value: 0.8795763059727651 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.20159610286813717, 'learning_rate': 0.051568351770771466, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:51:05,515] Trial 298 finished with value: 0.8604528813244379 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.21807056040066627, 'learning_rate': 0.061580824552158867, 'use_batch_norm': False, 'batch_norm_continuous_input': True}. Best is trial 274 with value: 0.880915981761289.
# [I 2025-04-27 04:51:10,956] Trial 299 finished with value: 0.8608962214490209 and parameters: {'num_layers': 1, 'layer_0_log2_size': 7, 'activation': 'LeakyReLU', 'dropout': 0.2031290540036286, 'learning_rate': 0.05397915082223308, 'use_batch_norm': False, 'batch_norm_continuous_input': False}. Best is trial 274 with value: 0.880915981761289.
# raw best_params
# {'num_layers': 1,
#  'layer_0_log2_size': 7,
#  'activation': 'LeakyReLU',
#  'dropout': 0.020012990188122446,
#  'learning_rate': 0.051818480542551844,
#  'use_batch_norm': False,
#  'batch_norm_continuous_input': True}
# best_params
# {'activation': 'LeakyReLU',
#  'dropout': 0.020012990188122446,
#  'learning_rate': 0.051818480542551844,
#  'use_batch_norm': False,
#  'batch_norm_continuous_input': True,
#  'layers': '128'}
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "no_fragmentation" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "PytorchTabularEstimator"
#                                                                                   0
# target                                                             no_fragmentation
# model                             CategoryEmbeddingModel_no_fragmentation_smoten...
# holdout_test_f1_macro                                                      0.859023
# holdout_test_accuracy_balanced                                             0.847727
# holdout_test_roc_auc                                                       0.957273
# holdout_test_f1                                                            0.789474
# holdout_test_accuracy                                                      0.893333
# cv_test_f1_macro_median                                                    0.890909
# cv_test_accuracy_balanced_median                                           0.915385
# cv_test_roc_auc_median                                                     0.969231
# cv_test_f1_median                                                          0.848485
# cv_test_accuracy_median                                                    0.907407
# cv_test_precision_class_0_median                                           0.972222
# cv_test_recall_class_0_median                                              0.923077
# cv_test_f1_class_0_median                                                  0.933333
# Model saved in ..\results\models_modelling4\CategoryEmbeddingModel_no_fragmentation_smotenc_opt-model

# %% [markdown]
# Best choose:
#
# - "activation": "LeakyReLU",
# - "use_batch_norm": False,
# - "batch_norm_continuous_input": True,
#
# Params to optimize:
# - dropout
# - learning_rate
# - layers
