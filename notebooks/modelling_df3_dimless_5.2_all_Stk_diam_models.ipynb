# %% [markdown]
# Save base Logit, KNN, SVC, LogisticRegression, CatBoost, XGboost with pipeline. Sedimentation_Stk feature was used!
# No optimization was used.

# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import joblib

from statsmodels.api import Logit
from statsmodels.api import Logit # type: ignore
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

from pathlib import Path
import sys

sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from split_tools import get_train_test
from modelling3_utils import (
    # _prepare_df,
    MLPipeline,
    _create_pipeline,
    StatsModelsEstimator,
)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Settings

# %%
features_to_drop = (
    # 'sign_particle_droplet_diameter_ratio',
    'sign_sedimentation_Stk',
    'Re', 
    'We', 
    'init_volume_fraction',
    'particle_droplet_diameter_ratio',
    'sedimentation_Re',
    'particle_liquid_density_ratio',
    # 'sedimentation_Stk',
    'sign_sedimentation_Re',
    # 'volume_fraction', 
    # 'relative_roughness', 
    # 'inclination',
    # 'wettability',
    # 'K',
)
log_features=(
    'relative_roughness',
    'sedimentation_Stk',
)
minmax_features_splash=(
    # 'relative_roughness',
    'inclination',
    'volume_fraction',
)
passthrough_features_splash=(
    'wettability',
)
minmax_features_no_fragm=(
    # 'relative_roughness',
)
passthrough_features_no_fragm=(
    'wettability',
    'inclination',
    'volume_fraction',
)
add_const=False
model_postfix='Stk_diam'

# %% [markdown]
# # Logit

# %%
estimator = StatsModelsEstimator(Logit)

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_splash,
    passthrough_features=passthrough_features_splash,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run(
    save_model_and_metrics=False
)
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# Optimization terminated successfully.
#          Current function value: 0.397271
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.366859
# ...

# %%
estimator = StatsModelsEstimator(Logit)

ml_pipe = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_no_fragm,
    passthrough_features=passthrough_features_no_fragm,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run(
    save_model_and_metrics=False
)
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# Optimization terminated successfully.
#          Current function value: 0.282634
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.264131
# ...

# %% [markdown]
# # Logistic Regression

# %%
estimator = LogisticRegression(
    fit_intercept=False,
)

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_splash,
    passthrough_features=passthrough_features_splash,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "LogisticRegression"
#                                                              0
# target                                               splashing
# ...

# %%
estimator = LogisticRegression(
    fit_intercept=False,
)

ml_pipe = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_no_fragm,
    passthrough_features=passthrough_features_no_fragm,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "LogisticRegression"
#                                                                     0
# ...

# %% [markdown]
# # KNClassifier

# %%
estimator = KNeighborsClassifier()

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_splash,
    passthrough_features=passthrough_features_splash,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "KNeighborsClassifier"
#                                                                0
# target                                                 splashing
# ...

# %%
estimator = KNeighborsClassifier()

ml_pipe = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_no_fragm,
    passthrough_features=passthrough_features_no_fragm,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "KNeighborsClassifier"
#                                                                       0
# ...

# %% [markdown]
# # SVC

# %%
estimator = SVC(probability=True)

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_splash,
    passthrough_features=passthrough_features_splash,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "SVC"
#                                               0
# target                                splashing
# model                    SVC_splashing_Stk_diam
# ...

# %%
estimator = SVC(probability=True)

ml_pipe = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_no_fragm,
    passthrough_features=passthrough_features_no_fragm,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "SVC"
#                                                      0
# target                                no_fragmentation
# ...

# %% [markdown]
# # CatBoost

# %%
estimator = CatBoostClassifier(verbose=False)

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_splash,
    passthrough_features=passthrough_features_splash,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "CatBoostClassifier"
#                                                              0
# target                                               splashing
# ...

# %%
estimator = CatBoostClassifier(verbose=False)

ml_pipe = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_no_fragm,
    passthrough_features=passthrough_features_no_fragm,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "CatBoostClassifier"
#                                                                     0
# ...

# %% [markdown]
# # XGBoost

# %%
estimator = XGBClassifier()

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_splash,
    passthrough_features=passthrough_features_splash,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_splashing.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "XGBClassifier"
#                                                         0
# target                                          splashing
# ...

# %%
estimator = XGBClassifier()

ml_pipe = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=features_to_drop,
    minmax_features=minmax_features_no_fragm,
    passthrough_features=passthrough_features_no_fragm,
    log_features=log_features,
    add_const=add_const,
    model_postfix=model_postfix,
)

ml_pipe.run()
# Out:
# Load dataset from: ../data/df_dimless.xlsx
# Keep "no_fragmentation" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ../data/df_ml_split_no_fragmentation.xlsx
# std_features
# ('sedimentation_Stk',
#  'sign_particle_droplet_diameter_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(),
#                                  ('sedimentation_Stk',
#                                   'sign_particle_droplet_diameter_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability', 'inclination',
#                                   'volume_fraction'))])
# no summary in estimator class "XGBClassifier"
#                                                                0
# target                                          no_fragmentation
# ...
