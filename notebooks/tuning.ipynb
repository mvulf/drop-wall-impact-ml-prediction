# %% [markdown]
# # Загрузка библиотек

# %%
import pandas as pd
import sys
import pickle
from catboost import CatBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC
from IPython.display import display, HTML

# %%
sys.path.append('../utils_functionality/')
from data_analysis.split_analisys import *
from data_analysis.reports import *
from models.class_models import *
from models.class_models import *
from models.hyperparams_tuning import *
from models.blending import *
# Out:
# Imported 0.2.6 version. Select nrows to a small number when running on huge datasets.
# output = featurewiz(dataname, target, corr_limit=0.90, verbose=2, sep=',',
# 		header=0, test_data='',feature_engg='', category_encoders='',
# 		dask_xgboost_flag=False, nrows=None, skip_sulov=False)
# Create new features via 'feature_engg' flag : ['interactions','groupby','target']

# %%
import wandb
wandb.login(key='8b1f2ae49570ea59dc8612ff434ca497d463d221')

# %%
pd.set_option('display.max_columns', None)

# %%
RANDOM_STATE = 42
N_TRIALS = 500

# %% [markdown]
# # Загрузка данных и разделение на train, test

# %%
df = pd.read_excel('../data/df_merged_edited.xlsx', index_col=[0])
df.reset_index(inplace=True, drop=True)
train, test = train_test_split(df, test_size=0.33, random_state=RANDOM_STATE)

# %%
# логирование 
df_logs = pd.DataFrame(columns=['Таргет', 'Модель', 'Датасет', 'F1', 'ROC AUC'])

# %% [markdown]
# # splashing

# %% [markdown]
# ## 1. CatBoost + SMOTENC + optuna

# %% [markdown]
# ### Original Dataset

# %%
features = ['Re', 'We', 'particle_liquid_density_ratio',
             'wettability', 'roughness', 'surface_tension', 'liquid_density']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      liquid_density  surface_tension  particle_liquid_density_ratio  \
# 31             1140           0.0691                       0.877193
# 36             1140           0.0691                       0.877193
# 158            1180           0.0679                       1.864407
# 183            1180           0.0679                       0.847458
# 168             820           0.0269                       1.219512
#
#     wettability  roughness           Re           We
# 31      neutral       0.04  2110.385675   833.534028
# 36    lyophilic      10.89  2022.562172   798.846587
# 158   lyophobic       2.49   661.664919   891.662791
# 183   lyophilic       0.10   649.524278   875.302006
# 168     neutral       0.04  1466.205641  1465.995744

# %%
cat_features = [3]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/splashing_original_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8590</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.842857</td>
#       <td>0.907692</td>
#       <td>0.874074</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.886792</td>
#       <td>0.810345</td>
#       <td>0.846847</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.861789</td>
#       <td>0.861789</td>
#       <td>0.861789</td>
#       <td>0.861789</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.864825</td>
#       <td>0.859019</td>
#       <td>0.860460</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.863575</td>
#       <td>0.861789</td>
#       <td>0.861235</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(pd.DataFrame({
    'Таргет': ['splashing'],
    'Модель': ['CatBoost + SMOTENC + optuna'],
    'Датасет': ['original'],
    'F1': [f1],
    'ROC AUC': [roc]
}))

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, splashing, original'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### United Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We
# 31    833.534028
# 36    798.846587
# 158   891.662791
# 183   875.302006
# 168  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/splashing_united_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8590</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.842857</td>
#       <td>0.907692</td>
#       <td>0.874074</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.886792</td>
#       <td>0.810345</td>
#       <td>0.846847</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.861789</td>
#       <td>0.861789</td>
#       <td>0.861789</td>
#       <td>0.861789</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.864825</td>
#       <td>0.859019</td>
#       <td>0.860460</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.863575</td>
#       <td>0.861789</td>
#       <td>0.861235</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["united"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, splashing, united'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### Alternative Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness_binary', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio',
            'volume_fraction_binary', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness_binary  \
# 31                        0.877193     neutral                 0
# 36                        0.877193   lyophilic                 1
# 158                       1.864407   lyophobic                 0
# 183                       0.847458   lyophilic                 0
# 168                       1.219512     neutral                 0
#
#      volume_fraction_binary           Re           We
# 31                        1  2110.385675   833.534028
# 36                        1  2022.562172   798.846587
# 158                       0   661.664919   891.662791
# 183                       1   649.524278   875.302006
# 168                       0  1466.205641  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/splashing_alternative_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8676</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.855072</td>
#       <td>0.907692</td>
#       <td>0.880597</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.888889</td>
#       <td>0.827586</td>
#       <td>0.857143</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.869919</td>
#       <td>0.869919</td>
#       <td>0.869919</td>
#       <td>0.869919</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.871981</td>
#       <td>0.867639</td>
#       <td>0.868870</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.871018</td>
#       <td>0.869919</td>
#       <td>0.869537</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["alternative"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, splashing, alternative'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### PF Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 
            'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features, get_pf=True)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We    Re_1/4    We_1/4   Re_1/4^2  Re_1/4 We_1/4   We_1/4^2
# 31    833.534028  6.777827  5.373173  45.938934      36.418436  28.870989
# 36    798.846587  6.706184  5.316378  44.972905      35.652609  28.263874
# 158   891.662791  5.071770  5.464497  25.722848      27.714668  29.860723
# 183   875.302006  5.048343  5.439256  25.485766      27.459228  29.585503
# 168  1465.995744  6.187977  6.187756  38.291065      38.289694  38.288324

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/splashing_pf_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8935</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.893939</td>
#       <td>0.907692</td>
#       <td>0.900763</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.894737</td>
#       <td>0.879310</td>
#       <td>0.886957</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.894338</td>
#       <td>0.893501</td>
#       <td>0.893860</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.894315</td>
#       <td>0.894309</td>
#       <td>0.894253</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["pf"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, splashing, pf'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ## 2. RandomForest + SMOTENC + optuna

# %% [markdown]
# ### Original Dataset

# %%
features = ['Re', 'We', 'particle_liquid_density_ratio',
             'wettability', 'roughness', 'surface_tension', 'liquid_density']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      liquid_density  surface_tension  particle_liquid_density_ratio  \
# 31             1140           0.0691                       0.877193
# 36             1140           0.0691                       0.877193
# 158            1180           0.0679                       1.864407
# 183            1180           0.0679                       0.847458
# 168             820           0.0269                       1.219512
#
#     wettability  roughness           Re           We
# 31      neutral       0.04  2110.385675   833.534028
# 36    lyophilic      10.89  2022.562172   798.846587
# 158   lyophobic       2.49   661.664919   891.662791
# 183   lyophilic       0.10   649.524278   875.302006
# 168     neutral       0.04  1466.205641  1465.995744

# %%
cat_features = [3]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_original_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8676</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.855072</td>
#       <td>0.907692</td>
#       <td>0.880597</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.888889</td>
#       <td>0.827586</td>
#       <td>0.857143</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.869919</td>
#       <td>0.869919</td>
#       <td>0.869919</td>
#       <td>0.869919</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.871981</td>
#       <td>0.867639</td>
#       <td>0.868870</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.871018</td>
#       <td>0.869919</td>
#       <td>0.869537</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["original"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, splashing, original'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### United Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We
# 31    833.534028
# 36    798.846587
# 158   891.662791
# 183   875.302006
# 168  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_united_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8935</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.893939</td>
#       <td>0.907692</td>
#       <td>0.900763</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.894737</td>
#       <td>0.879310</td>
#       <td>0.886957</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.894338</td>
#       <td>0.893501</td>
#       <td>0.893860</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.894315</td>
#       <td>0.894309</td>
#       <td>0.894253</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["united"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, splashing, united'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### Alternative Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness_binary', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio',
            'volume_fraction_binary', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness_binary  \
# 31                        0.877193     neutral                 0
# 36                        0.877193   lyophilic                 1
# 158                       1.864407   lyophobic                 0
# 183                       0.847458   lyophilic                 0
# 168                       1.219512     neutral                 0
#
#      volume_fraction_binary           Re           We
# 31                        1  2110.385675   833.534028
# 36                        1  2022.562172   798.846587
# 158                       0   661.664919   891.662791
# 183                       1   649.524278   875.302006
# 168                       0  1466.205641  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_alternative_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8763</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.867647</td>
#       <td>0.907692</td>
#       <td>0.887218</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.890909</td>
#       <td>0.844828</td>
#       <td>0.867257</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.879278</td>
#       <td>0.876260</td>
#       <td>0.877237</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.878616</td>
#       <td>0.878049</td>
#       <td>0.877805</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["alternative"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, splashing, alternative'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### PF Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 
            'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features, get_pf=True)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We    Re_1/4    We_1/4   Re_1/4^2  Re_1/4 We_1/4   We_1/4^2
# 31    833.534028  6.777827  5.373173  45.938934      36.418436  28.870989
# 36    798.846587  6.706184  5.316378  44.972905      35.652609  28.263874
# 158   891.662791  5.071770  5.464497  25.722848      27.714668  29.860723
# 183   875.302006  5.048343  5.439256  25.485766      27.459228  29.585503
# 168  1465.995744  6.187977  6.187756  38.291065      38.289694  38.288324

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_pf_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8599</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.852941</td>
#       <td>0.892308</td>
#       <td>0.872180</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.872727</td>
#       <td>0.827586</td>
#       <td>0.849558</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.861789</td>
#       <td>0.861789</td>
#       <td>0.861789</td>
#       <td>0.861789</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.862834</td>
#       <td>0.859947</td>
#       <td>0.860869</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.862271</td>
#       <td>0.861789</td>
#       <td>0.861513</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["pf"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, splashing, pf'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ## 3. KNN  + SMOTENC + optuna

# %% [markdown]
# ### Original Dataset

# %%
features = ['Re', 'We', 'particle_liquid_density_ratio',
             'wettability', 'roughness', 'surface_tension', 'liquid_density']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      liquid_density  surface_tension  particle_liquid_density_ratio  \
# 31             1140           0.0691                       0.877193
# 36             1140           0.0691                       0.877193
# 158            1180           0.0679                       1.864407
# 183            1180           0.0679                       0.847458
# 168             820           0.0269                       1.219512
#
#     wettability  roughness           Re           We
# 31      neutral       0.04  2110.385675   833.534028
# 36    lyophilic      10.89  2022.562172   798.846587
# 158   lyophobic       2.49   661.664919   891.662791
# 183   lyophilic       0.10   649.524278   875.302006
# 168     neutral       0.04  1466.205641  1465.995744

# %%
cat_features = [3]
numerical_features = [0, 1, 2, 4, 5, 6]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_original_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8676</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.855072</td>
#       <td>0.907692</td>
#       <td>0.880597</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.888889</td>
#       <td>0.827586</td>
#       <td>0.857143</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.869919</td>
#       <td>0.869919</td>
#       <td>0.869919</td>
#       <td>0.869919</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.871981</td>
#       <td>0.867639</td>
#       <td>0.868870</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.871018</td>
#       <td>0.869919</td>
#       <td>0.869537</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["KNN + SMOTENC + optuna"],
            "Датасет": ["original"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='KNN + SMOTENC + optuna, splashing, original'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### United Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We
# 31    833.534028
# 36    798.846587
# 158   891.662791
# 183   875.302006
# 168  1465.995744

# %%
cat_features = [0, 5]
numerical_features = [1,2,3,4,6,7,8]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_united_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.7448</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.742857</td>
#       <td>0.800000</td>
#       <td>0.770370</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.754717</td>
#       <td>0.689655</td>
#       <td>0.720721</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.747967</td>
#       <td>0.747967</td>
#       <td>0.747967</td>
#       <td>0.747967</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.748787</td>
#       <td>0.744828</td>
#       <td>0.745546</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.748450</td>
#       <td>0.747967</td>
#       <td>0.746958</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["KNN + SMOTENC + optuna"],
            "Датасет": ["united"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='KNN + SMOTENC + optuna, splashing, united'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### Alternative Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness_binary', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio',
            'volume_fraction_binary', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness_binary  \
# 31                        0.877193     neutral                 0
# 36                        0.877193   lyophilic                 1
# 158                       1.864407   lyophobic                 0
# 183                       0.847458   lyophilic                 0
# 168                       1.219512     neutral                 0
#
#      volume_fraction_binary           Re           We
# 31                        1  2110.385675   833.534028
# 36                        1  2022.562172   798.846587
# 158                       0   661.664919   891.662791
# 183                       1   649.524278   875.302006
# 168                       0  1466.205641  1465.995744

# %%
cat_features = [0, 5]
numerical_features = [1, 2, 3, 4, 7, 8]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_alternative_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.7439</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.736111</td>
#       <td>0.815385</td>
#       <td>0.773723</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.764706</td>
#       <td>0.672414</td>
#       <td>0.715596</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.747967</td>
#       <td>0.747967</td>
#       <td>0.747967</td>
#       <td>0.747967</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.750408</td>
#       <td>0.743899</td>
#       <td>0.744659</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.749595</td>
#       <td>0.747967</td>
#       <td>0.746313</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["KNN + SMOTENC + optuna"],
            "Датасет": ["alternative"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='KNN + SMOTENC + optuna, splashing, alternative'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### PF Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 
            'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='splashing', features=features, get_pf=True)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We    Re_1/4    We_1/4   Re_1/4^2  Re_1/4 We_1/4   We_1/4^2
# 31    833.534028  6.777827  5.373173  45.938934      36.418436  28.870989
# 36    798.846587  6.706184  5.316378  44.972905      35.652609  28.263874
# 158   891.662791  5.071770  5.464497  25.722848      27.714668  29.860723
# 183   875.302006  5.048343  5.439256  25.485766      27.459228  29.585503
# 168  1465.995744  6.187977  6.187756  38.291065      38.289694  38.288324

# %%
cat_features = [0, 5]
numerical_features = [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12, 13]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/splashing_pf_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8772</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.878788</td>
#       <td>0.892308</td>
#       <td>0.885496</td>
#       <td>65.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.877193</td>
#       <td>0.862069</td>
#       <td>0.869565</td>
#       <td>58.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.877990</td>
#       <td>0.877188</td>
#       <td>0.877531</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.878036</td>
#       <td>0.878049</td>
#       <td>0.877984</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["splashing"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["pf"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, splashing, pf'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# # net_impact

# %% [markdown]
# ## 1. CatBoost + SMOTENC + optuna

# %% [markdown]
# ### Original Dataset

# %%
features = ['Re', 'We', 'particle_liquid_density_ratio',
             'wettability', 'roughness', 'surface_tension', 'liquid_density']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      liquid_density  surface_tension  particle_liquid_density_ratio  \
# 31             1140           0.0691                       0.877193
# 36             1140           0.0691                       0.877193
# 158            1180           0.0679                       1.864407
# 183            1180           0.0679                       0.847458
# 168             820           0.0269                       1.219512
#
#     wettability  roughness           Re           We
# 31      neutral       0.04  2110.385675   833.534028
# 36    lyophilic      10.89  2022.562172   798.846587
# 158   lyophobic       2.49   661.664919   891.662791
# 183   lyophilic       0.10   649.524278   875.302006
# 168     neutral       0.04  1466.205641  1465.995744

# %%
cat_features = [3]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/net_impact_original_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8232</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.926471</td>
#       <td>0.768293</td>
#       <td>0.840000</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.654545</td>
#       <td>0.878049</td>
#       <td>0.750000</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.804878</td>
#       <td>0.804878</td>
#       <td>0.804878</td>
#       <td>0.804878</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.790508</td>
#       <td>0.823171</td>
#       <td>0.795000</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.835829</td>
#       <td>0.804878</td>
#       <td>0.810000</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["original"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, net_impact, original'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### United Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We
# 31    833.534028
# 36    798.846587
# 158   891.662791
# 183   875.302006
# 168  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/net_impact_united_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.9390</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.986667</td>
#       <td>0.902439</td>
#       <td>0.942675</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.833333</td>
#       <td>0.975610</td>
#       <td>0.898876</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.926829</td>
#       <td>0.926829</td>
#       <td>0.926829</td>
#       <td>0.926829</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.910000</td>
#       <td>0.939024</td>
#       <td>0.920776</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.935556</td>
#       <td>0.926829</td>
#       <td>0.928076</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["united"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, net_impact, united'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### Alternative Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness_binary', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio',
            'volume_fraction_binary', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness_binary  \
# 31                        0.877193     neutral                 0
# 36                        0.877193   lyophilic                 1
# 158                       1.864407   lyophobic                 0
# 183                       0.847458   lyophilic                 0
# 168                       1.219512     neutral                 0
#
#      volume_fraction_binary           Re           We
# 31                        1  2110.385675   833.534028
# 36                        1  2022.562172   798.846587
# 158                       0   661.664919   891.662791
# 183                       1   649.524278   875.302006
# 168                       0  1466.205641  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/net_impact_alternative_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.9146</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.985915</td>
#       <td>0.853659</td>
#       <td>0.915033</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.769231</td>
#       <td>0.975610</td>
#       <td>0.860215</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.877573</td>
#       <td>0.914634</td>
#       <td>0.887624</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.913687</td>
#       <td>0.894309</td>
#       <td>0.896760</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["alternative"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, net_impact, alternative'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### PF Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 
            'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features, get_pf=True)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We    Re_1/4    We_1/4   Re_1/4^2  Re_1/4 We_1/4   We_1/4^2
# 31    833.534028  6.777827  5.373173  45.938934      36.418436  28.870989
# 36    798.846587  6.706184  5.316378  44.972905      35.652609  28.263874
# 158   891.662791  5.071770  5.464497  25.722848      27.714668  29.860723
# 183   875.302006  5.048343  5.439256  25.485766      27.459228  29.585503
# 168  1465.995744  6.187977  6.187756  38.291065      38.289694  38.288324

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
best_trial_cb = get_best_trial(X_train, X_test, y_train, y_test, cat_indexes=cat_features, n_trials=N_TRIALS, timeout=None)
model = CatBoostClassifier(**best_trial_cb.params, cat_features=cat_features, verbose=False)
model.fit(X_train, y_train)
model.save_model('../utils_functionality/models/models_pickles/tuned_models/net_impact_pf_1')
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.9329</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.974026</td>
#       <td>0.914634</td>
#       <td>0.943396</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.847826</td>
#       <td>0.951220</td>
#       <td>0.896552</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.926829</td>
#       <td>0.926829</td>
#       <td>0.926829</td>
#       <td>0.926829</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.910926</td>
#       <td>0.932927</td>
#       <td>0.919974</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.931959</td>
#       <td>0.926829</td>
#       <td>0.927781</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["CatBoost + SMOTENC + optuna"],
            "Датасет": ["pf"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='CatBoost + SMOTENC + optuna, net_impact, pf'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ## 2. RandomForest + SMOTENC + optuna

# %% [markdown]
# ### Original Dataset

# %%
features = ['Re', 'We', 'particle_liquid_density_ratio',
             'wettability', 'roughness', 'surface_tension', 'liquid_density']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      liquid_density  surface_tension  particle_liquid_density_ratio  \
# 31             1140           0.0691                       0.877193
# 36             1140           0.0691                       0.877193
# 158            1180           0.0679                       1.864407
# 183            1180           0.0679                       0.847458
# 168             820           0.0269                       1.219512
#
#     wettability  roughness           Re           We
# 31      neutral       0.04  2110.385675   833.534028
# 36    lyophilic      10.89  2022.562172   798.846587
# 158   lyophobic       2.49   661.664919   891.662791
# 183   lyophilic       0.10   649.524278   875.302006
# 168     neutral       0.04  1466.205641  1465.995744

# %%
cat_features = [3]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_original_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.7988</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.865854</td>
#       <td>0.865854</td>
#       <td>0.865854</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.731707</td>
#       <td>0.731707</td>
#       <td>0.731707</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.821138</td>
#       <td>0.821138</td>
#       <td>0.821138</td>
#       <td>0.821138</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.798780</td>
#       <td>0.798780</td>
#       <td>0.798780</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.821138</td>
#       <td>0.821138</td>
#       <td>0.821138</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["original"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, net_impact, original'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### United Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We
# 31    833.534028
# 36    798.846587
# 158   891.662791
# 183   875.302006
# 168  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_united_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8720</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.924051</td>
#       <td>0.890244</td>
#       <td>0.906832</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.795455</td>
#       <td>0.853659</td>
#       <td>0.823529</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.859753</td>
#       <td>0.871951</td>
#       <td>0.865181</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.881185</td>
#       <td>0.878049</td>
#       <td>0.879065</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["united"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, net_impact, united'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### Alternative Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness_binary', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio',
            'volume_fraction_binary', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness_binary  \
# 31                        0.877193     neutral                 0
# 36                        0.877193   lyophilic                 1
# 158                       1.864407   lyophobic                 0
# 183                       0.847458   lyophilic                 0
# 168                       1.219512     neutral                 0
#
#      volume_fraction_binary           Re           We
# 31                        1  2110.385675   833.534028
# 36                        1  2022.562172   798.846587
# 158                       0   661.664919   891.662791
# 183                       1   649.524278   875.302006
# 168                       0  1466.205641  1465.995744

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_alternative_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8902</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.936709</td>
#       <td>0.902439</td>
#       <td>0.919255</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.818182</td>
#       <td>0.878049</td>
#       <td>0.847059</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.877445</td>
#       <td>0.890244</td>
#       <td>0.883157</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.897200</td>
#       <td>0.894309</td>
#       <td>0.895189</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["alternative"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, net_impact, alternative'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### PF Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 
            'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features, get_pf=True)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We    Re_1/4    We_1/4   Re_1/4^2  Re_1/4 We_1/4   We_1/4^2
# 31    833.534028  6.777827  5.373173  45.938934      36.418436  28.870989
# 36    798.846587  6.706184  5.316378  44.972905      35.652609  28.263874
# 158   891.662791  5.071770  5.464497  25.722848      27.714668  29.860723
# 183   875.302006  5.048343  5.439256  25.485766      27.459228  29.585503
# 168  1465.995744  6.187977  6.187756  38.291065      38.289694  38.288324

# %%
cat_features = [0, 5]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_rf = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=True)
model = RandomForestClassifier(**best_trial_rf.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_pf_2.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8963</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.948052</td>
#       <td>0.890244</td>
#       <td>0.918239</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.804348</td>
#       <td>0.902439</td>
#       <td>0.850575</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#       <td>0.894309</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.876200</td>
#       <td>0.896341</td>
#       <td>0.884407</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.900151</td>
#       <td>0.894309</td>
#       <td>0.895684</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["pf"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, net_impact, pf'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ## 3. KNN  + SMOTENC + optuna

# %% [markdown]
# ### Original Dataset

# %%
features = ['Re', 'We', 'particle_liquid_density_ratio',
             'wettability', 'roughness', 'surface_tension', 'liquid_density']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      liquid_density  surface_tension  particle_liquid_density_ratio  \
# 31             1140           0.0691                       0.877193
# 36             1140           0.0691                       0.877193
# 158            1180           0.0679                       1.864407
# 183            1180           0.0679                       0.847458
# 168             820           0.0269                       1.219512
#
#     wettability  roughness           Re           We
# 31      neutral       0.04  2110.385675   833.534028
# 36    lyophilic      10.89  2022.562172   798.846587
# 158   lyophobic       2.49   661.664919   891.662791
# 183   lyophilic       0.10   649.524278   875.302006
# 168     neutral       0.04  1466.205641  1465.995744

# %%
cat_features = [3]
numerical_features = [0, 1, 2, 4, 5, 6]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_original_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8415</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.909091</td>
#       <td>0.853659</td>
#       <td>0.880503</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.739130</td>
#       <td>0.829268</td>
#       <td>0.781609</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.845528</td>
#       <td>0.845528</td>
#       <td>0.845528</td>
#       <td>0.845528</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.824111</td>
#       <td>0.841463</td>
#       <td>0.831056</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.852437</td>
#       <td>0.845528</td>
#       <td>0.847538</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["KNN + SMOTENC + optuna"],
            "Датасет": ["original"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='KNN + SMOTENC + optuna, net_impact, original'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### United Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We
# 31    833.534028
# 36    798.846587
# 158   891.662791
# 183   875.302006
# 168  1465.995744

# %%
cat_features = [0, 5]
numerical_features = [1,2,3,4,6,7,8]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_united_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.7744</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.893939</td>
#       <td>0.719512</td>
#       <td>0.797297</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.596491</td>
#       <td>0.829268</td>
#       <td>0.693878</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.756098</td>
#       <td>0.756098</td>
#       <td>0.756098</td>
#       <td>0.756098</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.745215</td>
#       <td>0.774390</td>
#       <td>0.745587</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.794790</td>
#       <td>0.756098</td>
#       <td>0.762824</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["KNN + SMOTENC + optuna"],
            "Датасет": ["united"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='KNN + SMOTENC + optuna, net_impact, united'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### Alternative Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness_binary', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio',
            'volume_fraction_binary', 'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness_binary  \
# 31                        0.877193     neutral                 0
# 36                        0.877193   lyophilic                 1
# 158                       1.864407   lyophobic                 0
# 183                       0.847458   lyophilic                 0
# 168                       1.219512     neutral                 0
#
#      volume_fraction_binary           Re           We
# 31                        1  2110.385675   833.534028
# 36                        1  2022.562172   798.846587
# 158                       0   661.664919   891.662791
# 183                       1   649.524278   875.302006
# 168                       0  1466.205641  1465.995744

# %%
cat_features = [0, 5]
numerical_features = [1, 2, 3, 4, 7, 8]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_alternative_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.7378</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.855072</td>
#       <td>0.719512</td>
#       <td>0.781457</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.574074</td>
#       <td>0.756098</td>
#       <td>0.652632</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.731707</td>
#       <td>0.731707</td>
#       <td>0.731707</td>
#       <td>0.731707</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.714573</td>
#       <td>0.737805</td>
#       <td>0.717044</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.761406</td>
#       <td>0.731707</td>
#       <td>0.738515</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["KNN + SMOTENC + optuna"],
            "Датасет": ["alternative"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='KNN + SMOTENC + optuna, net_impact, alternative'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# ### PF Dataset

# %%
features = ['Re', 'We', 'wettability', 'roughness', 'inclination', 
            'particle_mean_diameter', 'particle_liquid_density_ratio', 
            'surface_tension', 'viscosity']

# %%
cs = CreateSamples(df, train, test, target='net_impact', features=features, get_pf=True)
X_train, X_test, y_train, y_test = cs.get_samples()
X_train.head()
# Out:
#      inclination  surface_tension  viscosity  particle_mean_diameter  \
# 31             0           0.0691    0.00689                0.000041
# 36             0           0.0691    0.00689                0.000041
# 158            0           0.0679    0.02310                0.000041
# 183            0           0.0679    0.02310                0.000041
# 168            0           0.0269    0.00679                0.000041
#
#      particle_liquid_density_ratio wettability  roughness           Re  \
# 31                        0.877193     neutral       0.04  2110.385675
# 36                        0.877193   lyophilic      10.89  2022.562172
# 158                       1.864407   lyophobic       2.49   661.664919
# 183                       0.847458   lyophilic       0.10   649.524278
# 168                       1.219512     neutral       0.04  1466.205641
#
#               We    Re_1/4    We_1/4   Re_1/4^2  Re_1/4 We_1/4   We_1/4^2
# 31    833.534028  6.777827  5.373173  45.938934      36.418436  28.870989
# 36    798.846587  6.706184  5.316378  44.972905      35.652609  28.263874
# 158   891.662791  5.071770  5.464497  25.722848      27.714668  29.860723
# 183   875.302006  5.048343  5.439256  25.485766      27.459228  29.585503
# 168  1465.995744  6.187977  6.187756  38.291065      38.289694  38.288324

# %%
cat_features = [0, 5]
numerical_features = [1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 12, 13]
smote_nc = SMOTENC(categorical_features=cat_features, random_state=RANDOM_STATE)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)
scaler = StandardScaler()
X_train.iloc[:, numerical_features] = scaler.fit_transform(X_train.iloc[:, numerical_features])
X_test.iloc[:, numerical_features] = scaler.fit_transform(X_test.iloc[:, numerical_features])
X_train = pd.get_dummies(X_train, columns=X_train.columns[cat_features])
X_test = pd.get_dummies(X_test, columns=X_test.columns[cat_features])

# %%
best_trial_knn = get_best_trial(X_train, X_test, y_train, y_test, n_trials=N_TRIALS, timeout=None, cb=False, rf=False, knn=True)
model = KNeighborsClassifier(**best_trial_knn.params)
model.fit(X_train, y_train)
pickle.dump(model, open('../utils_functionality/models/models_pickles/tuned_models/net_impact_pf_3.pkl', 'wb'))
y_preds = model.predict(X_test)
y_preds_proba = model.predict_proba(X_test)[:, 1]

# %%
roc, acc, f1 = get_classification_report(y_train, y_test, y_preds, y_preds_proba, return_metrics=True)
# Out:
# <h2>ROC AUC: 0.8415</h2>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>precision</th>
#       <th>recall</th>
#       <th>f1-score</th>
#       <th>support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.876404</td>
#       <td>0.951220</td>
#       <td>0.912281</td>
#       <td>82.000000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.882353</td>
#       <td>0.731707</td>
#       <td>0.800000</td>
#       <td>41.000000</td>
#     </tr>
#     <tr>
#       <th>accuracy</th>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#       <td>0.878049</td>
#     </tr>
#     <tr>
#       <th>macro avg</th>
#       <td>0.879379</td>
#       <td>0.841463</td>
#       <td>0.856140</td>
#       <td>123.000000</td>
#     </tr>
#     <tr>
#       <th>weighted avg</th>
#       <td>0.878387</td>
#       <td>0.878049</td>
#       <td>0.874854</td>
#       <td>123.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_logs = df_logs.append(
    pd.DataFrame(
        {
            "Таргет": ["net_impact"],
            "Модель": ["RandomForest + SMOTENC + optuna"],
            "Датасет": ["pf"],
            "F1": [f1],
            "ROC AUC": [roc],
        }
    )
)

# %%
wandb.init(
    project='drop-wall-impact-clfr', 
    name='RandomForest + SMOTENC + optuna, net_impact, pf'
)
wandb.log({
    'accuracy': acc,
    'ROC-AUC': roc,
    'F1-score': f1
    })

# %% [markdown]
# # Результаты экспериментов

# %% [markdown]
# ## splashing

# %%
df_splashing = df_logs[df_logs['Таргет']=='splashing']
df_splashing.sort_values(by=['F1', 'ROC AUC'], ascending=False, inplace=True)
df_splashing.reset_index(inplace=True, drop=True)
display(df_splashing.style.background_gradient(
    axis=0, 
    cmap='YlOrRd',
    subset=['F1', 'ROC AUC']
))
# Out:
# <style type="text/css">
# #T_caf5f_row0_col3, #T_caf5f_row0_col4, #T_caf5f_row1_col3, #T_caf5f_row1_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_caf5f_row2_col3 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_caf5f_row2_col4 {
#   background-color: #b40026;
#   color: #f1f1f1;
# }
# #T_caf5f_row3_col3, #T_caf5f_row3_col4 {
#   background-color: #b70026;
#   color: #f1f1f1;
# }
# #T_caf5f_row4_col3, #T_caf5f_row4_col4, #T_caf5f_row5_col3, #T_caf5f_row5_col4, #T_caf5f_row6_col3, #T_caf5f_row6_col4 {
#   background-color: #cb0a22;
#   color: #f1f1f1;
# }
# #T_caf5f_row7_col3 {
#   background-color: #d9131f;
#   color: #f1f1f1;
# }
# #T_caf5f_row7_col4 {
#   background-color: #db141e;
#   color: #f1f1f1;
# }
# #T_caf5f_row8_col3, #T_caf5f_row8_col4, #T_caf5f_row9_col3, #T_caf5f_row9_col4 {
#   background-color: #dd161d;
#   color: #f1f1f1;
# }
# #T_caf5f_row10_col3 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_caf5f_row10_col4 {
#   background-color: #fffecb;
#   color: #000000;
# }
# #T_caf5f_row11_col3, #T_caf5f_row11_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_caf5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_caf5f_level0_col0" class="col_heading level0 col0" >Таргет</th>
#       <th id="T_caf5f_level0_col1" class="col_heading level0 col1" >Модель</th>
#       <th id="T_caf5f_level0_col2" class="col_heading level0 col2" >Датасет</th>
#       <th id="T_caf5f_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_caf5f_level0_col4" class="col_heading level0 col4" >ROC AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_caf5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_caf5f_row0_col0" class="data row0 col0" >splashing</td>
#       <td id="T_caf5f_row0_col1" class="data row0 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_caf5f_row0_col2" class="data row0 col2" >pf</td>
#       <td id="T_caf5f_row0_col3" class="data row0 col3" >0.886957</td>
#       <td id="T_caf5f_row0_col4" class="data row0 col4" >0.893501</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_caf5f_row1_col0" class="data row1 col0" >splashing</td>
#       <td id="T_caf5f_row1_col1" class="data row1 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_caf5f_row1_col2" class="data row1 col2" >united</td>
#       <td id="T_caf5f_row1_col3" class="data row1 col3" >0.886957</td>
#       <td id="T_caf5f_row1_col4" class="data row1 col4" >0.893501</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_caf5f_row2_col0" class="data row2 col0" >splashing</td>
#       <td id="T_caf5f_row2_col1" class="data row2 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_caf5f_row2_col2" class="data row2 col2" >pf</td>
#       <td id="T_caf5f_row2_col3" class="data row2 col3" >0.869565</td>
#       <td id="T_caf5f_row2_col4" class="data row2 col4" >0.877188</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_caf5f_row3_col0" class="data row3 col0" >splashing</td>
#       <td id="T_caf5f_row3_col1" class="data row3 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_caf5f_row3_col2" class="data row3 col2" >alternative</td>
#       <td id="T_caf5f_row3_col3" class="data row3 col3" >0.867257</td>
#       <td id="T_caf5f_row3_col4" class="data row3 col4" >0.876260</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_caf5f_row4_col0" class="data row4 col0" >splashing</td>
#       <td id="T_caf5f_row4_col1" class="data row4 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_caf5f_row4_col2" class="data row4 col2" >alternative</td>
#       <td id="T_caf5f_row4_col3" class="data row4 col3" >0.857143</td>
#       <td id="T_caf5f_row4_col4" class="data row4 col4" >0.867639</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_caf5f_row5_col0" class="data row5 col0" >splashing</td>
#       <td id="T_caf5f_row5_col1" class="data row5 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_caf5f_row5_col2" class="data row5 col2" >original</td>
#       <td id="T_caf5f_row5_col3" class="data row5 col3" >0.857143</td>
#       <td id="T_caf5f_row5_col4" class="data row5 col4" >0.867639</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_caf5f_row6_col0" class="data row6 col0" >splashing</td>
#       <td id="T_caf5f_row6_col1" class="data row6 col1" >KNN + SMOTENC + optuna</td>
#       <td id="T_caf5f_row6_col2" class="data row6 col2" >original</td>
#       <td id="T_caf5f_row6_col3" class="data row6 col3" >0.857143</td>
#       <td id="T_caf5f_row6_col4" class="data row6 col4" >0.867639</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_caf5f_row7_col0" class="data row7 col0" >splashing</td>
#       <td id="T_caf5f_row7_col1" class="data row7 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_caf5f_row7_col2" class="data row7 col2" >pf</td>
#       <td id="T_caf5f_row7_col3" class="data row7 col3" >0.849558</td>
#       <td id="T_caf5f_row7_col4" class="data row7 col4" >0.859947</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_caf5f_row8_col0" class="data row8 col0" >splashing</td>
#       <td id="T_caf5f_row8_col1" class="data row8 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_caf5f_row8_col2" class="data row8 col2" >original</td>
#       <td id="T_caf5f_row8_col3" class="data row8 col3" >0.846847</td>
#       <td id="T_caf5f_row8_col4" class="data row8 col4" >0.859019</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_caf5f_row9_col0" class="data row9 col0" >splashing</td>
#       <td id="T_caf5f_row9_col1" class="data row9 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_caf5f_row9_col2" class="data row9 col2" >united</td>
#       <td id="T_caf5f_row9_col3" class="data row9 col3" >0.846847</td>
#       <td id="T_caf5f_row9_col4" class="data row9 col4" >0.859019</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_caf5f_row10_col0" class="data row10 col0" >splashing</td>
#       <td id="T_caf5f_row10_col1" class="data row10 col1" >KNN + SMOTENC + optuna</td>
#       <td id="T_caf5f_row10_col2" class="data row10 col2" >united</td>
#       <td id="T_caf5f_row10_col3" class="data row10 col3" >0.720721</td>
#       <td id="T_caf5f_row10_col4" class="data row10 col4" >0.744828</td>
#     </tr>
#     <tr>
#       <th id="T_caf5f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_caf5f_row11_col0" class="data row11 col0" >splashing</td>
#       <td id="T_caf5f_row11_col1" class="data row11 col1" >KNN + SMOTENC + optuna</td>
#       <td id="T_caf5f_row11_col2" class="data row11 col2" >alternative</td>
#       <td id="T_caf5f_row11_col3" class="data row11 col3" >0.715596</td>
#       <td id="T_caf5f_row11_col4" class="data row11 col4" >0.743899</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Топ 1 модель

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Топ 2 модель

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## net_impact

# %%
df_net_impact = df_logs[df_logs['Таргет']=='net_impact']
df_net_impact.sort_values(by=['F1', 'ROC AUC'], ascending=False, inplace=True)
df_net_impact.reset_index(inplace=True, drop=True)
display(df_net_impact.style.background_gradient(
    axis=0, 
    cmap='YlOrRd',
    subset=['F1', 'ROC AUC']
))
# Out:
# <style type="text/css">
# #T_28d9d_row0_col3, #T_28d9d_row0_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_28d9d_row1_col3 {
#   background-color: #840026;
#   color: #f1f1f1;
# }
# #T_28d9d_row1_col4 {
#   background-color: #8d0026;
#   color: #f1f1f1;
# }
# #T_28d9d_row2_col3 {
#   background-color: #c70723;
#   color: #f1f1f1;
# }
# #T_28d9d_row2_col4 {
#   background-color: #bb0026;
#   color: #f1f1f1;
# }
# #T_28d9d_row3_col3 {
#   background-color: #d30f20;
#   color: #f1f1f1;
# }
# #T_28d9d_row3_col4 {
#   background-color: #d7121f;
#   color: #f1f1f1;
# }
# #T_28d9d_row4_col3 {
#   background-color: #d6111f;
#   color: #f1f1f1;
# }
# #T_28d9d_row4_col4 {
#   background-color: #e1191d;
#   color: #f1f1f1;
# }
# #T_28d9d_row5_col3 {
#   background-color: #ee3122;
#   color: #f1f1f1;
# }
# #T_28d9d_row5_col4 {
#   background-color: #f43d25;
#   color: #f1f1f1;
# }
# #T_28d9d_row6_col3 {
#   background-color: #fc5b2e;
#   color: #f1f1f1;
# }
# #T_28d9d_row6_col4, #T_28d9d_row7_col4 {
#   background-color: #fd863a;
#   color: #f1f1f1;
# }
# #T_28d9d_row7_col3 {
#   background-color: #fd8038;
#   color: #f1f1f1;
# }
# #T_28d9d_row8_col3 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_28d9d_row8_col4 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_28d9d_row9_col3 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_28d9d_row9_col4 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_28d9d_row10_col3 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_28d9d_row10_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_28d9d_row11_col3, #T_28d9d_row11_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_28d9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28d9d_level0_col0" class="col_heading level0 col0" >Таргет</th>
#       <th id="T_28d9d_level0_col1" class="col_heading level0 col1" >Модель</th>
#       <th id="T_28d9d_level0_col2" class="col_heading level0 col2" >Датасет</th>
#       <th id="T_28d9d_level0_col3" class="col_heading level0 col3" >F1</th>
#       <th id="T_28d9d_level0_col4" class="col_heading level0 col4" >ROC AUC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28d9d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28d9d_row0_col0" class="data row0 col0" >net_impact</td>
#       <td id="T_28d9d_row0_col1" class="data row0 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_28d9d_row0_col2" class="data row0 col2" >united</td>
#       <td id="T_28d9d_row0_col3" class="data row0 col3" >0.898876</td>
#       <td id="T_28d9d_row0_col4" class="data row0 col4" >0.939024</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row1" class="row_heading level0 row1" >11</th>
#       <td id="T_28d9d_row1_col0" class="data row1 col0" >net_impact</td>
#       <td id="T_28d9d_row1_col1" class="data row1 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_28d9d_row1_col2" class="data row1 col2" >pf</td>
#       <td id="T_28d9d_row1_col3" class="data row1 col3" >0.896552</td>
#       <td id="T_28d9d_row1_col4" class="data row1 col4" >0.932927</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_28d9d_row2_col0" class="data row2 col0" >net_impact</td>
#       <td id="T_28d9d_row2_col1" class="data row2 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_28d9d_row2_col2" class="data row2 col2" >alternative</td>
#       <td id="T_28d9d_row2_col3" class="data row2 col3" >0.860215</td>
#       <td id="T_28d9d_row2_col4" class="data row2 col4" >0.914634</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_28d9d_row3_col0" class="data row3 col0" >net_impact</td>
#       <td id="T_28d9d_row3_col1" class="data row3 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_28d9d_row3_col2" class="data row3 col2" >pf</td>
#       <td id="T_28d9d_row3_col3" class="data row3 col3" >0.850575</td>
#       <td id="T_28d9d_row3_col4" class="data row3 col4" >0.896341</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_28d9d_row4_col0" class="data row4 col0" >net_impact</td>
#       <td id="T_28d9d_row4_col1" class="data row4 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_28d9d_row4_col2" class="data row4 col2" >alternative</td>
#       <td id="T_28d9d_row4_col3" class="data row4 col3" >0.847059</td>
#       <td id="T_28d9d_row4_col4" class="data row4 col4" >0.890244</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_28d9d_row5_col0" class="data row5 col0" >net_impact</td>
#       <td id="T_28d9d_row5_col1" class="data row5 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_28d9d_row5_col2" class="data row5 col2" >united</td>
#       <td id="T_28d9d_row5_col3" class="data row5 col3" >0.823529</td>
#       <td id="T_28d9d_row5_col4" class="data row5 col4" >0.871951</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_28d9d_row6_col0" class="data row6 col0" >net_impact</td>
#       <td id="T_28d9d_row6_col1" class="data row6 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_28d9d_row6_col2" class="data row6 col2" >pf</td>
#       <td id="T_28d9d_row6_col3" class="data row6 col3" >0.800000</td>
#       <td id="T_28d9d_row6_col4" class="data row6 col4" >0.841463</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row7" class="row_heading level0 row7" >6</th>
#       <td id="T_28d9d_row7_col0" class="data row7 col0" >net_impact</td>
#       <td id="T_28d9d_row7_col1" class="data row7 col1" >KNN + SMOTENC + optuna</td>
#       <td id="T_28d9d_row7_col2" class="data row7 col2" >original</td>
#       <td id="T_28d9d_row7_col3" class="data row7 col3" >0.781609</td>
#       <td id="T_28d9d_row7_col4" class="data row7 col4" >0.841463</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row8" class="row_heading level0 row8" >7</th>
#       <td id="T_28d9d_row8_col0" class="data row8 col0" >net_impact</td>
#       <td id="T_28d9d_row8_col1" class="data row8 col1" >CatBoost + SMOTENC + optuna</td>
#       <td id="T_28d9d_row8_col2" class="data row8 col2" >original</td>
#       <td id="T_28d9d_row8_col3" class="data row8 col3" >0.750000</td>
#       <td id="T_28d9d_row8_col4" class="data row8 col4" >0.823171</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_28d9d_row9_col0" class="data row9 col0" >net_impact</td>
#       <td id="T_28d9d_row9_col1" class="data row9 col1" >RandomForest + SMOTENC + optuna</td>
#       <td id="T_28d9d_row9_col2" class="data row9 col2" >original</td>
#       <td id="T_28d9d_row9_col3" class="data row9 col3" >0.731707</td>
#       <td id="T_28d9d_row9_col4" class="data row9 col4" >0.798780</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_28d9d_row10_col0" class="data row10 col0" >net_impact</td>
#       <td id="T_28d9d_row10_col1" class="data row10 col1" >KNN + SMOTENC + optuna</td>
#       <td id="T_28d9d_row10_col2" class="data row10 col2" >united</td>
#       <td id="T_28d9d_row10_col3" class="data row10 col3" >0.693878</td>
#       <td id="T_28d9d_row10_col4" class="data row10 col4" >0.774390</td>
#     </tr>
#     <tr>
#       <th id="T_28d9d_level0_row11" class="row_heading level0 row11" >10</th>
#       <td id="T_28d9d_row11_col0" class="data row11 col0" >net_impact</td>
#       <td id="T_28d9d_row11_col1" class="data row11 col1" >KNN + SMOTENC + optuna</td>
#       <td id="T_28d9d_row11_col2" class="data row11 col2" >alternative</td>
#       <td id="T_28d9d_row11_col3" class="data row11 col3" >0.652632</td>
#       <td id="T_28d9d_row11_col4" class="data row11 col4" >0.737805</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Топ 1 модель

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Топ 2 модель

# %% [markdown]
# ![image.png](attachment:image.png)
