# %% [markdown]
# Test KNN, SVC, LogisticRegression, CatBoost, XGboost with pipeline

# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

import joblib

from statsmodels.api import Logit # type: ignore
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

from pathlib import Path
import sys

sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from split_tools import get_train_test
from modelling3_utils import (
    # _prepare_df,
    MLPipeline,
    _create_pipeline,
    StatsModelsEstimator,
)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Logistic Regression

# %%
estimator = LogisticRegression()

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop = (
        'Re', 
        'We', 
        'init_volume_fraction',
        'particle_droplet_diameter_ratio', 
        'sedimentation_Re',
        # 'particle_liquid_density_ratio',
        'sedimentation_Stk'
        # 'sign_sedimentation_Re',
        # 'volume_fraction', 
        # 'relative_roughness', 
        # 'inclination',
        # 'wettability',
    ),
    model_postfix='test',
)

ml_pipe.run()
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sign_sedimentation_Re',
#  'particle_liquid_density_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sign_sedimentation_Re',
#                                   'particle_liquid_density_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "LogisticRegression"
#                                                                          0
# dataset                                                         df_dimless
# ...

# %%
model = joblib.load(
    '../results/models_modelling3/LogisticRegression_splashing_test')
model.predict_proba(
    ml_pipe.get_X_y(ml_pipe.test)[0])[:5]
# Out:
# array([[0.05959526, 0.94040474],
#        [0.06389382, 0.93610618],
#        [0.04239738, 0.95760262],
#        [0.89485934, 0.10514066],
#        [0.00426144, 0.99573856]])

# %% [markdown]
# # KNClassifier

# %%
estimator = KNeighborsClassifier()

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop = (
        'Re', 
        'We', 
        'init_volume_fraction',
        'particle_droplet_diameter_ratio', 
        'sedimentation_Re',
        # 'particle_liquid_density_ratio',
        'sedimentation_Stk'
        # 'sign_sedimentation_Re',
        # 'volume_fraction', 
        # 'relative_roughness', 
        # 'inclination',
        # 'wettability',
    ), model_postfix='test',)

ml_pipe.run()
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sign_sedimentation_Re',
#  'particle_liquid_density_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sign_sedimentation_Re',
#                                   'particle_liquid_density_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "KNeighborsClassifier"
#                                                                          0
# dataset                                                         df_dimless
# ...

# %%
model = joblib.load(
    '../results/models_modelling3/KNeighborsClassifier_splashing_test')
model.predict_proba(
    ml_pipe.get_X_y(ml_pipe.test)[0])[:5]
# Out:
# array([[0.05959526, 0.94040474],
#        [0.06389382, 0.93610618],
#        [0.04239738, 0.95760262],
#        [0.89485934, 0.10514066],
#        [0.00426144, 0.99573856]])

# %% [markdown]
# # SVC

# %%
estimator = SVC(probability=True)

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop = (
        'Re', 
        'We', 
        'init_volume_fraction',
        'particle_droplet_diameter_ratio', 
        'sedimentation_Re',
        # 'particle_liquid_density_ratio',
        'sedimentation_Stk'
        # 'sign_sedimentation_Re',
        # 'volume_fraction', 
        # 'relative_roughness', 
        # 'inclination',
        # 'wettability',
    ), model_postfix='test',)

ml_pipe.run()
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sign_sedimentation_Re',
#  'particle_liquid_density_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sign_sedimentation_Re',
#                                   'particle_liquid_density_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "SVC"
#                                                                          0
# dataset                                                         df_dimless
# ...

# %%
model = joblib.load(
    '../results/models_modelling3/SVC_splashing_test')
model.predict_proba(
    ml_pipe.get_X_y(ml_pipe.test)[0])[:5]
# Out:
# array([[0.05959526, 0.94040474],
#        [0.06389382, 0.93610618],
#        [0.04239738, 0.95760262],
#        [0.89485934, 0.10514066],
#        [0.00426144, 0.99573856]])

# %% [markdown]
# # CatBoost

# %%
estimator = CatBoostClassifier(verbose=False)

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop = (
        'Re', 
        'We', 
        'init_volume_fraction',
        'particle_droplet_diameter_ratio', 
        'sedimentation_Re',
        # 'particle_liquid_density_ratio',
        'sedimentation_Stk'
        # 'sign_sedimentation_Re',
        # 'volume_fraction', 
        # 'relative_roughness', 
        # 'inclination',
        # 'wettability',
    ), model_postfix='test',)

ml_pipe.run()
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sign_sedimentation_Re',
#  'particle_liquid_density_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sign_sedimentation_Re',
#                                   'particle_liquid_density_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "CatBoostClassifier"
#                                                                          0
# dataset                                                         df_dimless
# ...

# %%
model = joblib.load(
    '../results/models_modelling3/CatBoostClassifier_splashing_test')
model.predict_proba(
    ml_pipe.get_X_y(ml_pipe.test)[0])[:5]
# Out:
# array([[0.05959526, 0.94040474],
#        [0.06389382, 0.93610618],
#        [0.04239738, 0.95760262],
#        [0.89485934, 0.10514066],
#        [0.00426144, 0.99573856]])

# %% [markdown]
# # XGBoost

# %%
estimator = XGBClassifier()

ml_pipe = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop = (
        'Re', 
        'We', 
        'init_volume_fraction',
        'particle_droplet_diameter_ratio', 
        'sedimentation_Re',
        # 'particle_liquid_density_ratio',
        'sedimentation_Stk'
        # 'sign_sedimentation_Re',
        # 'volume_fraction', 
        # 'relative_roughness', 
        # 'inclination',
        # 'wettability',
    ), model_postfix='test',)

ml_pipe.run()
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'no_fragmentation', 'splashing'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ('sign_sedimentation_Re',
#  'particle_liquid_density_ratio',
#  'relative_roughness',
#  'K')
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(),
#                                  ('inclination', 'volume_fraction')),
#                                 ('std', StandardScaler(),
#                                  ('sign_sedimentation_Re',
#                                   'particle_liquid_density_ratio',
#                                   'relative_roughness', 'K')),
#                                 ('passthrough', 'passthrough',
#                                  ('wettability',))])
# no summary in estimator class "XGBClassifier"
#                                                                          0
# dataset                                                         df_dimless
# ...

# %%
model = joblib.load(
    '../results/models_modelling3/XGBClassifier_splashing_test')
model.predict_proba(
    ml_pipe.get_X_y(ml_pipe.test)[0])[:5]
# Out:
# array([[0.00264955, 0.99735045],
#        [0.05747163, 0.94252837],
#        [0.00106913, 0.9989309 ],
#        [0.9433746 , 0.05662544],
#        [0.06219703, 0.937803  ]], dtype=float32)
