# %% [markdown]
# Modelling of df_modelling_dimensionless.xlsx

# %% [markdown]
# # Libraries

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from tqdm import tqdm

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from xgboost import XGBClassifier
from catboost import CatBoostClassifier

# %%
RANDOM_STATE = 42

# %%
# train/test split
sys.path.insert(1, '../utils_functionality/split_utils/')
from split_tools import get_train_test

# %%
# sklearn models pipeline
sys.path.insert(1, '../utils_functionality/models/')
from modelling2_utils import MLPipeline

# %%
# sklearn models pipeline
sys.path.insert(1, '../utils_functionality/models/')
from modelling2_utils import MLPipeline

# %%
dataset_filename = 'df_modelling_dimensionless'

# %% [markdown]
# # Splashing

# %% [markdown]
# ## Train/test datasets creation

# %%
target = 'splashing'
train, test = get_train_test(
    dataset_filename=dataset_filename,
    target=target)

# %% [markdown]
# ## Numerical, categorical features selection

# %%
train.describe()
# Out:
#         splashing  wettability  inclination  roughness_binary  \
# count  297.000000   297.000000   297.000000        297.000000
# mean     0.646465     0.912458     9.242424          0.117845
# std      0.478874     0.825530    15.987172          0.322969
# min      0.000000     0.000000     0.000000          0.000000
# 25%      0.000000     0.000000     0.000000          0.000000
# 50%      1.000000     1.000000     0.000000          0.000000
# 75%      1.000000     2.000000    20.000000          0.000000
# max      1.000000     2.000000    45.000000          1.000000
#
#        particle_liquid_density_ratio  volume_fraction_binary  \
# count                     297.000000              297.000000
# mean                        0.990754                0.727273
# std                         0.269354                0.446113
# min                         0.381356                0.000000
# 25%                         0.877193                0.000000
# 50%                         1.000000                1.000000
# 75%                         1.016949                1.000000
# max                         1.864407                1.000000
#
#        particle_droplet_diameter_ratio            Re           We       We_Re
# count                       297.000000    297.000000   297.000000  297.000000
# mean                          0.025974   3437.867206   759.440848  171.713124
# std                           0.024387   4881.530866   403.820050   84.738011
# min                           0.011339    256.976895   142.008866   52.684981
# 25%                           0.012652    600.961715   629.826251  128.988793
# 50%                           0.013577    672.716015   807.132068  152.487586
# 75%                           0.018694   6185.563594   903.933380  236.927284
# max                           0.103774  19139.168057  2036.917752  472.780129

# %%
for column in train.columns:
    print(f'{column}:\t|\t{[round(x, 3) for x in train[column].unique()[:5]]}\t|\tUnique vales: {train[column].nunique()}')
# Out:
# splashing:	|	[0, 1]	|	Unique vales: 2
# wettability:	|	[1, 2, 0]	|	Unique vales: 3
# inclination:	|	[45, 0, 20]	|	Unique vales: 3
# roughness_binary:	|	[0, 1]	|	Unique vales: 2
# particle_liquid_density_ratio:	|	[0.847, 1.0, 1.864, 1.017, 1.22]	|	Unique vales: 8
# volume_fraction_binary:	|	[1, 0]	|	Unique vales: 2
# particle_droplet_diameter_ratio:	|	[0.014, 0.044, 0.014, 0.013, 0.012]	|	Unique vales: 148
# Re:	|	[300.481, 11864.38, 16568.235, 6246.415, 682.304]	|	Unique vales: 196
# We:	|	[202.465, 667.71, 1398.653, 175.769, 919.476]	|	Unique vales: 199
# We_Re:	|	[59.242, 269.684, 424.301, 117.864, 154.976]	|	Unique vales: 197

# %%
binary_features = ['roughness_binary', 'volume_fraction_binary']
categorical_features = ['wettability']
numerical_features = ['Re', 'We', 'We_Re',
                         'inclination',
                        'particle_liquid_density_ratio',
                        'particle_droplet_diameter_ratio']

# %%
assert len((set(train.columns)) & set(binary_features + categorical_features + numerical_features)) + 1 \
    == len(train.columns), 'Some features are not selected'

# %% [markdown]
# ## Modelling

# %% [markdown]
# Models:
# * Sklearn models
#     * LogReg
#     * SVM
#     * KNN
# * CatBoost
# * XGBoost

# %% [markdown]
# ### Sklearn models

# %%
models = [
    LogisticRegression(),
    SVC(),
    KNeighborsClassifier()]
encoders = ['onehot', 'ordenc']
smote_flags = [True, False]

for model in tqdm(models):
    for encoder in encoders:
        for smote_flag in smote_flags:
            pipeline = MLPipeline(train, test, target, model,
                    numerical_features, categorical_features,
                    random_state=RANDOM_STATE,
                    postfix=encoder, dataset_filename=dataset_filename,
                    smote=smote_flag, binary_features=binary_features, addition_str='_binary',
                    path_models='../results/models_modelling2_binary')
            pipeline.full_pipeline()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# logisticregression_smote_splashing_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# logisticregression_splashing_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# logisticregression_smote_splashing_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
#  33%|███▎      | 1/3 [00:00<00:00,  2.83it/s]
# logisticregression_splashing_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# svc_smote_splashing_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# svc_splashing_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
#  67%|██████▋   | 2/3 [00:00<00:00,  2.97it/s]
# svc_smote_splashing_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# svc_splashing_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_smote_splashing_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# 100%|██████████| 3/3 [00:01<00:00,  2.90it/s]
# kneighborsclassifier_splashing_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_smote_splashing_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_splashing_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary

# %% [markdown]
# ### Boosting Models

# %%
models =  [
    XGBClassifier(),
    CatBoostClassifier(verbose=False)
    ]
ohe_flags = [True, False]

for model in tqdm(models):
    for smote_flag in smote_flags:
        for ohe_flag in ohe_flags:
            pipeline = MLPipeline(train, test, target, model,
                        numerical_features, categorical_features,
                        random_state=RANDOM_STATE,
                        postfix='', dataset_filename=dataset_filename,
                        smote=smote_flag, boosting_ohe=ohe_flag)
            pipeline.full_pipeline()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# xgbclassifier_ohe_smote_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
# xgbclassifier_smote_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
# xgbclassifier_ohe_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
#  50%|█████     | 1/2 [00:00<00:00,  2.67it/s]
# xgbclassifier_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
# catboostclassifier_ohe_smote_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
# catboostclassifier_smote_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
# catboostclassifier_ohe_splashing_df_modelling_dimensionless was saved in ..\modelling2_models
# 100%|██████████| 2/2 [00:26<00:00, 13.36s/it]
# catboostclassifier_splashing_df_modelling_dimensionless was saved in ..\modelling2_models

# %% [markdown]
# # Net impact

# %% [markdown]
# ## Train/test datasets creation

# %%
target = 'net_impact'
train, test = get_train_test(
    dataset_filename=dataset_filename,
    target=target)

# %% [markdown]
# ## Modelling

# %% [markdown]
# Models:
# * Sklearn models
#     * LogReg
#     * SVM
#     * KNN
# * CatBoost
# * XGBoost

# %% [markdown]
# ### Sklearn models

# %%
models = [
    LogisticRegression(),
    SVC(),
    KNeighborsClassifier()]
encoders = ['onehot', 'ordenc']
smote_flags = [True, False]

for model in tqdm(models):
    for encoder in encoders:
        for smote_flag in smote_flags:
            pipeline = MLPipeline(train, test, target, model,
                    numerical_features, categorical_features,
                    random_state=RANDOM_STATE,
                    postfix=encoder, dataset_filename=dataset_filename,
                    smote=smote_flag, binary_features=binary_features, addition_str='_binary',
                    path_models='../results/models_modelling2_binary')
            pipeline.full_pipeline()
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# logisticregression_smote_net_impact_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# logisticregression_net_impact_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# logisticregression_smote_net_impact_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
#  33%|███▎      | 1/3 [00:00<00:00,  2.82it/s]
# logisticregression_net_impact_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# svc_smote_net_impact_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# svc_net_impact_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
#  67%|██████▋   | 2/3 [00:00<00:00,  2.80it/s]
# svc_smote_net_impact_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# svc_net_impact_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_smote_net_impact_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_net_impact_df_modelling_dimensionless_binary_onehot was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_smote_net_impact_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# kneighborsclassifier_net_impact_df_modelling_dimensionless_binary_ordenc was saved in ..\results\models_modelling2_binary
# 100%|██████████| 3/3 [00:01<00:00,  2.79it/s]

# %% [markdown]
# ### Boosting Models

# %%
models =  [
    XGBClassifier(),
    CatBoostClassifier(verbose=False)
    ]
ohe_flags = [True, False]

for model in tqdm(models):
    for smote_flag in smote_flags:
        for ohe_flag in ohe_flags:
            pipeline = MLPipeline(train, test, target, model,
                        numerical_features, categorical_features,
                        random_state=RANDOM_STATE,
                        postfix='', dataset_filename=dataset_filename,
                        smote=smote_flag, boosting_ohe=ohe_flag)
            pipeline.full_pipeline()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# xgbclassifier_ohe_smote_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
# xgbclassifier_smote_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
# xgbclassifier_ohe_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
#  50%|█████     | 1/2 [00:00<00:00,  2.65it/s]
# xgbclassifier_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
# catboostclassifier_ohe_smote_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
# catboostclassifier_smote_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
# catboostclassifier_ohe_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
# 100%|██████████| 2/2 [00:27<00:00, 13.51s/it]
# catboostclassifier_net_impact_df_modelling_dimensionless was saved in ..\modelling2_models
