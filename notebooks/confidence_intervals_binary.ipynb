# %% [markdown]
# Calculations of confidence intervals for Logistic Regression

# %% [markdown]
# # Libraries

# %%
import os
from pathlib import Path
import statsmodels.api as sm
import joblib
import pandas as pd

# %%
RANDOM_STATE = 42

# %%
# train/test split
import sys
sys.path.insert(1, '../utils_functionality/split_utils/')
from split_tools import get_train_test

# %%
# dict with num features
sys.path.insert(1, '../utils_functionality/models/')
from modelling2_hyperparams import dict_num_features

# %% [markdown]
# # Splashing

# %% [markdown]
# ../results/models_modelling2_binary/logisticregression_splashing_df_modelling_dimensionless_binary_ordenc

# %%
target = 'splashing'
train, test = get_train_test(
    dataset_filename='df_modelling_dimensionless',
    target=target)
features = dict_num_features['df_modelling_dimensionless']+['wettability']+ ['roughness_binary', 'volume_fraction_binary']
train = train[features+[target]]
test = test[features+[target]]

# %%
path_pipeline = r'../results/models_modelling2_binary/logisticregression_splashing_df_modelling_dimensionless_binary_ordenc'
pipeline = joblib.load(path_pipeline)

# %%
column_transformer = pipeline.steps[0][1].fit(train.drop(columns=[target]))

# %% [markdown]
# ## With intercept

# %%
X = column_transformer.transform(
    train.drop(columns=[target]))

# %%
X = column_transformer.transform(
    train.drop(columns=[target]))
X = sm.add_constant(X)
y = train[target]

# %%
model_splashing_intercept = sm.Logit(y, X)
result = model_splashing_intercept.fit()
model_splashing_intercept.exog_names[:] = ['const'] + features
# Out:
# Optimization terminated successfully.
#          Current function value: 0.308097
#          Iterations 10

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              splashing   No. Observations:                  297
# Model:                          Logit   Df Residuals:                      287
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                  0.5257
# Time:                        23:08:20   Log-Likelihood:                -91.505
# converged:                       True   LL-Null:                       -192.93
# Covariance Type:            nonrobust   LLR p-value:                 8.338e-39
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                               2.2947      0.661      3.472      0.001       0.999       3.590
# Re                                 -3.3650      1.270     -2.650      0.008      -5.854      -0.876
# We                                 -0.1847      0.139     -1.325      0.185      -0.458       0.089
# We_Re                               9.1735      2.416      3.796      0.000       4.437      13.910
# inclination                         1.1173      0.232      4.818      0.000       0.663       1.572
# particle_liquid_density_ratio       0.5394      0.202      2.667      0.008       0.143       0.936
# particle_droplet_diameter_ratio    -3.5505      1.434     -2.476      0.013      -6.361      -0.740
# wettability                         0.9205      0.258      3.574      0.000       0.416       1.425
# roughness_binary                    0.0784      0.607      0.129      0.897      -1.111       1.268
# volume_fraction_binary             -1.2771      0.510     -2.506      0.012      -2.276      -0.278
# ===================================================================================================
# """

# %%
result.summary().as_latex()
# Out:
# '\\begin{center}\n\\begin{tabular}{lclc}\n\\toprule\n\\textbf{Dep. Variable:}                     &    splashing     & \\textbf{  No. Observations:  } &      297    \\\\\n\\textbf{Model:}                             &      Logit       & \\textbf{  Df Residuals:      } &      287    \\\\\n\\textbf{Method:}                            &       MLE        & \\textbf{  Df Model:          } &        9    \\\\\n\\textbf{Date:}                              & Tue, 02 Jul 2024 & \\textbf{  Pseudo R-squ.:     } &   0.5257    \\\\\n\\textbf{Time:}                              &     23:08:34     & \\textbf{  Log-Likelihood:    } &   -91.505   \\\\\n\\textbf{converged:}                         &       True       & \\textbf{  LL-Null:           } &   -192.93   \\\\\n\\textbf{Covariance Type:}                   &    nonrobust     & \\textbf{  LLR p-value:       } & 8.338e-39   \\\\\n\\bottomrule\n\\end{tabular}\n\\begin{tabular}{lcccccc}\n                                            & \\textbf{coef} & \\textbf{std err} & \\textbf{z} & \\textbf{P$> |$z$|$} & \\textbf{[0.025} & \\textbf{0.975]}  \\\\\n\\midrule\n\\textbf{const}                              &       2.2947  &        0.661     &     3.472  &         0.001        &        0.999    &        3.590     \\\\\n\\textbf{Re}                                 &      -3.3650  &        1.270     &    -2.650  &         0.008        &       -5.854    &       -0.876     \\\\\n\\textbf{We}                                 &      -0.1847  &        0.139     &    -1.325  &         0.185        &       -0.458    &        0.089     \\\\\n\\textbf{We\\_Re}                             &       9.1735  &        2.416     &     3.796  &         0.000        &        4.437    &       13.910     \\\\\n\\textbf{inclination}                        &       1.1173  &        0.232     &     4.818  &         0.000        &        0.663    &        1.572     \\\\\n\\textbf{particle\\_liquid\\_density\\_ratio}   &       0.5394  &        0.202     &     2.667  &         0.008        &        0.143    &        0.936     \\\\\n\\textbf{particle\\_droplet\\_diameter\\_ratio} &      -3.5505  &        1.434     &    -2.476  &         0.013        &       -6.361    &       -0.740     \\\\\n\\textbf{wettability}                        &       0.9205  &        0.258     &     3.574  &         0.000        &        0.416    &        1.425     \\\\\n\\textbf{roughness\\_binary}                  &       0.0784  &        0.607     &     0.129  &         0.897        &       -1.111    &        1.268     \\\\\n\\textbf{volume\\_fraction\\_binary}           &      -1.2771  &        0.510     &    -2.506  &         0.012        &       -2.276    &       -0.278     \\\\\n\\bottomrule\n\\end{tabular}\n%\\caption{Logit Regression Results}\n\\end{center}'

# %% [markdown]
# ## Without intercept

# %%
X = column_transformer.transform(
    train.drop(columns=[target]))
y = train[target]

# %%
model_splashing = sm.Logit(y, X)
result = model_splashing.fit()
model_splashing.exog_names[:] = features
# Out:
# Optimization terminated successfully.
#          Current function value: 0.334908
#          Iterations 8

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              splashing   No. Observations:                  297
# Model:                          Logit   Df Residuals:                      288
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                  0.4844
# Time:                        23:08:55   Log-Likelihood:                -99.468
# converged:                       True   LL-Null:                       -192.93
# Covariance Type:            nonrobust   LLR p-value:                 3.599e-36
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Re                                 -3.0978      1.034     -2.997      0.003      -5.124      -1.072
# We                                 -0.1651      0.139     -1.191      0.234      -0.437       0.107
# We_Re                               8.4754      1.880      4.507      0.000       4.790      12.161
# inclination                         0.9644      0.200      4.811      0.000       0.572       1.357
# particle_liquid_density_ratio       0.3579      0.194      1.847      0.065      -0.022       0.738
# particle_droplet_diameter_ratio    -4.4788      1.364     -3.284      0.001      -7.152      -1.806
# wettability                         1.3043      0.230      5.679      0.000       0.854       1.754
# roughness_binary                    0.6391      0.544      1.174      0.240      -0.428       1.706
# volume_fraction_binary             -0.0527      0.344     -0.153      0.878      -0.726       0.621
# ===================================================================================================
# """

# %%
result.summary().as_latex()
# Out:
# '\\begin{center}\n\\begin{tabular}{lclc}\n\\toprule\n\\textbf{Dep. Variable:}                     &    splashing     & \\textbf{  No. Observations:  } &      297    \\\\\n\\textbf{Model:}                             &      Logit       & \\textbf{  Df Residuals:      } &      288    \\\\\n\\textbf{Method:}                            &       MLE        & \\textbf{  Df Model:          } &        8    \\\\\n\\textbf{Date:}                              & Tue, 02 Jul 2024 & \\textbf{  Pseudo R-squ.:     } &   0.4844    \\\\\n\\textbf{Time:}                              &     23:09:11     & \\textbf{  Log-Likelihood:    } &   -99.468   \\\\\n\\textbf{converged:}                         &       True       & \\textbf{  LL-Null:           } &   -192.93   \\\\\n\\textbf{Covariance Type:}                   &    nonrobust     & \\textbf{  LLR p-value:       } & 3.599e-36   \\\\\n\\bottomrule\n\\end{tabular}\n\\begin{tabular}{lcccccc}\n                                            & \\textbf{coef} & \\textbf{std err} & \\textbf{z} & \\textbf{P$> |$z$|$} & \\textbf{[0.025} & \\textbf{0.975]}  \\\\\n\\midrule\n\\textbf{Re}                                 &      -3.0978  &        1.034     &    -2.997  &         0.003        &       -5.124    &       -1.072     \\\\\n\\textbf{We}                                 &      -0.1651  &        0.139     &    -1.191  &         0.234        &       -0.437    &        0.107     \\\\\n\\textbf{We\\_Re}                             &       8.4754  &        1.880     &     4.507  &         0.000        &        4.790    &       12.161     \\\\\n\\textbf{inclination}                        &       0.9644  &        0.200     &     4.811  &         0.000        &        0.572    &        1.357     \\\\\n\\textbf{particle\\_liquid\\_density\\_ratio}   &       0.3579  &        0.194     &     1.847  &         0.065        &       -0.022    &        0.738     \\\\\n\\textbf{particle\\_droplet\\_diameter\\_ratio} &      -4.4788  &        1.364     &    -3.284  &         0.001        &       -7.152    &       -1.806     \\\\\n\\textbf{wettability}                        &       1.3043  &        0.230     &     5.679  &         0.000        &        0.854    &        1.754     \\\\\n\\textbf{roughness\\_binary}                  &       0.6391  &        0.544     &     1.174  &         0.240        &       -0.428    &        1.706     \\\\\n\\textbf{volume\\_fraction\\_binary}           &      -0.0527  &        0.344     &    -0.153  &         0.878        &       -0.726    &        0.621     \\\\\n\\bottomrule\n\\end{tabular}\n%\\caption{Logit Regression Results}\n\\end{center}'

# %% [markdown]
# # Net impact

# %% [markdown]
# ../results/models_modelling2_binary/logisticregression_net_impact_df_modelling_dimensionless_binary_ordenc

# %%
target = 'net_impact'
train, test = get_train_test(
    dataset_filename='df_modelling_dimensionless',
    target=target)
train = train[features+[target]]
test = test[features+[target]]

# %%
path_pipeline = '../results/models_modelling2_binary/logisticregression_net_impact_df_modelling_dimensionless_binary_ordenc'
pipeline = joblib.load(path_pipeline)
column_transformer = pipeline.steps[0][1].fit(train.drop(columns=[target]))

# %% [markdown]
# ## With intercept

# %%
X = column_transformer.transform(
    train.drop(columns=[target]))
X = sm.add_constant(X)
y = train[target]

# %%
model_net_impact_intercept = sm.Logit(y, X)
result = model_net_impact_intercept.fit()
model_net_impact_intercept.exog_names[:] = ['const'] + features
# Out:
# Optimization terminated successfully.
#          Current function value: 0.267808
#          Iterations 9

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             net_impact   No. Observations:                  297
# Model:                          Logit   Df Residuals:                      287
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                  0.5376
# Time:                        23:10:06   Log-Likelihood:                -79.539
# converged:                       True   LL-Null:                       -172.03
# Covariance Type:            nonrobust   LLR p-value:                 4.603e-35
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# const                              -1.2163      0.559     -2.176      0.030      -2.312      -0.121
# Re                                  2.5218      1.174      2.148      0.032       0.221       4.823
# We                                  0.1932      0.166      1.165      0.244      -0.132       0.518
# We_Re                              -7.4885      1.946     -3.849      0.000     -11.302      -3.675
# inclination                        -1.0366      0.235     -4.405      0.000      -1.498      -0.575
# particle_liquid_density_ratio      -0.9362      0.238     -3.937      0.000      -1.402      -0.470
# particle_droplet_diameter_ratio     3.1609      1.324      2.387      0.017       0.565       5.756
# wettability                        -2.0507      0.344     -5.962      0.000      -2.725      -1.377
# roughness_binary                   -0.6069      0.636     -0.954      0.340      -1.853       0.639
# volume_fraction_binary              0.5348      0.559      0.957      0.339      -0.561       1.630
# ===================================================================================================
# """

# %%
result.summary().as_latex()
# Out:
# '\\begin{center}\n\\begin{tabular}{lclc}\n\\toprule\n\\textbf{Dep. Variable:}                     &   net\\_impact    & \\textbf{  No. Observations:  } &      297    \\\\\n\\textbf{Model:}                             &      Logit       & \\textbf{  Df Residuals:      } &      287    \\\\\n\\textbf{Method:}                            &       MLE        & \\textbf{  Df Model:          } &        9    \\\\\n\\textbf{Date:}                              & Tue, 02 Jul 2024 & \\textbf{  Pseudo R-squ.:     } &   0.5376    \\\\\n\\textbf{Time:}                              &     23:10:15     & \\textbf{  Log-Likelihood:    } &   -79.539   \\\\\n\\textbf{converged:}                         &       True       & \\textbf{  LL-Null:           } &   -172.03   \\\\\n\\textbf{Covariance Type:}                   &    nonrobust     & \\textbf{  LLR p-value:       } & 4.603e-35   \\\\\n\\bottomrule\n\\end{tabular}\n\\begin{tabular}{lcccccc}\n                                            & \\textbf{coef} & \\textbf{std err} & \\textbf{z} & \\textbf{P$> |$z$|$} & \\textbf{[0.025} & \\textbf{0.975]}  \\\\\n\\midrule\n\\textbf{const}                              &      -1.2163  &        0.559     &    -2.176  &         0.030        &       -2.312    &       -0.121     \\\\\n\\textbf{Re}                                 &       2.5218  &        1.174     &     2.148  &         0.032        &        0.221    &        4.823     \\\\\n\\textbf{We}                                 &       0.1932  &        0.166     &     1.165  &         0.244        &       -0.132    &        0.518     \\\\\n\\textbf{We\\_Re}                             &      -7.4885  &        1.946     &    -3.849  &         0.000        &      -11.302    &       -3.675     \\\\\n\\textbf{inclination}                        &      -1.0366  &        0.235     &    -4.405  &         0.000        &       -1.498    &       -0.575     \\\\\n\\textbf{particle\\_liquid\\_density\\_ratio}   &      -0.9362  &        0.238     &    -3.937  &         0.000        &       -1.402    &       -0.470     \\\\\n\\textbf{particle\\_droplet\\_diameter\\_ratio} &       3.1609  &        1.324     &     2.387  &         0.017        &        0.565    &        5.756     \\\\\n\\textbf{wettability}                        &      -2.0507  &        0.344     &    -5.962  &         0.000        &       -2.725    &       -1.377     \\\\\n\\textbf{roughness\\_binary}                  &      -0.6069  &        0.636     &    -0.954  &         0.340        &       -1.853    &        0.639     \\\\\n\\textbf{volume\\_fraction\\_binary}           &       0.5348  &        0.559     &     0.957  &         0.339        &       -0.561    &        1.630     \\\\\n\\bottomrule\n\\end{tabular}\n%\\caption{Logit Regression Results}\n\\end{center}'

# %% [markdown]
# ## Without intercept

# %%
X = column_transformer.transform(
    train.drop(columns=[target]))
y = train[target]

# %%
model_net_impact = sm.Logit(y, X)
result = model_net_impact.fit()
model_net_impact.exog_names[:] = features
# Out:
# Optimization terminated successfully.
#          Current function value: 0.276396
#          Iterations 9

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             net_impact   No. Observations:                  297
# Model:                          Logit   Df Residuals:                      288
# Method:                           MLE   Df Model:                            8
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                  0.5228
# Time:                        23:10:26   Log-Likelihood:                -82.089
# converged:                       True   LL-Null:                       -172.03
# Covariance Type:            nonrobust   LLR p-value:                 1.088e-34
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# Re                                  2.5468      1.065      2.392      0.017       0.460       4.634
# We                                  0.1907      0.167      1.142      0.254      -0.137       0.518
# We_Re                              -7.5776      1.754     -4.320      0.000     -11.016      -4.140
# inclination                        -1.0259      0.228     -4.491      0.000      -1.474      -0.578
# particle_liquid_density_ratio      -0.8456      0.232     -3.649      0.000      -1.300      -0.391
# particle_droplet_diameter_ratio     3.7340      1.243      3.003      0.003       1.297       6.171
# wettability                        -2.2697      0.328     -6.922      0.000      -2.912      -1.627
# roughness_binary                   -0.8656      0.598     -1.448      0.148      -2.037       0.306
# volume_fraction_binary             -0.3068      0.386     -0.795      0.427      -1.063       0.450
# ===================================================================================================
# """

# %%
result.summary().as_latex()
# Out:
# '\\begin{center}\n\\begin{tabular}{lclc}\n\\toprule\n\\textbf{Dep. Variable:}                     &   net\\_impact    & \\textbf{  No. Observations:  } &      297    \\\\\n\\textbf{Model:}                             &      Logit       & \\textbf{  Df Residuals:      } &      288    \\\\\n\\textbf{Method:}                            &       MLE        & \\textbf{  Df Model:          } &        8    \\\\\n\\textbf{Date:}                              & Tue, 02 Jul 2024 & \\textbf{  Pseudo R-squ.:     } &   0.5228    \\\\\n\\textbf{Time:}                              &     23:10:29     & \\textbf{  Log-Likelihood:    } &   -82.089   \\\\\n\\textbf{converged:}                         &       True       & \\textbf{  LL-Null:           } &   -172.03   \\\\\n\\textbf{Covariance Type:}                   &    nonrobust     & \\textbf{  LLR p-value:       } & 1.088e-34   \\\\\n\\bottomrule\n\\end{tabular}\n\\begin{tabular}{lcccccc}\n                                            & \\textbf{coef} & \\textbf{std err} & \\textbf{z} & \\textbf{P$> |$z$|$} & \\textbf{[0.025} & \\textbf{0.975]}  \\\\\n\\midrule\n\\textbf{Re}                                 &       2.5468  &        1.065     &     2.392  &         0.017        &        0.460    &        4.634     \\\\\n\\textbf{We}                                 &       0.1907  &        0.167     &     1.142  &         0.254        &       -0.137    &        0.518     \\\\\n\\textbf{We\\_Re}                             &      -7.5776  &        1.754     &    -4.320  &         0.000        &      -11.016    &       -4.140     \\\\\n\\textbf{inclination}                        &      -1.0259  &        0.228     &    -4.491  &         0.000        &       -1.474    &       -0.578     \\\\\n\\textbf{particle\\_liquid\\_density\\_ratio}   &      -0.8456  &        0.232     &    -3.649  &         0.000        &       -1.300    &       -0.391     \\\\\n\\textbf{particle\\_droplet\\_diameter\\_ratio} &       3.7340  &        1.243     &     3.003  &         0.003        &        1.297    &        6.171     \\\\\n\\textbf{wettability}                        &      -2.2697  &        0.328     &    -6.922  &         0.000        &       -2.912    &       -1.627     \\\\\n\\textbf{roughness\\_binary}                  &      -0.8656  &        0.598     &    -1.448  &         0.148        &       -2.037    &        0.306     \\\\\n\\textbf{volume\\_fraction\\_binary}           &      -0.3068  &        0.386     &    -0.795  &         0.427        &       -1.063    &        0.450     \\\\\n\\bottomrule\n\\end{tabular}\n%\\caption{Logit Regression Results}\n\\end{center}'
