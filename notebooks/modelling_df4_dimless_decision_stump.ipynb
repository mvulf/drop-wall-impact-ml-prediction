# %% [markdown]
# Comparison with baseline decision stump $K < K_L$

# %% [markdown]
# $K_L = (649 + \frac{3.76}{\text{relative\_roughness}^{0.63}} ^ {5/8})$

# %% [markdown]
# # Import libraries

# %%
# Changes to all modules will automatically be applied when any cell runs. 
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

from pathlib import Path
import sys

sys.path.append(
    str(Path('..', 'utils_functionality', 'split_utils'))
)
sys.path.append(
    str(Path('..', 'utils_functionality', 'models'))
)

from modelling3_utils import (
    MLPipeline,
    DecisionStumpEstimator
)

# %% [markdown]
# # Baseline comparison

# %%
estimator = DecisionStumpEstimator(less_sign=False)
ml_pipe_ds = MLPipeline(
    target='splashing',
    estimator=estimator,
    features_to_drop=('init_volume_fraction', 'volume_fraction', 'sedimentation_Re',
       'sign_sedimentation_Re', 'sign_sedimentation_Stk', 'sedimentation_Stk',
       'particle_liquid_density_ratio', 'particle_droplet_diameter_ratio',
       'sign_particle_droplet_diameter_ratio', 'wettability', 'inclination', 'Re', 'We'),
    passthrough_features=('K', 'relative_roughness'),
    log_features=(),
    model_postfix='greater_or_equal_kl')

ml_pipe_ds.run(
    save_model_and_metrics=True)
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "splashing" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_splashing.xlsx
# std_features
# ()
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(), ()),
#                                 ('passthrough', 'passthrough',
#                                  ('K', 'relative_roughness'))])
# no summary in estimator class "DecisionStumpEstimator"
#                                                                             0
# target                                                              splashing
# model                             DecisionStump_splashing_greater_or_equal_kl
# holdout_test_accuracy                                                0.773333
# holdout_test_f1                                                      0.808989
# holdout_test_roc_auc                                                 0.782407
# ...

# %%
estimator = DecisionStumpEstimator(less_sign=True)
ml_pipe_ds = MLPipeline(
    target='no_fragmentation',
    estimator=estimator,
    features_to_drop=('init_volume_fraction', 'volume_fraction', 'sedimentation_Re',
       'sign_sedimentation_Re', 'sign_sedimentation_Stk', 'sedimentation_Stk',
       'particle_liquid_density_ratio', 'particle_droplet_diameter_ratio',
       'sign_particle_droplet_diameter_ratio', 'wettability', 'inclination', 'Re', 'We',),
    passthrough_features=('K', 'relative_roughness'),
    log_features=(),
    model_postfix='less_kl')

ml_pipe_ds.run(
    save_model_and_metrics=True)
# Out:
# Load dataset from: ..\data\df_dimless.xlsx
# Keep "no_fragmentation" from {'splashing', 'no_fragmentation'}
# Load split indexes from: ..\data\df_ml_split_no_fragmentation.xlsx
# std_features
# ()
# ColumnTransformer(transformers=[('minmax', MinMaxScaler(), ()),
#                                 ('std', StandardScaler(), ()),
#                                 ('passthrough', 'passthrough',
#                                  ('K', 'relative_roughness'))])
# no summary in estimator class "DecisionStumpEstimator"
#                                                                        0
# target                                                  no_fragmentation
# model                             DecisionStump_no_fragmentation_less_kl
# holdout_test_accuracy                                           0.733333
# holdout_test_f1                                                 0.642857
# holdout_test_roc_auc                                            0.786364
# ...
